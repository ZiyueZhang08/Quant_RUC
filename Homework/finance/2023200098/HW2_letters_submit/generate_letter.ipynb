# %%
import pandas as pd
from docxtpl import DocxTemplate
from docx2pdf import convert
import os
import time

# %%
# --- 1. 定义文件名和输出文件夹 ---
TEMPLATE_FILE = "template.docx"
UNIVERSITY_FILE = "university_name.xlsx"
RESEARCH_FILE = "research_area.xlsx"
OUTPUT_DIR = "Generated_Letters_90"

# --- 2. 创建输出文件夹 ---

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    print(f"成功创建输出文件夹: '{OUTPUT_DIR}'")

# --- 3. 读取Excel数据 ---
try:
    df_unis = pd.read_excel(UNIVERSITY_FILE)
    df_research = pd.read_excel(RESEARCH_FILE)
    print("成功读取 university_name.xlsx 和 research_area.xlsx 数据。")
except FileNotFoundError as e:
    print(f"错误: 找不到文件 {e.filename}。请确保文件与脚本在同一目录下。")
    exit()
# Out:
# 成功创建输出文件夹: 'Generated_Letters_90'
# 成功读取 university_name.xlsx 和 research_area.xlsx 数据。

# %%
# --- 4. 加载Word模板 ---
doc = DocxTemplate(TEMPLATE_FILE)
print(f"成功加载Word模板: '{TEMPLATE_FILE}'")

# --- 5. 循环生成90封信件 ---
total_letters = len(df_unis) * len(df_research)
current_letter = 0
print(f"\n开始生成 {total_letters} 封申请信...")

# 遍历所有大学
for uni_index, uni_row in df_unis.iterrows():
    # 遍历所有研究方向
    for research_index, research_row in df_research.iterrows():
        current_letter += 1
              
        context = {}
        context.update(uni_row.to_dict())
        context.update(research_row.to_dict())

        #将 context 中的数据填入
        doc.render(context)   
        uni_name_clean = uni_row['university_name'].replace(" ", "_").replace("-", "_")
        research_area_clean = research_row['research_area'].replace(" ", "_")
        file_name = f"{uni_name_clean}_{research_area_clean}"
        
        # 定义Word和PDF文件的完整保存路径
        docx_path = os.path.join(OUTPUT_DIR, f"{file_name}.docx")
        doc.save(docx_path)
        print(f"[{current_letter}/{total_letters}] 已生成: {file_name}.docx")
        
print(f"\n所有 {total_letters} 封信件已保存在 '{OUTPUT_DIR}' 文件夹中。")
# Out:
# 成功加载Word模板: 'template.docx'
#
# 开始生成 90 封申请信...
# [1/90] 已生成: Massachusetts_Institute_of_Technology_finance.docx
# [2/90] 已生成: Massachusetts_Institute_of_Technology_Economics.docx
# [3/90] 已生成: Massachusetts_Institute_of_Technology_Marketing.docx
# [4/90] 已生成: University_of_California_Berkeley_finance.docx
# [5/90] 已生成: University_of_California_Berkeley_Economics.docx
# [6/90] 已生成: University_of_California_Berkeley_Marketing.docx
# [7/90] 已生成: University_of_Chicago_finance.docx
# [8/90] 已生成: University_of_Chicago_Economics.docx
# [9/90] 已生成: University_of_Chicago_Marketing.docx
# [10/90] 已生成: Paris_School_of_Economics_finance.docx
# [11/90] 已生成: Paris_School_of_Economics_Economics.docx
# [12/90] 已生成: Paris_School_of_Economics_Marketing.docx
# [13/90] 已生成: Princeton_University_finance.docx
# [14/90] 已生成: Princeton_University_Economics.docx
# [15/90] 已生成: Princeton_University_Marketing.docx
# [16/90] 已生成: Stanford_University_finance.docx
# [17/90] 已生成: Stanford_University_Economics.docx
# [18/90] 已生成: Stanford_University_Marketing.docx
# [19/90] 已生成: Yale_University_finance.docx
# [20/90] 已生成: Yale_University_Economics.docx
# [21/90] 已生成: Yale_University_Marketing.docx
# [22/90] 已生成: Toulouse_School_of_Economics_finance.docx
# [23/90] 已生成: Toulouse_School_of_Economics_Economics.docx
# [24/90] 已生成: Toulouse_School_of_Economics_Marketing.docx
# [25/90] 已生成: Oxford_University_finance.docx
# [26/90] 已生成: Oxford_University_Economics.docx
# [27/90] 已生成: Oxford_University_Marketing.docx
# [28/90] 已生成: Columbia_University_finance.docx
# [29/90] 已生成: Columbia_University_Economics.docx
# [30/90] 已生成: Columbia_University_Marketing.docx
# [31/90] 已生成: Barcelona_School_of_Economics_finance.docx
# [32/90] 已生成: Barcelona_School_of_Economics_Economics.docx
# [33/90] 已生成: Barcelona_School_of_Economics_Marketing.docx
# [34/90] 已生成: New_York_University_finance.docx
# [35/90] 已生成: New_York_University_Economics.docx
# [36/90] 已生成: New_York_University_Marketing.docx
# [37/90] 已生成: Brown_University_finance.docx
# [38/90] 已生成: Brown_University_Economics.docx
# [39/90] 已生成: Brown_University_Marketing.docx
# [40/90] 已生成: University_of_Pennsylvania_finance.docx
# [41/90] 已生成: University_of_Pennsylvania_Economics.docx
# [42/90] 已生成: University_of_Pennsylvania_Marketing.docx
# [43/90] 已生成: London_School_of_Economics_finance.docx
# [44/90] 已生成: London_School_of_Economics_Economics.docx
# [45/90] 已生成: London_School_of_Economics_Marketing.docx
# [46/90] 已生成: Boston_University_finance.docx
# [47/90] 已生成: Boston_University_Economics.docx
# [48/90] 已生成: Boston_University_Marketing.docx
# [49/90] 已生成: University_College_London_finance.docx
# [50/90] 已生成: University_College_London_Economics.docx
# [51/90] 已生成: University_College_London_Marketing.docx
# [52/90] 已生成: University_of_California_San_Diego_finance.docx
# [53/90] 已生成: University_of_California_San_Diego_Economics.docx
# [54/90] 已生成: University_of_California_San_Diego_Marketing.docx
# [55/90] 已生成: University_of_Michigan_finance.docx
# [56/90] 已生成: University_of_Michigan_Economics.docx
# [57/90] 已生成: University_of_Michigan_Marketing.docx
# [58/90] 已生成: Northwestern_University_finance.docx
# [59/90] 已生成: Northwestern_University_Economics.docx
# [60/90] 已生成: Northwestern_University_Marketing.docx
# [61/90] 已生成: Dartmouth_College_finance.docx
# [62/90] 已生成: Dartmouth_College_Economics.docx
# [63/90] 已生成: Dartmouth_College_Marketing.docx
# [64/90] 已生成: Universiteit_van_Tilburg_finance.docx
# [65/90] 已生成: Universiteit_van_Tilburg_Economics.docx
# [66/90] 已生成: Universiteit_van_Tilburg_Marketing.docx
# [67/90] 已生成: University_of_British_Columbia_finance.docx
# [68/90] 已生成: University_of_British_Columbia_Economics.docx
# [69/90] 已生成: University_of_British_Columbia_Marketing.docx
# [70/90] 已生成: University_of_Southern_California_finance.docx
# [71/90] 已生成: University_of_Southern_California_Economics.docx
# [72/90] 已生成: University_of_Southern_California_Marketing.docx
# [73/90] 已生成: University_of_California_Los_Angeles_finance.docx
# [74/90] 已生成: University_of_California_Los_Angeles_Economics.docx
# [75/90] 已生成: University_of_California_Los_Angeles_Marketing.docx
# [76/90] 已生成: University_of_Wisconsin_Madison_finance.docx
# [77/90] 已生成: University_of_Wisconsin_Madison_Economics.docx
# [78/90] 已生成: University_of_Wisconsin_Madison_Marketing.docx
# [79/90] 已生成: Duke_University_finance.docx
# [80/90] 已生成: Duke_University_Economics.docx
# [81/90] 已生成: Duke_University_Marketing.docx
# [82/90] 已生成: University_of_Cambridge_finance.docx
# [83/90] 已生成: University_of_Cambridge_Economics.docx
# [84/90] 已生成: University_of_Cambridge_Marketing.docx
# [85/90] 已生成: Michigan_State_University_finance.docx
# [86/90] 已生成: Michigan_State_University_Economics.docx
# [87/90] 已生成: Michigan_State_University_Marketing.docx
# [88/90] 已生成: University_of_Toronto_finance.docx
# [89/90] 已生成: University_of_Toronto_Economics.docx
# [90/90] 已生成: University_of_Toronto_Marketing.docx
#
# 所有 90 封信件已保存在 'Generated_Letters_90' 文件夹中。

# %%
import pandas as pd
from docxtpl import DocxTemplate
import os

def main():
    # 创建输出目录
    output_dir = "HW_School_Application"
    os.makedirs(output_dir, exist_ok=True)
    
    # 读取Excel文件
    universities = pd.read_excel('universities.xlsx', header=None).iloc[:, 0].tolist()
    research = pd.read_excel('research.xlsx')
    
    # 加载Word模板
    template = DocxTemplate('template.docx')
    
    # 生成SOP文档
    generated_count = 0
    
    for university in universities[:30]:
        for _, row in research.iterrows():
            # 使用正确的列名
            area = row['research_area']
            journals = [row['journal_1'], row['journal_2'], row['journal_3']]
            skills_for_area = row['skill']
            
            # 确定项目名称
            program_mapping = {
                'ECON': 'Master of Economics',
                'FINANCE': 'Master of Finance', 
                'SOC SCI': 'Master of Social Sciences',
            }
            program_name = program_mapping.get(area, f'Master of {area}')
            
            # 准备上下文数据
            context = {
                'name': 'Xiong Junfeng',
                'university': university,
                'program': program_name,
                'research_area': area,
                'journals': ", ".join(str(journal) for journal in journals),
                'skills': skills_for_area
            }
            
            # 渲染模板
            template.render(context)
            
            # 生成文件名
            safe_uni = "".join(c if c.isalnum() or c in (' ', '-', '_') else '_' for c in str(university))
            safe_area = "".join(c if c.isalnum() or c in (' ', '-', '_') else '_' for c in area)
            filename = f"SOP_{safe_uni.replace(' ', '_')}_{safe_area.replace(' ', '_')}.docx"
            
            # 保存文档
            output_path = os.path.join(output_dir, filename)
            template.save(output_path)
            generated_count += 1
            print(f"生成 [{generated_count}]: {filename}")
    
    print(f"\n生成完成！共创建 {generated_count} 份目的声明")
    
    # 询问是否生成PDF
    response = input("\n是否将Word文档转换为PDF？(y/n): ")
    if response.lower() == 'y':
        convert_to_pdf(output_dir)

def convert_to_pdf(output_dir):
    """将生成的Word文档转换为PDF"""
    try:
        from docx2pdf import convert
        print("正在转换Word文档为PDF...")
        convert(output_dir)
        print("PDF转换完成！")
    except ImportError:
        print("未安装docx2pdf库，正在尝试使用win32com方法...")
        try:
            import win32com.client
            word = win32com.client.Dispatch("Word.Application")
            word.visible = 0
            
            # 遍历所有Word文档
            for filename in os.listdir(output_dir):
                if filename.endswith(".docx"):
                    in_file = os.path.abspath(os.path.join(output_dir, filename))
                    out_file = os.path.abspath(os.path.join(output_dir, filename.replace(".docx", ".pdf")))
                    
                    doc = word.Documents.Open(in_file)
                    doc.SaveAs(out_file, FileFormat=17)  # 17表示PDF格式
                    doc.Close()
            
            word.Quit()
            print("PDF转换完成！")
        except Exception as e:
            print(f"PDF转换失败: {e}")
            print("请安装docx2pdf库: pip install docx2pdf")
    except Exception as e:
        print(f"PDF转换出错: {e}")

if __name__ == "__main__":
    main()
# Out:
# 生成 [1]: SOP_Harvard_University_Cambridge__Massachusetts__USA___ECON.docx
# 生成 [2]: SOP_Harvard_University_Cambridge__Massachusetts__USA___FINANCE.docx
# 生成 [3]: SOP_Harvard_University_Cambridge__Massachusetts__USA___SOC_SCI.docx
# 生成 [4]: SOP_Massachusetts_Institute_of_Technology__MIT__Cambridge__Massachusetts__USA___ECON.docx
# 生成 [5]: SOP_Massachusetts_Institute_of_Technology__MIT__Cambridge__Massachusetts__USA___FINANCE.docx
# 生成 [6]: SOP_Massachusetts_Institute_of_Technology__MIT__Cambridge__Massachusetts__USA___SOC_SCI.docx
# 生成 [7]: SOP_University_of_California-Berkeley_Berkeley__California__USA___ECON.docx
# 生成 [8]: SOP_University_of_California-Berkeley_Berkeley__California__USA___FINANCE.docx
# 生成 [9]: SOP_University_of_California-Berkeley_Berkeley__California__USA___SOC_SCI.docx
# 生成 [10]: SOP_University_of_Chicago_Chicago__Illinois__USA___ECON.docx
# 生成 [11]: SOP_University_of_Chicago_Chicago__Illinois__USA___FINANCE.docx
# 生成 [12]: SOP_University_of_Chicago_Chicago__Illinois__USA___SOC_SCI.docx
# 生成 [13]: SOP_Paris_School_of_Economics_Paris__France__ECON.docx
# 生成 [14]: SOP_Paris_School_of_Economics_Paris__France__FINANCE.docx
# 生成 [15]: SOP_Paris_School_of_Economics_Paris__France__SOC_SCI.docx
# 生成 [16]: SOP_Princeton_University_Princeton__New_Jersey__USA___ECON.docx
# 生成 [17]: SOP_Princeton_University_Princeton__New_Jersey__USA___FINANCE.docx
# 生成 [18]: SOP_Princeton_University_Princeton__New_Jersey__USA___SOC_SCI.docx
# 生成 [19]: SOP_Stanford_University_Stanford__California__USA___ECON.docx
# 生成 [20]: SOP_Stanford_University_Stanford__California__USA___FINANCE.docx
# 生成 [21]: SOP_Stanford_University_Stanford__California__USA___SOC_SCI.docx
# 生成 [22]: SOP_Yale_University_New_Haven__Connecticut__USA___ECON.docx
# 生成 [23]: SOP_Yale_University_New_Haven__Connecticut__USA___FINANCE.docx
# 生成 [24]: SOP_Yale_University_New_Haven__Connecticut__USA___SOC_SCI.docx
# 生成 [25]: SOP_Toulouse_School_of_Economics__TSE__Toulouse__France__ECON.docx
# 生成 [26]: SOP_Toulouse_School_of_Economics__TSE__Toulouse__France__FINANCE.docx
# 生成 [27]: SOP_Toulouse_School_of_Economics__TSE__Toulouse__France__SOC_SCI.docx
# 生成 [28]: SOP_Oxford_University_Oxford__United_Kingdom__ECON.docx
# 生成 [29]: SOP_Oxford_University_Oxford__United_Kingdom__FINANCE.docx
# 生成 [30]: SOP_Oxford_University_Oxford__United_Kingdom__SOC_SCI.docx
# 生成 [31]: SOP_Finance_and_Economics_Department__Graduate_School_of_Business__Columbia_University_New_York_City__New_York__USA___ECON.docx
# 生成 [32]: SOP_Finance_and_Economics_Department__Graduate_School_of_Business__Columbia_University_New_York_City__New_York__USA___FINANCE.docx
# 生成 [33]: SOP_Finance_and_Economics_Department__Graduate_School_of_Business__Columbia_University_New_York_City__New_York__USA___SOC_SCI.docx
# 生成 [34]: SOP_Faculty_of_Economics__University_of_Cambridge_Cambridge__United_Kingdom__ECON.docx
# 生成 [35]: SOP_Faculty_of_Economics__University_of_Cambridge_Cambridge__United_Kingdom__FINANCE.docx
# 生成 [36]: SOP_Faculty_of_Economics__University_of_Cambridge_Cambridge__United_Kingdom__SOC_SCI.docx
# 生成 [37]: SOP_Department_of_Economics__Boston_College_Chestnut_Hill__Massachusetts__USA___ECON.docx
# 生成 [38]: SOP_Department_of_Economics__Boston_College_Chestnut_Hill__Massachusetts__USA___FINANCE.docx
# 生成 [39]: SOP_Department_of_Economics__Boston_College_Chestnut_Hill__Massachusetts__USA___SOC_SCI.docx
# 生成 [40]: SOP_University_of_Toronto_Toronto__Canada__ECON.docx
# 生成 [41]: SOP_University_of_Toronto_Toronto__Canada__FINANCE.docx
# 生成 [42]: SOP_University_of_Toronto_Toronto__Canada__SOC_SCI.docx
# 生成 [43]: SOP_University_of_Warwick_Coventry__United_Kingdom__ECON.docx
# 生成 [44]: SOP_University_of_Warwick_Coventry__United_Kingdom__FINANCE.docx
# 生成 [45]: SOP_University_of_Warwick_Coventry__United_Kingdom__SOC_SCI.docx
# 生成 [46]: SOP_Cornell_University_Ithaca__New_York__USA___ECON.docx
# 生成 [47]: SOP_Cornell_University_Ithaca__New_York__USA___FINANCE.docx
# 生成 [48]: SOP_Cornell_University_Ithaca__New_York__USA___SOC_SCI.docx
# 生成 [49]: SOP_University_of_California-Davis_Davis__California__USA___ECON.docx
# 生成 [50]: SOP_University_of_California-Davis_Davis__California__USA___FINANCE.docx
# 生成 [51]: SOP_University_of_California-Davis_Davis__California__USA___SOC_SCI.docx
# 生成 [52]: SOP_Rijksuniversiteit_Groningen_Groningen__Netherlands__ECON.docx
# 生成 [53]: SOP_Rijksuniversiteit_Groningen_Groningen__Netherlands__FINANCE.docx
# 生成 [54]: SOP_Rijksuniversiteit_Groningen_Groningen__Netherlands__SOC_SCI.docx
# 生成 [55]: SOP_Johns_Hopkins_University_Baltimore__Maryland__USA___ECON.docx
# 生成 [56]: SOP_Johns_Hopkins_University_Baltimore__Maryland__USA___FINANCE.docx
# 生成 [57]: SOP_Johns_Hopkins_University_Baltimore__Maryland__USA___SOC_SCI.docx
# 生成 [58]: SOP_Alma_Mater_Studiorum_-_Università_di_Bologna_Bologna__Italy__ECON.docx
# 生成 [59]: SOP_Alma_Mater_Studiorum_-_Università_di_Bologna_Bologna__Italy__FINANCE.docx
# 生成 [60]: SOP_Alma_Mater_Studiorum_-_Università_di_Bologna_Bologna__Italy__SOC_SCI.docx
# 生成 [61]: SOP_Department_of_Economics__University_of_Virginia_Charlottesville__Virginia__USA___ECON.docx
# 生成 [62]: SOP_Department_of_Economics__University_of_Virginia_Charlottesville__Virginia__USA___FINANCE.docx
# 生成 [63]: SOP_Department_of_Economics__University_of_Virginia_Charlottesville__Virginia__USA___SOC_SCI.docx
# 生成 [64]: SOP_College_of_Business_and_Economics__Australian_National_University_Canberra__Australia__ECON.docx
# 生成 [65]: SOP_College_of_Business_and_Economics__Australian_National_University_Canberra__Australia__FINANCE.docx
# 生成 [66]: SOP_College_of_Business_and_Economics__Australian_National_University_Canberra__Australia__SOC_SCI.docx
# 生成 [67]: SOP_Georgetown_University_Washington__District_of_Columbia__USA___ECON.docx
# 生成 [68]: SOP_Georgetown_University_Washington__District_of_Columbia__USA___FINANCE.docx
# 生成 [69]: SOP_Georgetown_University_Washington__District_of_Columbia__USA___SOC_SCI.docx
# 生成 [70]: SOP_University_of_Minnesota_Minneapolis__Minnesota__USA___ECON.docx
# 生成 [71]: SOP_University_of_Minnesota_Minneapolis__Minnesota__USA___FINANCE.docx
# 生成 [72]: SOP_University_of_Minnesota_Minneapolis__Minnesota__USA___SOC_SCI.docx
# 生成 [73]: SOP_Stern_School_of_Business__New_York_University__NYU__New_York_City__New_York__USA___ECON.docx
# 生成 [74]: SOP_Stern_School_of_Business__New_York_University__NYU__New_York_City__New_York__USA___FINANCE.docx
# 生成 [75]: SOP_Stern_School_of_Business__New_York_University__NYU__New_York_City__New_York__USA___SOC_SCI.docx
# 生成 [76]: SOP_University_of_California-Santa_Barbara__UCSB__Santa_Barbara__California__USA___ECON.docx
# 生成 [77]: SOP_University_of_California-Santa_Barbara__UCSB__Santa_Barbara__California__USA___FINANCE.docx
# 生成 [78]: SOP_University_of_California-Santa_Barbara__UCSB__Santa_Barbara__California__USA___SOC_SCI.docx
# 生成 [79]: SOP_Pennsylvania_State_University_State_College__Pennsylvania__USA___ECON.docx
# 生成 [80]: SOP_Pennsylvania_State_University_State_College__Pennsylvania__USA___FINANCE.docx
# 生成 [81]: SOP_Pennsylvania_State_University_State_College__Pennsylvania__USA___SOC_SCI.docx
# 生成 [82]: SOP_Washington_University_in_St__Louis_St__Louis__Missouri__USA___ECON.docx
# 生成 [83]: SOP_Washington_University_in_St__Louis_St__Louis__Missouri__USA___FINANCE.docx
# 生成 [84]: SOP_Washington_University_in_St__Louis_St__Louis__Missouri__USA___SOC_SCI.docx
# 生成 [85]: SOP_University_of_Colorado_Boulder__Colorado__USA___ECON.docx
# 生成 [86]: SOP_University_of_Colorado_Boulder__Colorado__USA___FINANCE.docx
# 生成 [87]: SOP_University_of_Colorado_Boulder__Colorado__USA___SOC_SCI.docx
# 生成 [88]: SOP_Rutgers_University-New_Brunswick_New_Brunswick__New_Jersey__USA___ECON.docx
# 生成 [89]: SOP_Rutgers_University-New_Brunswick_New_Brunswick__New_Jersey__USA___FINANCE.docx
# 生成 [90]: SOP_Rutgers_University-New_Brunswick_New_Brunswick__New_Jersey__USA___SOC_SCI.docx
#
# 生成完成！共创建 90 份目的声明
#
# 是否将Word文档转换为PDF？(y/n): y
# 正在转换Word文档为PDF...
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=90.0), HTML(value='')))
# PDF转换完成！

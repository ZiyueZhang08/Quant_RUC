# %%
#作业一

# %%
#第一部分：求各区域租房中位数

# %%
import pandas as pd

# 读取Excel文件，保留所有空白单元格（默认行为）
# 假设文件名为"数据.xlsx"，读取第一个工作表
df = pd.read_excel("HW3_Rent.xlsx", sheet_name=0)

# 显示数据（空白单元格会显示为NaN，但在后续处理中会保留位置）
print("原始数据（包含空白）：")
print(df)

# 可选：将NaN替换为更直观的空白字符串（便于查看）
df_filled = df.fillna("")
print("\n替换NaN为空白后的显示：")
print(df_filled)

# 按行遍历数据（包含空白位置）
print("\n逐行打印数据（保留空白位置）：")
for index, row in df.iterrows():
    # 每行数据会包含所有列，即使是空白单元格也会占据位置
    print(f"第{index+1}行：{row.tolist()}")
# Out:
# 原始数据（包含空白）：
#                               名称  价格（元/月） 出租方式  出租方式（整租-0，合租主卧-1，合租单间-2）  \
# 0        万源城御璄,230户型,高区景观楼层,豪华装修    33000   整租                         0
# 1     近 科技绿洲 字节房补 一室户 拎包入住 12号线东     3100   整租                         0
# 2     中庚漫游城 平阳四街坊精装修一房 12号线顾戴路拎包     3200   整租                         0
# 3     近 科技绿洲 字节房补 一室拎包入住 12号线东兰路     3100   整租                         0
# 4        近12号线,婚房首租,精装全配拎包入住,已空关     3200   整租                         0
# ...                          ...      ...  ...                       ...
# 4177  扩建到800平 带地暖8套房 包物业 家具全配 可看    34000   整租                         0
# 4178   朗阅府 豪华装修 自住配置 中央空调地暖 拎包入住     7800   整租                         0
# 4179  住进高迪 | 电梯精装现房,南向三面采光,错过再无,     8000   整租                         0
# 4180  贝越流明新苑 3室2厅2卫 精装修129平米 诚意出     8500   整租                         0
# 4181  2.21广兰站 中环内中芯国际學校旁带泳池网球场南北    12500   整租                         0
#
#         户型  整租室数  整租厅数  合租人数  面积（单位：㎡）   朝向  \
# 0     4室2厅   4.0   2.0   NaN       225   朝南
# 1     1室1厅   1.0   1.0   NaN        46   朝南
# 2     1室1厅   1.0   1.0   NaN        58   朝南
# 3     1室1厅   1.0   1.0   NaN        41  朝南北
# 4     1室1厅   1.0   1.0   NaN        43   朝南
# ...    ...   ...   ...   ...       ...  ...
# 4177  6室3厅   6.0   3.0   NaN       471   朝东
# 4178  2室2厅   2.0   2.0   NaN        91  朝南北
# 4179  2室2厅   2.0   2.0   NaN       114   朝南
# 4180  3室2厅   3.0   2.0   NaN       129  朝南北
# 4181  3室2厅   3.0   2.0   NaN       143  朝南北
#
#       朝向（朝南-0，朝南北-1，朝东南-2，朝东-3，朝西南-4，西南北向-5，朝北-6，朝西-7，朝东北-8，朝西北-9，朝东南北-10，朝东西-11，朝东西南-12）  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     1
# 4                                                     0
# ...                                                 ...
# 4177                                                  3
# 4178                                                  1
# 4179                                                  0
# 4180                                                  1
# 4181                                                  1
#
#                  小区 一级地址 二级地址     三级地址             地铁站  据地铁站距离
# 0       闵行-古美-万源城御璄   闵行   古美    万源城御璄  距12号线东兰路站约700米   700.0
# 1     闵行-古美-东兰兴城惠兰苑   闵行   古美  东兰兴城惠兰苑  距12号线东兰路站约804米   804.0
# 2       闵行-古美-平阳四街坊   闵行   古美    平阳四街坊  距12号线顾戴路站约830米   830.0
# 3        闵行-古美-祜欣公寓   闵行   古美     祜欣公寓  距12号线东兰路站约263米   263.0
# 4        闵行-古美-同济华城   闵行   古美     同济华城  距12号线虹梅路站约562米   562.0
# ...             ...  ...  ...      ...             ...     ...
# 4177  浦东-张江-汤臣高尔夫别墅   浦东   张江  汤臣高尔夫别墅             NaN     NaN
# 4178    浦东-张江-中建朗阅府   浦东   张江    中建朗阅府             NaN     NaN
# 4179   浦东-张江-城市经典高迪   浦东   张江   城市经典高迪   距2号线广兰路站约387米   387.0
# 4180   浦东-张江-贝越流明新苑   浦东   张江   贝越流明新苑   距2号线广兰路站约894米   894.0
# 4181  浦东-张江-日月光水岸花园   浦东   张江  日月光水岸花园   距2号线广兰路站约569米   569.0
#
# [4182 rows x 17 columns]
#
# 替换NaN为空白后的显示：
#                               名称  价格（元/月） 出租方式  出租方式（整租-0，合租主卧-1，合租单间-2）  \
# 0        万源城御璄,230户型,高区景观楼层,豪华装修    33000   整租                         0
# 1     近 科技绿洲 字节房补 一室户 拎包入住 12号线东     3100   整租                         0
# 2     中庚漫游城 平阳四街坊精装修一房 12号线顾戴路拎包     3200   整租                         0
# 3     近 科技绿洲 字节房补 一室拎包入住 12号线东兰路     3100   整租                         0
# 4        近12号线,婚房首租,精装全配拎包入住,已空关     3200   整租                         0
# ...                          ...      ...  ...                       ...
# 4177  扩建到800平 带地暖8套房 包物业 家具全配 可看    34000   整租                         0
# 4178   朗阅府 豪华装修 自住配置 中央空调地暖 拎包入住     7800   整租                         0
# 4179  住进高迪 | 电梯精装现房,南向三面采光,错过再无,     8000   整租                         0
# 4180  贝越流明新苑 3室2厅2卫 精装修129平米 诚意出     8500   整租                         0
# 4181  2.21广兰站 中环内中芯国际學校旁带泳池网球场南北    12500   整租                         0
#
#         户型 整租室数 整租厅数 合租人数  面积（单位：㎡）   朝向  \
# 0     4室2厅  4.0  2.0            225   朝南
# 1     1室1厅  1.0  1.0             46   朝南
# 2     1室1厅  1.0  1.0             58   朝南
# 3     1室1厅  1.0  1.0             41  朝南北
# 4     1室1厅  1.0  1.0             43   朝南
# ...    ...  ...  ...  ...       ...  ...
# 4177  6室3厅  6.0  3.0            471   朝东
# 4178  2室2厅  2.0  2.0             91  朝南北
# 4179  2室2厅  2.0  2.0            114   朝南
# 4180  3室2厅  3.0  2.0            129  朝南北
# 4181  3室2厅  3.0  2.0            143  朝南北
#
#       朝向（朝南-0，朝南北-1，朝东南-2，朝东-3，朝西南-4，西南北向-5，朝北-6，朝西-7，朝东北-8，朝西北-9，朝东南北-10，朝东西-11，朝东西南-12）  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     1
# 4                                                     0
# ...                                                 ...
# 4177                                                  3
# 4178                                                  1
# 4179                                                  0
# 4180                                                  1
# 4181                                                  1
#
#                  小区 一级地址 二级地址     三级地址             地铁站 据地铁站距离
# 0       闵行-古美-万源城御璄   闵行   古美    万源城御璄  距12号线东兰路站约700米  700.0
# 1     闵行-古美-东兰兴城惠兰苑   闵行   古美  东兰兴城惠兰苑  距12号线东兰路站约804米  804.0
# 2       闵行-古美-平阳四街坊   闵行   古美    平阳四街坊  距12号线顾戴路站约830米  830.0
# 3        闵行-古美-祜欣公寓   闵行   古美     祜欣公寓  距12号线东兰路站约263米  263.0
# 4        闵行-古美-同济华城   闵行   古美     同济华城  距12号线虹梅路站约562米  562.0
# ...             ...  ...  ...      ...             ...    ...
# 4177  浦东-张江-汤臣高尔夫别墅   浦东   张江  汤臣高尔夫别墅
# 4178    浦东-张江-中建朗阅府   浦东   张江    中建朗阅府
# 4179   浦东-张江-城市经典高迪   浦东   张江   城市经典高迪   距2号线广兰路站约387米  387.0
# 4180   浦东-张江-贝越流明新苑   浦东   张江   贝越流明新苑   距2号线广兰路站约894米  894.0
# 4181  浦东-张江-日月光水岸花园   浦东   张江  日月光水岸花园   距2号线广兰路站约569米  569.0
#
# [4182 rows x 17 columns]
#
# 逐行打印数据（保留空白位置）：
# 第1行：['万源城御璄,230户型,高区景观楼层,豪华装修', 33000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 225, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线东兰路站约700米', 700.0]
# 第2行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线东', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-东兰兴城惠兰苑', '闵行', '古美', '东兰兴城惠兰苑', '距12号线东兰路站约804米', 804.0]
# 第3行：['中庚漫游城 平阳四街坊精装修一房 12号线顾戴路拎包', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 58, '朝南', 0, '闵行-古美-平阳四街坊', '闵行', '古美', '平阳四街坊', '距12号线顾戴路站约830米', 830.0]
# 第4行：['近 科技绿洲 字节房补 一室拎包入住 12号线东兰路', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-祜欣公寓', '闵行', '古美', '祜欣公寓', '距12号线东兰路站约263米', 263.0]
# 第5行：['近12号线,婚房首租,精装全配拎包入住,已空关', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线虹梅路站约562米', 562.0]
# 第6行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2999, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线东兰路站约787米', 787.0]
# 第7行：['古美罗阳1室东苑怡景园66.00平出租,电梯一房,全', 3200, '整租', 0, '1室2厅', 1.0, 2.0, nan, 57, '朝南', 0, '闵行-古美-东苑怡景园', '闵行', '古美', '东苑怡景园', '距12号线东兰路站约804米', 804.0]
# 第8行：['漕河泾出门12号线,美食一条街,看房方便,可拎包入住', 2700, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线虹梅路站约301米', 301.0]
# 第9行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 56, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线顾戴路站约665米', 665.0]
# 第10行：['新上好房,中间楼层,全明户型,近复旦儿科,近中庚南方', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-南方公寓', '闵行', '古美', '南方公寓', '距1号线莲花路站约894米', 894.0]
# 第11行：['晶杰苑精装一房,电梯高层景观好,商圈环绕交通便利,看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线虹莘路站约604米', 604.0]
# 第12行：['出门12号线虹莘路站,品质小区,精装大一房,拎包入住', 3000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南', 0, '闵行-古美-东苑半岛花园公寓', '闵行', '古美', '东苑半岛花园公寓', '距1号线莲花路站约653米', 653.0]
# 第13行：['南方新村,莲花路站,城开,南方商城,拎包入住,随时看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-南方新村', '闵行', '古美', '南方新村', '距12号线顾戴路站约374米', 374.0]
# 第14行：['近十二号线,近儿科医院 看房随时方便 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平阳二村', '闵行', '古美', '平阳二村', '距12号线虹梅路站约598米', 598.0]
# 第15行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线急', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 49, '朝南', 0, '闵行-古美-华一新城', '闵行', '古美', '华一新城', '距12号线虹梅路站约781米', 781.0]
# 第16行：['近12号线,婚房首租,精装全配拎包入住,已空关', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-华梅花苑', '闵行', '古美', '华梅花苑', '距12号线虹梅路站约301米', 301.0]
# 第17行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线顾戴路站约855米', 855.0]
# 第18行：['近12号线,精装修电梯一房,看房有钥匙,诚心出租好房', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线东兰路站约386米', 386.0]
# 第19行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距1号线莲花路站约894米', 894.0]
# 第20行：['九星苑 龙茗路 随时可看 租金可月付 家电齐全', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约492米', 492.0]
# 第21行：['出门12号线东兰路 近漕河泾 看房随时方便 拎包入住', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平南三四村', '闵行', '古美', '平南三四村', '距12号线东兰路站约868米', 868.0]
# 第22行：['实拍!一号线口,电梯精装一房,中庚,租金可月付!', 2888, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距1号线莲花路站约479米', 479.0]
# 第23行：['现代精装电梯一房,复旦儿科医院,12号线,可月付房租', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南北', 1, '闵行-古美-江南星城一期', '闵行', '古美', '江南星城一期', '距12号线东兰路站约868米', 868.0]
# 第24行：['刚刚挂牌!电梯大一房,业主自住装修,近漕河泾,可随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南北', 1, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线顾戴路站约785米', 785.0]
# 第25行：['首租!出门1号线,精装一房,南北通透,南方商城', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 37, '朝南', 0, '闵行-古美-南方城', '闵行', '古美', '南方城', '距12号线东兰路站约804米', 804.0]
# 第26行：['欧风花都 近漕河泾 近12号线东兰路 精装全配 拎包', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线东兰路站约193米', 193.0]
# 第27行：['莲花公寓出门12号线,近儿科医院!随时看房!租金月付', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-莲花公寓(闵行)', '闵行', '古美', '莲花公寓(闵行)', '距12号线东兰路站约616米', 616.0]
# 第28行：['精装修,家具家电全新,出门口,可短租,带车位,拎包入', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南北', 1, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线东兰路站约429米', 429.0]
# 第29行：['近12号东兰路 密码锁 随时可看 采光好 精装全配', 3100, '整租', 0, '1室2厅', 1.0, 2.0, nan, 41, '朝南', 0, '闵行-古美-和嘉公寓', '闵行', '古美', '和嘉公寓', '距12号线东兰路站约429米', 429.0]
# 第30行：['新出电梯一房,近12号线,紧临漕河泾,家具家电,随时', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距1号线莲花路站约894米', 894.0]
# 第31行：['九星苑,一房一厅 诚意出租,看房子随时,租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝北', 6, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线虹梅路站约562米', 562.0]
# 第32行：['装修3年精装电梯一房,出门龙茗路商业街,近12号线,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-东兰雅苑', '闵行', '古美', '东兰雅苑', '距12号线虹梅路站约301米', 301.0]
# 第33行：['12号线口精装修一房,近漕河泾,租金月付,看房随时,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距12号线顾戴路站约462米', 462.0]
# 第34行：['平南一村,精装大一房中间楼层采光好,交通便利,诚心出', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距1号线莲花路站约661米', 661.0]
# 第35行：['1号线.12号线精装一房一厅,适合居家白领,看房随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线东兰路站约668米', 668.0]
# 第36行：['华精装一房,12号线虹梅路站50米,漕河泾,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线虹梅路站约1092米', 1092.0]
# 第37行：['中友嘉园 出门12号线虹梅路 旁边漕河泾 随时可看拎', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 50, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线虹莘路站约823米', 823.0]
# 第38行：['出门12号线 顾戴路 随时可住 拎包入住 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-新时代花园', '闵行', '古美', '新时代花园', '距12号线东兰路站约616米', 616.0]
# 第39行：['阳光美景城 近南方商城 锦江乐园 万源城 电梯三房', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 134, '朝南', 0, '闵行-古美-阳光美景城一期', '闵行', '古美', '阳光美景城一期', '距12号线顾戴路站约775米', 775.0]
# 第40行：['万源城朗郡,11层,双南两房,精装修,包车位物业!', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 114, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线顾戴路站约775米', 775.0]
# 第41行：['东苑古龙尚居,精装修3房,带车位,靠西校世外,有钥匙', 13000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 147, '朝南', 0, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约668米', 668.0]
# 第42行：['平吉二村,精装一房,初次出租,全新家电,拎包入住价格', 3300, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-平吉二村', '闵行', '古美', '平吉二村', '距12号线东兰路站约616米', 616.0]
# 第43行：['12号线口,带车位,近漕河泾,人车分流', 24000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 144, '朝南北', 1, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距12号线东兰路站约700米', 700.0]
# 第44行：['初次出租,一楼,干净清爽 安静 陪读好房', 7700, '整租', 0, '2室2厅', 2.0, 2.0, nan, 93, '朝南', 0, '闵行-古美-新时代景庭', '闵行', '古美', '新时代景庭', '距12号线顾戴路站约855米', 855.0]
# 第45行：['初次出租,万源城双南两房,带车位,看房方便,近12号', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 109, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线东兰路站约668米', 668.0]
# 第46行：['人车分流,带双车位!视野好,空房可长租', 15500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 134, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线东兰路站约700米', 700.0]
# 第47行：['我拿钥匙,双南两房!豪华装修,包车位物业,可长租', 13000, '整租', 0, '2室2厅', 2.0, 2.0, nan, 115, '朝南北', 1, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线虹梅路站约1092米', 1092.0]
# 第48行：['近漕河泾,人车分流,精装四房,虹梅路口', 22000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 139, '朝南北', 1, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距12号线虹梅路站约1092米', 1092.0]
# 第49行：['仅此一套,四房四卫 ,御璄大平层,双车位', 40000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 261, '朝南北', 1, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线东兰路站约668米', 668.0]
# 第50行：['协和双语!万源城一期3房带车位!12号线东兰路', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 116, '朝南北', 1, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线顾戴路站约682米', 682.0]
# 第51行：['万源城朗郡 新装修三房,大金空调带地暖,家电全配,包', 16500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 150, '朝南北', 1, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线顾戴路站约540米', 540.0]
# 第52行：['御璄大平层 双车位,家具家电齐全,双车位', 39000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 264, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线顾戴路站约775米', 775.0]
# 第53行：['尚居大三房,有车位,近实验西燎原', 13500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 140, '朝南北', 1, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约668米', 668.0]
# 第54行：['有车位,尚居沿河3房,可以长租,近西校协和世外', 12000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 140, '朝南北', 1, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约700米', 700.0]
# 第55行：['空房出租,带地下车位,装修清爽,近协和', 15000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 156, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线东兰路站约804米', 804.0]
# 第56行：['两梯两户,视野开阔装修干净清爽,包车位物业', 10000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 90, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线东兰路站约263米', 263.0]
# 第57行：['初次出租,电梯三房,近实验西校,装修保养好,位置安静', 11000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 121, '朝南', 0, '闵行-古美-望族新城', '闵行', '古美', '望族新城', '距12号线虹梅路站约598米', 598.0]
# 第58行：['御溪花园洋房,两层大露台!大,实用', 40000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 266, '朝南北', 1, '闵行-古美-万源城御溪公寓', '闵行', '古美', '万源城御溪公寓', '距12号线虹梅路站约562米', 562.0]
# 第59行：['近协和,人车分流,精装全配有地暖,包物业车位', 17000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 133, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线东兰路站约804米', 804.0]
# 第60行：['业主自主房 次出租 8米宽大横厅 包车位', 20000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 172, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线东兰路站约868米', 868.0]
# 第61行：['万源城御璄,230户型,高区景观楼层,豪华装修', 33000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 225, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线东兰路站约193米', 193.0]
# 第62行：['精装修,家具家电全新,出门口,可短租,带车位,拎包入', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南北', 1, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线东兰路站约429米', 429.0]
# 第63行：['近 科技绿洲 字节房补 一室拎包入住 12号线东兰路', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-祜欣公寓', '闵行', '古美', '祜欣公寓', '距12号线虹梅路站约301米', 301.0]
# 第64行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线虹梅路站约301米', 301.0]
# 第65行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线急', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 49, '朝南', 0, '闵行-古美-华一新城', '闵行', '古美', '华一新城', '距12号线东兰路站约804米', 804.0]
# 第66行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2999, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约785米', 785.0]
# 第67行：['近12号线,婚房首租,精装全配拎包入住,已空关', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线顾戴路站约665米', 665.0]
# 第68行：['漕河泾出门12号线,美食一条街,看房方便,可拎包入住', 2700, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线虹梅路站约781米', 781.0]
# 第69行：['刚刚挂牌!电梯大一房,业主自住装修,近漕河泾,可随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南北', 1, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线虹梅路站约562米', 562.0]
# 第70行：['九星苑,一房一厅 诚意出租,看房子随时,租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝北', 6, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约830米', 830.0]
# 第71行：['近12号东兰路 密码锁 随时可看 采光好 精装全配', 3100, '整租', 0, '1室2厅', 1.0, 2.0, nan, 41, '朝南', 0, '闵行-古美-和嘉公寓', '闵行', '古美', '和嘉公寓', '距12号线顾戴路站约855米', 855.0]
# 第72行：['12号线口精装修一房,近漕河泾,租金月付,看房随时,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距1号线莲花路站约894米', 894.0]
# 第73行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线虹莘路站约604米', 604.0]
# 第74行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 56, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线顾戴路站约374米', 374.0]
# 第75行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线东', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-东兰兴城惠兰苑', '闵行', '古美', '东兰兴城惠兰苑', '距12号线虹梅路站约301米', 301.0]
# 第76行：['莲花公寓出门12号线,近儿科医院!随时看房!租金月付', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-莲花公寓(闵行)', '闵行', '古美', '莲花公寓(闵行)', '距12号线东兰路站约616米', 616.0]
# 第77行：['新上好房,中间楼层,全明户型,近复旦儿科,近中庚南方', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-南方公寓', '闵行', '古美', '南方公寓', '距12号线东兰路站约868米', 868.0]
# 第78行：['近12号线,婚房首租,精装全配拎包入住,已空关', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-华梅花苑', '闵行', '古美', '华梅花苑', '距12号线东兰路站约787米', 787.0]
# 第79行：['华精装一房,12号线虹梅路站50米,漕河泾,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线东兰路站约386米', 386.0]
# 第80行：['中庚漫游城 平阳四街坊精装修一房 12号线顾戴路拎包', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 58, '朝南', 0, '闵行-古美-平阳四街坊', '闵行', '古美', '平阳四街坊', '距12号线顾戴路站约492米', 492.0]
# 第81行：['近12号线,精装修电梯一房,看房有钥匙,诚心出租好房', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距1号线莲花路站约653米', 653.0]
# 第82行：['晶杰苑精装一房,电梯高层景观好,商圈环绕交通便利,看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距1号线莲花路站约479米', 479.0]
# 第83行：['出门12号线虹莘路站,品质小区,精装大一房,拎包入住', 3000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南', 0, '闵行-古美-东苑半岛花园公寓', '闵行', '古美', '东苑半岛花园公寓', '距12号线东兰路站约429米', 429.0]
# 第84行：['近十二号线,近儿科医院 看房随时方便 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平阳二村', '闵行', '古美', '平阳二村', '距1号线莲花路站约894米', 894.0]
# 第85行：['中友嘉园 出门12号线虹梅路 旁边漕河泾 随时可看拎', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 50, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距1号线莲花路站约894米', 894.0]
# 第86行：['新出电梯一房,近12号线,紧临漕河泾,家具家电,随时', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距12号线顾戴路站约462米', 462.0]
# 第87行：['欧风花都 近漕河泾 近12号线东兰路 精装全配 拎包', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距1号线莲花路站约661米', 661.0]
# 第88行：['九星苑 龙茗路 随时可看 租金可月付 家电齐全', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线虹梅路站约1092米', 1092.0]
# 第89行：['古美罗阳1室东苑怡景园66.00平出租,电梯一房,全', 3200, '整租', 0, '1室2厅', 1.0, 2.0, nan, 57, '朝南', 0, '闵行-古美-东苑怡景园', '闵行', '古美', '东苑怡景园', '距12号线东兰路站约668米', 668.0]
# 第90行：['出门12号线东兰路 近漕河泾 看房随时方便 拎包入住', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平南三四村', '闵行', '古美', '平南三四村', '距12号线虹莘路站约823米', 823.0]
# 第91行：['现代精装电梯一房,复旦儿科医院,12号线,可月付房租', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南北', 1, '闵行-古美-江南星城一期', '闵行', '古美', '江南星城一期', '距12号线东兰路站约668米', 668.0]
# 第92行：['南方新村,莲花路站,城开,南方商城,拎包入住,随时看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-南方新村', '闵行', '古美', '南方新村', '距12号线顾戴路站约775米', 775.0]
# 第93行：['首租!出门1号线,精装一房,南北通透,南方商城', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 37, '朝南', 0, '闵行-古美-南方城', '闵行', '古美', '南方城', '距12号线东兰路站约700米', 700.0]
# 第94行：['装修3年精装电梯一房,出门龙茗路商业街,近12号线,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-东兰雅苑', '闵行', '古美', '东兰雅苑', '距1号线莲花路站约586米', 586.0]
# 第95行：['平南一村,精装大一房中间楼层采光好,交通便利,诚心出', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距12号线东兰路站约668米', 668.0]
# 第96行：['1号线.12号线精装一房一厅,适合居家白领,看房随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线顾戴路站约682米', 682.0]
# 第97行：['实拍!一号线口,电梯精装一房,中庚,租金可月付!', 2888, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线东兰路站约668米', 668.0]
# 第98行：['出门12号线 顾戴路 随时可住 拎包入住 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-新时代花园', '闵行', '古美', '新时代花园', '距12号线东兰路站约700米', 700.0]
# 第99行：['阳光美景城 近南方商城 锦江乐园 万源城 电梯三房', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 134, '朝南', 0, '闵行-古美-阳光美景城一期', '闵行', '古美', '阳光美景城一期', '距12号线顾戴路站约855米', 855.0]
# 第100行：['东苑古龙尚居,精装修3房,带车位,靠西校世外,有钥匙', 13000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 147, '朝南', 0, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线顾戴路站约775米', 775.0]
# 第101行：['万源城朗郡,11层,双南两房,精装修,包车位物业!', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 114, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线虹梅路站约1092米', 1092.0]
# 第102行：['平吉二村,精装一房,初次出租,全新家电,拎包入住价格', 3300, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-平吉二村', '闵行', '古美', '平吉二村', '距12号线顾戴路站约682米', 682.0]
# 第103行：['空房出租,带地下车位,装修清爽,近协和', 15000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 156, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线顾戴路站约682米', 682.0]
# 第104行：['初次出租,万源城双南两房,带车位,看房方便,近12号', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 109, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线顾戴路站约775米', 775.0]
# 第105行：['御璄大平层 双车位,家具家电齐全,双车位', 39000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 264, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线顾戴路站约682米', 682.0]
# 第106行：['上海花园洋房,初次出租!精装带地暖,停车方便', 18000, '整租', 0, '5室3厅', 5.0, 3.0, nan, 199, '朝南', 0, '闵行-古美-上海花园', '闵行', '古美', '上海花园', '距12号线东兰路站约700米', 700.0]
# 第107行：['初次挂牌,全新家具,两房朝南,随时可看', 11000, '整租', 0, '2室2厅', 2.0, 2.0, nan, 116, '朝南北', 1, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线东兰路站约804米', 804.0]
# 第108行：['尚郡精装三房,干净清爽!包车位物业,看房提前约', 10000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 89, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线顾戴路站约374米', 374.0]
# 第109行：['我拿钥匙,双南两房!豪华装修,包车位物业,可长租', 13000, '整租', 0, '2室2厅', 2.0, 2.0, nan, 115, '朝南北', 1, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线顾戴路站约785米', 785.0]
# 第110行：['蔚蓝大3房,电梯高层,价格比较实惠,业主急租', 11000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 128, '朝南', 0, '闵行-古美-蔚蓝城市花园', '闵行', '古美', '蔚蓝城市花园', '距12号线东兰路站约193米', 193.0]
# 第111行：['近协和,大平层四房,豪华装修,业主为人和善', 35000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 228, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线东兰路站约263米', 263.0]
# 第112行：['精装上叠别墅,南北大露台!有产权车位,随时可看', 18000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 167, '朝南北', 1, '闵行-古美-新时代景庭', '闵行', '古美', '新时代景庭', '距12号线东兰路站约429米', 429.0]
# 第113行：['万源城三房,有地暖,带车位,整体还可以,来看看?', 11500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 128, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距1号线莲花路站约894米', 894.0]
# 第114行：['温馨舒适,平层四房,中空带地暖,包车位物业', 22000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 237, '朝南', 0, '闵行-古美-金汇豪庭', '闵行', '古美', '金汇豪庭', '距1号线莲花路站约894米', 894.0]
# 第115行：['视野很好!人车分流三房,空房可长租,家具可配!', 15000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 133, '朝南', 0, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线顾戴路站约830米', 830.0]
# 第116行：['有车位,尚居沿河3房,可以长租,近西校协和世外', 12000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 140, '朝南北', 1, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约787米', 787.0]
# 第117行：['万源城尚郡,精装两房,带车位,楼层位置好', 8300, '整租', 0, '2室2厅', 2.0, 2.0, nan, 72, '朝南', 0, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线虹梅路站约598米', 598.0]
# 第118行：['新挂牌,边套3房出租,装修干净清爽,包车位物业', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 90, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线东兰路站约429米', 429.0]
# 第119行：['近协和,人车分流,精装全配有地暖,包物业车位', 17000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 133, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线顾戴路站约855米', 855.0]
# 第120行：['两梯两户,视野开阔装修干净清爽,包车位物业', 10000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 90, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线虹梅路站约781米', 781.0]
# 第121行：['万源城御璄,230户型,高区景观楼层,豪华装修', 33000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 225, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线虹梅路站约301米', 301.0]
# 第122行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线东', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-东兰兴城惠兰苑', '闵行', '古美', '东兰兴城惠兰苑', '距12号线虹梅路站约301米', 301.0]
# 第123行：['近十二号线,近儿科医院 看房随时方便 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平阳二村', '闵行', '古美', '平阳二村', '距12号线虹梅路站约301米', 301.0]
# 第124行：['莲花公寓出门12号线,近儿科医院!随时看房!租金月付', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-莲花公寓(闵行)', '闵行', '古美', '莲花公寓(闵行)', '距12号线东兰路站约616米', 616.0]
# 第125行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线东兰路站约386米', 386.0]
# 第126行：['近12号东兰路 密码锁 随时可看 采光好 精装全配', 3100, '整租', 0, '1室2厅', 1.0, 2.0, nan, 41, '朝南', 0, '闵行-古美-和嘉公寓', '闵行', '古美', '和嘉公寓', '距12号线东兰路站约804米', 804.0]
# 第127行：['近 科技绿洲 字节房补 一室拎包入住 12号线东兰路', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-祜欣公寓', '闵行', '古美', '祜欣公寓', '距12号线顾戴路站约492米', 492.0]
# 第128行：['12号线口精装修一房,近漕河泾,租金月付,看房随时,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距12号线虹莘路站约604米', 604.0]
# 第129行：['1号线.12号线精装一房一厅,适合居家白领,看房随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线东兰路站约868米', 868.0]
# 第130行：['实拍!一号线口,电梯精装一房,中庚,租金可月付!', 2888, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距1号线莲花路站约479米', 479.0]
# 第131行：['中庚漫游城 平阳四街坊精装修一房 12号线顾戴路拎包', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 58, '朝南', 0, '闵行-古美-平阳四街坊', '闵行', '古美', '平阳四街坊', '距1号线莲花路站约653米', 653.0]
# 第132行：['九星苑,一房一厅 诚意出租,看房子随时,租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝北', 6, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线东兰路站约868米', 868.0]
# 第133行：['古美罗阳1室东苑怡景园66.00平出租,电梯一房,全', 3200, '整租', 0, '1室2厅', 1.0, 2.0, nan, 57, '朝南', 0, '闵行-古美-东苑怡景园', '闵行', '古美', '东苑怡景园', '距12号线东兰路站约804米', 804.0]
# 第134行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线急', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 49, '朝南', 0, '闵行-古美-华一新城', '闵行', '古美', '华一新城', '距12号线顾戴路站约665米', 665.0]
# 第135行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2999, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距1号线莲花路站约894米', 894.0]
# 第136行：['平南一村,精装大一房中间楼层采光好,交通便利,诚心出', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距12号线虹梅路站约562米', 562.0]
# 第137行：['近12号线,精装修电梯一房,看房有钥匙,诚心出租好房', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线虹梅路站约562米', 562.0]
# 第138行：['近12号线,婚房首租,精装全配拎包入住,已空关', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-华梅花苑', '闵行', '古美', '华梅花苑', '距1号线莲花路站约661米', 661.0]
# 第139行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 56, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线顾戴路站约462米', 462.0]
# 第140行：['中友嘉园 出门12号线虹梅路 旁边漕河泾 随时可看拎', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 50, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线东兰路站约668米', 668.0]
# 第141行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线虹梅路站约1092米', 1092.0]
# 第142行：['新出电梯一房,近12号线,紧临漕河泾,家具家电,随时', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距12号线虹莘路站约823米', 823.0]
# 第143行：['出门12号线东兰路 近漕河泾 看房随时方便 拎包入住', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平南三四村', '闵行', '古美', '平南三四村', '距12号线顾戴路站约775米', 775.0]
# 第144行：['漕河泾出门12号线,美食一条街,看房方便,可拎包入住', 2700, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线顾戴路站约775米', 775.0]
# 第145行：['现代精装电梯一房,复旦儿科医院,12号线,可月付房租', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南北', 1, '闵行-古美-江南星城一期', '闵行', '古美', '江南星城一期', '距12号线虹梅路站约301米', 301.0]
# 第146行：['出门12号线虹莘路站,品质小区,精装大一房,拎包入住', 3000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南', 0, '闵行-古美-东苑半岛花园公寓', '闵行', '古美', '东苑半岛花园公寓', '距12号线虹梅路站约1092米', 1092.0]
# 第147行：['欧风花都 近漕河泾 近12号线东兰路 精装全配 拎包', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线东兰路站约668米', 668.0]
# 第148行：['九星苑 龙茗路 随时可看 租金可月付 家电齐全', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约682米', 682.0]
# 第149行：['首租!出门1号线,精装一房,南北通透,南方商城', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 37, '朝南', 0, '闵行-古美-南方城', '闵行', '古美', '南方城', '距12号线东兰路站约668米', 668.0]
# 第150行：['南方新村,莲花路站,城开,南方商城,拎包入住,随时看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-南方新村', '闵行', '古美', '南方新村', '距12号线虹梅路站约1092米', 1092.0]
# 第151行：['刚刚挂牌!电梯大一房,业主自住装修,近漕河泾,可随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南北', 1, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线顾戴路站约855米', 855.0]
# 第152行：['精装修,家具家电全新,出门口,可短租,带车位,拎包入', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南北', 1, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线东兰路站约616米', 616.0]
# 第153行：['新上好房,中间楼层,全明户型,近复旦儿科,近中庚南方', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-南方公寓', '闵行', '古美', '南方公寓', '距12号线顾戴路站约855米', 855.0]
# 第154行：['晶杰苑精装一房,电梯高层景观好,商圈环绕交通便利,看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线虹梅路站约1092米', 1092.0]
# 第155行：['近12号线,婚房首租,精装全配拎包入住,已空关', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线东兰路站约700米', 700.0]
# 第156行：['装修3年精装电梯一房,出门龙茗路商业街,近12号线,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-东兰雅苑', '闵行', '古美', '东兰雅苑', '距12号线顾戴路站约540米', 540.0]
# 第157行：['华精装一房,12号线虹梅路站50米,漕河泾,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线顾戴路站约855米', 855.0]
# 第158行：['阳光美景城 近南方商城 锦江乐园 万源城 电梯三房', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 134, '朝南', 0, '闵行-古美-阳光美景城一期', '闵行', '古美', '阳光美景城一期', '距12号线顾戴路站约775米', 775.0]
# 第159行：['出门12号线 顾戴路 随时可住 拎包入住 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-新时代花园', '闵行', '古美', '新时代花园', '距1号线莲花路站约586米', 586.0]
# 第160行：['万源城朗郡,11层,双南两房,精装修,包车位物业!', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 114, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线东兰路站约700米', 700.0]
# 第161行：['东苑古龙尚居,精装修3房,带车位,靠西校世外,有钥匙', 13000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 147, '朝南', 0, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约804米', 804.0]
# 第162行：['平吉二村,精装一房,初次出租,全新家电,拎包入住价格', 3300, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-平吉二村', '闵行', '古美', '平吉二村', '距12号线东兰路站约263米', 263.0]
# 第163行：['初次出租,万源城双南两房,带车位,看房方便,近12号', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 109, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线虹梅路站约598米', 598.0]
# 第164行：['视野很好!人车分流三房,空房可长租,家具可配!', 15000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 133, '朝南', 0, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线虹梅路站约562米', 562.0]
# 第165行：['口,豪装四房,近漕河泾随时可以看', 23000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 161, '朝南北', 1, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线东兰路站约804米', 804.0]
# 第166行：['钥匙房,初次出租,精装带地暖,干净清爽,包物业车位,', 12500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 138, '朝南', 0, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约868米', 868.0]
# 第167行：['干净清爽,实地看很舒适!高层大三房,带车位', 16000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 147, '朝南北', 1, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线东兰路站约193米', 193.0]
# 第168行：['新挂牌,边套3房出租,装修干净清爽,包车位物业', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 90, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线东兰路站约429米', 429.0]
# 第169行：['近12号线 双南两室,拎包入住 带车位', 13800, '整租', 0, '2室2厅', 2.0, 2.0, nan, 122, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线虹梅路站约301米', 301.0]
# 第170行：['适合年轻人,精装两房,带两卫,温馨舒适,近漕河泾', 6600, '整租', 0, '2室2厅', 2.0, 2.0, nan, 88, '朝南北', 1, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线虹梅路站约301米', 301.0]
# 第171行：['万源城三房,有地暖,带车位,整体还可以,来看看?', 11500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 128, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线东兰路站约804米', 804.0]
# 第172行：['近漕河泾,人车分流,精装四房,虹梅路口', 22000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 139, '朝南北', 1, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距12号线顾戴路站约785米', 785.0]
# 第173行：['初次出租,一楼,干净清爽 安静 陪读好房', 7700, '整租', 0, '2室2厅', 2.0, 2.0, nan, 93, '朝南', 0, '闵行-古美-新时代景庭', '闵行', '古美', '新时代景庭', '距12号线顾戴路站约665米', 665.0]
# 第174行：['协和双语!精装万源城一期2房带车位', 9000, '整租', 0, '2室2厅', 2.0, 2.0, nan, 96, '朝南北', 1, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线虹梅路站约781米', 781.0]
# 第175行：['有车位,尚居沿河3房,可以长租,近西校协和世外', 12000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 140, '朝南北', 1, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线虹梅路站约562米', 562.0]
# 第176行：['御璄大平层 双车位,家具家电齐全,双车位', 39000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 264, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线顾戴路站约830米', 830.0]
# 第177行：['御溪花园洋房,两层大露台!大,实用', 40000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 266, '朝南北', 1, '闵行-古美-万源城御溪公寓', '闵行', '古美', '万源城御溪公寓', '距12号线顾戴路站约855米', 855.0]
# 第178行：['协和双语!万源城一期3房带车位!12号线东兰路', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 116, '朝南北', 1, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距1号线莲花路站约894米', 894.0]
# 第179行：['人车分流,带双车位!视野好,空房可长租', 15500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 134, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线虹莘路站约604米', 604.0]
# 第180行：['上海花园洋房,初次出租!精装带地暖,停车方便', 18000, '整租', 0, '5室3厅', 5.0, 3.0, nan, 199, '朝南', 0, '闵行-古美-上海花园', '闵行', '古美', '上海花园', '距12号线顾戴路站约374米', 374.0]
# 第181行：['万源城御璄,230户型,高区景观楼层,豪华装修', 33000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 225, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线虹梅路站约301米', 301.0]
# 第182行：['精装修,家具家电全新,出门口,可短租,带车位,拎包入', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南北', 1, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线东兰路站约616米', 616.0]
# 第183行：['近 科技绿洲 字节房补 一室拎包入住 12号线东兰路', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-祜欣公寓', '闵行', '古美', '祜欣公寓', '距12号线东兰路站约868米', 868.0]
# 第184行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线东兰路站约787米', 787.0]
# 第185行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线急', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 49, '朝南', 0, '闵行-古美-华一新城', '闵行', '古美', '华一新城', '距12号线东兰路站约386米', 386.0]
# 第186行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2999, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约492米', 492.0]
# 第187行：['近12号线,婚房首租,精装全配拎包入住,已空关', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距1号线莲花路站约653米', 653.0]
# 第188行：['漕河泾出门12号线,美食一条街,看房方便,可拎包入住', 2700, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距1号线莲花路站约479米', 479.0]
# 第189行：['刚刚挂牌!电梯大一房,业主自住装修,近漕河泾,可随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南北', 1, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线东兰路站约429米', 429.0]
# 第190行：['九星苑,一房一厅 诚意出租,看房子随时,租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝北', 6, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距1号线莲花路站约894米', 894.0]
# 第191行：['近12号东兰路 密码锁 随时可看 采光好 精装全配', 3100, '整租', 0, '1室2厅', 1.0, 2.0, nan, 41, '朝南', 0, '闵行-古美-和嘉公寓', '闵行', '古美', '和嘉公寓', '距1号线莲花路站约894米', 894.0]
# 第192行：['12号线口精装修一房,近漕河泾,租金月付,看房随时,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距12号线顾戴路站约462米', 462.0]
# 第193行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距1号线莲花路站约661米', 661.0]
# 第194行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 56, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线虹梅路站约1092米', 1092.0]
# 第195行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线东', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-东兰兴城惠兰苑', '闵行', '古美', '东兰兴城惠兰苑', '距12号线东兰路站约668米', 668.0]
# 第196行：['莲花公寓出门12号线,近儿科医院!随时看房!租金月付', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-莲花公寓(闵行)', '闵行', '古美', '莲花公寓(闵行)', '距12号线虹莘路站约823米', 823.0]
# 第197行：['新上好房,中间楼层,全明户型,近复旦儿科,近中庚南方', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-南方公寓', '闵行', '古美', '南方公寓', '距12号线东兰路站约668米', 668.0]
# 第198行：['近12号线,婚房首租,精装全配拎包入住,已空关', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-华梅花苑', '闵行', '古美', '华梅花苑', '距12号线顾戴路站约775米', 775.0]
# 第199行：['华精装一房,12号线虹梅路站50米,漕河泾,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线东兰路站约700米', 700.0]
# 第200行：['中庚漫游城 平阳四街坊精装修一房 12号线顾戴路拎包', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 58, '朝南', 0, '闵行-古美-平阳四街坊', '闵行', '古美', '平阳四街坊', '距1号线莲花路站约586米', 586.0]
# 第201行：['近12号线,精装修电梯一房,看房有钥匙,诚心出租好房', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线东兰路站约668米', 668.0]
# 第202行：['晶杰苑精装一房,电梯高层景观好,商圈环绕交通便利,看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线顾戴路站约682米', 682.0]
# 第203行：['出门12号线虹莘路站,品质小区,精装大一房,拎包入住', 3000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南', 0, '闵行-古美-东苑半岛花园公寓', '闵行', '古美', '东苑半岛花园公寓', '距12号线东兰路站约668米', 668.0]
# 第204行：['近十二号线,近儿科医院 看房随时方便 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平阳二村', '闵行', '古美', '平阳二村', '距12号线东兰路站约700米', 700.0]
# 第205行：['中友嘉园 出门12号线虹梅路 旁边漕河泾 随时可看拎', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 50, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线顾戴路站约855米', 855.0]
# 第206行：['新出电梯一房,近12号线,紧临漕河泾,家具家电,随时', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距12号线顾戴路站约775米', 775.0]
# 第207行：['欧风花都 近漕河泾 近12号线东兰路 精装全配 拎包', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线虹梅路站约1092米', 1092.0]
# 第208行：['九星苑 龙茗路 随时可看 租金可月付 家电齐全', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约682米', 682.0]
# 第209行：['古美罗阳1室东苑怡景园66.00平出租,电梯一房,全', 3200, '整租', 0, '1室2厅', 1.0, 2.0, nan, 57, '朝南', 0, '闵行-古美-东苑怡景园', '闵行', '古美', '东苑怡景园', '距12号线顾戴路站约682米', 682.0]
# 第210行：['出门12号线东兰路 近漕河泾 看房随时方便 拎包入住', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平南三四村', '闵行', '古美', '平南三四村', '距12号线顾戴路站约775米', 775.0]
# 第211行：['现代精装电梯一房,复旦儿科医院,12号线,可月付房租', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南北', 1, '闵行-古美-江南星城一期', '闵行', '古美', '江南星城一期', '距12号线顾戴路站约682米', 682.0]
# 第212行：['南方新村,莲花路站,城开,南方商城,拎包入住,随时看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-南方新村', '闵行', '古美', '南方新村', '距12号线东兰路站约700米', 700.0]
# 第213行：['首租!出门1号线,精装一房,南北通透,南方商城', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 37, '朝南', 0, '闵行-古美-南方城', '闵行', '古美', '南方城', '距12号线东兰路站约804米', 804.0]
# 第214行：['装修3年精装电梯一房,出门龙茗路商业街,近12号线,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-东兰雅苑', '闵行', '古美', '东兰雅苑', '距12号线东兰路站约263米', 263.0]
# 第215行：['平南一村,精装大一房中间楼层采光好,交通便利,诚心出', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距12号线虹梅路站约598米', 598.0]
# 第216行：['1号线.12号线精装一房一厅,适合居家白领,看房随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线虹梅路站约562米', 562.0]
# 第217行：['实拍!一号线口,电梯精装一房,中庚,租金可月付!', 2888, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线东兰路站约804米', 804.0]
# 第218行：['出门12号线 顾戴路 随时可住 拎包入住 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-新时代花园', '闵行', '古美', '新时代花园', '距12号线东兰路站约868米', 868.0]
# 第219行：['阳光美景城 近南方商城 锦江乐园 万源城 电梯三房', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 134, '朝南', 0, '闵行-古美-阳光美景城一期', '闵行', '古美', '阳光美景城一期', '距12号线东兰路站约193米', 193.0]
# 第220行：['东苑古龙尚居,精装修3房,带车位,靠西校世外,有钥匙', 13000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 147, '朝南', 0, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约429米', 429.0]
# 第221行：['万源城朗郡,11层,双南两房,精装修,包车位物业!', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 114, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线虹梅路站约301米', 301.0]
# 第222行：['平吉二村,精装一房,初次出租,全新家电,拎包入住价格', 3300, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-平吉二村', '闵行', '古美', '平吉二村', '距12号线虹梅路站约301米', 301.0]
# 第223行：['空房出租,带地下车位,装修清爽,近协和', 15000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 156, '朝南', 0, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线东兰路站约804米', 804.0]
# 第224行：['初次出租,万源城双南两房,带车位,看房方便,近12号', 11500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 109, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线顾戴路站约785米', 785.0]
# 第225行：['御璄大平层 双车位,家具家电齐全,双车位', 39000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 264, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线顾戴路站约665米', 665.0]
# 第226行：['上海花园洋房,初次出租!精装带地暖,停车方便', 18000, '整租', 0, '5室3厅', 5.0, 3.0, nan, 199, '朝南', 0, '闵行-古美-上海花园', '闵行', '古美', '上海花园', '距12号线虹梅路站约781米', 781.0]
# 第227行：['初次挂牌,全新家具,两房朝南,随时可看', 11000, '整租', 0, '2室2厅', 2.0, 2.0, nan, 116, '朝南北', 1, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线虹梅路站约562米', 562.0]
# 第228行：['尚郡精装三房,干净清爽!包车位物业,看房提前约', 10000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 89, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线顾戴路站约830米', 830.0]
# 第229行：['我拿钥匙,双南两房!豪华装修,包车位物业,可长租', 13000, '整租', 0, '2室2厅', 2.0, 2.0, nan, 115, '朝南北', 1, '闵行-古美-万源城朗郡', '闵行', '古美', '万源城朗郡', '距12号线顾戴路站约855米', 855.0]
# 第230行：['蔚蓝大3房,电梯高层,价格比较实惠,业主急租', 11000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 128, '朝南', 0, '闵行-古美-蔚蓝城市花园', '闵行', '古美', '蔚蓝城市花园', '距1号线莲花路站约894米', 894.0]
# 第231行：['近协和,大平层四房,豪华装修,业主为人和善', 35000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 228, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线虹莘路站约604米', 604.0]
# 第232行：['精装上叠别墅,南北大露台!有产权车位,随时可看', 18000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 167, '朝南北', 1, '闵行-古美-新时代景庭', '闵行', '古美', '新时代景庭', '距12号线顾戴路站约374米', 374.0]
# 第233行：['万源城三房,有地暖,带车位,整体还可以,来看看?', 11500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 128, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线虹梅路站约301米', 301.0]
# 第234行：['温馨舒适,平层四房,中空带地暖,包车位物业', 22000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 237, '朝南', 0, '闵行-古美-金汇豪庭', '闵行', '古美', '金汇豪庭', '距12号线东兰路站约616米', 616.0]
# 第235行：['视野很好!人车分流三房,空房可长租,家具可配!', 15000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 133, '朝南', 0, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距12号线东兰路站约868米', 868.0]
# 第236行：['有车位,尚居沿河3房,可以长租,近西校协和世外', 12000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 140, '朝南北', 1, '闵行-古美-东苑古龙城', '闵行', '古美', '东苑古龙城', '距12号线东兰路站约787米', 787.0]
# 第237行：['万源城尚郡,精装两房,带车位,楼层位置好', 8300, '整租', 0, '2室2厅', 2.0, 2.0, nan, 72, '朝南', 0, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线东兰路站约386米', 386.0]
# 第238行：['新挂牌,边套3房出租,装修干净清爽,包车位物业', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 90, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距12号线顾戴路站约492米', 492.0]
# 第239行：['近协和,人车分流,精装全配有地暖,包物业车位', 17000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 133, '朝南北', 1, '闵行-古美-万源城逸郡', '闵行', '古美', '万源城逸郡', '距1号线莲花路站约653米', 653.0]
# 第240行：['两梯两户,视野开阔装修干净清爽,包车位物业', 10000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 90, '朝南北', 1, '闵行-古美-万源城尚郡', '闵行', '古美', '万源城尚郡', '距1号线莲花路站约479米', 479.0]
# 第241行：['万源城御璄,230户型,高区景观楼层,豪华装修', 33000, '整租', 0, '4室2厅', 4.0, 2.0, nan, 225, '朝南', 0, '闵行-古美-万源城御璄', '闵行', '古美', '万源城御璄', '距12号线东兰路站约429米', 429.0]
# 第242行：['精装修,家具家电全新,出门口,可短租,带车位,拎包入', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南北', 1, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距1号线莲花路站约894米', 894.0]
# 第243行：['近 科技绿洲 字节房补 一室拎包入住 12号线东兰路', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-祜欣公寓', '闵行', '古美', '祜欣公寓', '距1号线莲花路站约894米', 894.0]
# 第244行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约462米', 462.0]
# 第245行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线急', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 49, '朝南', 0, '闵行-古美-华一新城', '闵行', '古美', '华一新城', '距1号线莲花路站约661米', 661.0]
# 第246行：['近12号线,近漕河泾,精装全配,随时看住,环境舒适,', 2999, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线虹梅路站约1092米', 1092.0]
# 第247行：['近12号线,婚房首租,精装全配拎包入住,已空关', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线东兰路站约668米', 668.0]
# 第248行：['漕河泾出门12号线,美食一条街,看房方便,可拎包入住', 2700, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-东兰兴城东兰新村', '闵行', '古美', '东兰兴城东兰新村', '距12号线虹莘路站约823米', 823.0]
# 第249行：['刚刚挂牌!电梯大一房,业主自住装修,近漕河泾,可随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南北', 1, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线东兰路站约668米', 668.0]
# 第250行：['九星苑,一房一厅 诚意出租,看房子随时,租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝北', 6, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线顾戴路站约775米', 775.0]
# 第251行：['近12号东兰路 密码锁 随时可看 采光好 精装全配', 3100, '整租', 0, '1室2厅', 1.0, 2.0, nan, 41, '朝南', 0, '闵行-古美-和嘉公寓', '闵行', '古美', '和嘉公寓', '距12号线东兰路站约700米', 700.0]
# 第252行：['12号线口精装修一房,近漕河泾,租金月付,看房随时,', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距1号线莲花路站约586米', 586.0]
# 第253行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线东兰路站约668米', 668.0]
# 第254行：['中友嘉园,电梯高层,精装修,面前12号线,出行便捷,', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 56, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线顾戴路站约682米', 682.0]
# 第255行：['近 科技绿洲 字节房补 一室户 拎包入住 12号线东', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-东兰兴城惠兰苑', '闵行', '古美', '东兰兴城惠兰苑', '距12号线东兰路站约668米', 668.0]
# 第256行：['莲花公寓出门12号线,近儿科医院!随时看房!租金月付', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '闵行-古美-莲花公寓(闵行)', '闵行', '古美', '莲花公寓(闵行)', '距12号线东兰路站约700米', 700.0]
# 第257行：['新上好房,中间楼层,全明户型,近复旦儿科,近中庚南方', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-南方公寓', '闵行', '古美', '南方公寓', '距12号线顾戴路站约855米', 855.0]
# 第258行：['近12号线,婚房首租,精装全配拎包入住,已空关', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 43, '朝南', 0, '闵行-古美-华梅花苑', '闵行', '古美', '华梅花苑', '距12号线顾戴路站约775米', 775.0]
# 第259行：['华精装一房,12号线虹梅路站50米,漕河泾,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '闵行-古美-同济华城', '闵行', '古美', '同济华城', '距12号线虹梅路站约1092米', 1092.0]
# 第260行：['中庚漫游城 平阳四街坊精装修一房 12号线顾戴路拎包', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 58, '朝南', 0, '闵行-古美-平阳四街坊', '闵行', '古美', '平阳四街坊', '距12号线顾戴路站约682米', 682.0]
# 第261行：['近12号线,精装修电梯一房,看房有钥匙,诚心出租好房', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-万源城E1', '闵行', '古美', '万源城E1', '距12号线顾戴路站约682米', 682.0]
# 第262行：['晶杰苑精装一房,电梯高层景观好,商圈环绕交通便利,看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线顾戴路站约775米', 775.0]
# 第263行：['出门12号线虹莘路站,品质小区,精装大一房,拎包入住', 3000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南', 0, '闵行-古美-东苑半岛花园公寓', '闵行', '古美', '东苑半岛花园公寓', '距12号线顾戴路站约682米', 682.0]
# 第264行：['近十二号线,近儿科医院 看房随时方便 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平阳二村', '闵行', '古美', '平阳二村', '距12号线东兰路站约700米', 700.0]
# 第265行：['中友嘉园 出门12号线虹梅路 旁边漕河泾 随时可看拎', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 50, '朝南', 0, '闵行-古美-中友嘉园', '闵行', '古美', '中友嘉园', '距12号线东兰路站约804米', 804.0]
# 第266行：['新出电梯一房,近12号线,紧临漕河泾,家具家电,随时', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-同济融创玫瑰公馆', '闵行', '古美', '同济融创玫瑰公馆', '距12号线顾戴路站约374米', 374.0]
# 第267行：['欧风花都 近漕河泾 近12号线东兰路 精装全配 拎包', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-欧风花都', '闵行', '古美', '欧风花都', '距12号线顾戴路站约785米', 785.0]
# 第268行：['九星苑 龙茗路 随时可看 租金可月付 家电齐全', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 47, '朝南', 0, '闵行-古美-九星苑', '闵行', '古美', '九星苑', '距12号线东兰路站约193米', 193.0]
# 第269行：['古美罗阳1室东苑怡景园66.00平出租,电梯一房,全', 3200, '整租', 0, '1室2厅', 1.0, 2.0, nan, 57, '朝南', 0, '闵行-古美-东苑怡景园', '闵行', '古美', '东苑怡景园', '距12号线东兰路站约263米', 263.0]
# 第270行：['出门12号线东兰路 近漕河泾 看房随时方便 拎包入住', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-平南三四村', '闵行', '古美', '平南三四村', '距12号线东兰路站约429米', 429.0]
# 第271行：['现代精装电梯一房,复旦儿科医院,12号线,可月付房租', 2900, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南北', 1, '闵行-古美-江南星城一期', '闵行', '古美', '江南星城一期', '距1号线莲花路站约894米', 894.0]
# 第272行：['南方新村,莲花路站,城开,南方商城,拎包入住,随时看', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 46, '朝南', 0, '闵行-古美-南方新村', '闵行', '古美', '南方新村', '距1号线莲花路站约894米', 894.0]
# 第273行：['首租!出门1号线,精装一房,南北通透,南方商城', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 37, '朝南', 0, '闵行-古美-南方城', '闵行', '古美', '南方城', '距12号线顾戴路站约830米', 830.0]
# 第274行：['装修3年精装电梯一房,出门龙茗路商业街,近12号线,', 3100, '整租', 0, '1室1厅', 1.0, 1.0, nan, 44, '朝南北', 1, '闵行-古美-东兰雅苑', '闵行', '古美', '东兰雅苑', '距12号线东兰路站约787米', 787.0]
# 第275行：['平南一村,精装大一房中间楼层采光好,交通便利,诚心出', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 39, '朝南', 0, '闵行-古美-平南一村', '闵行', '古美', '平南一村', '距12号线虹梅路站约598米', 598.0]
# 第276行：['1号线.12号线精装一房一厅,适合居家白领,看房随时', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南北', 1, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线东兰路站约429米', 429.0]
# 第277行：['实拍!一号线口,电梯精装一房,中庚,租金可月付!', 2888, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-晶杰苑', '闵行', '古美', '晶杰苑', '距12号线顾戴路站约855米', 855.0]
# 第278行：['出门12号线 顾戴路 随时可住 拎包入住 租金可月付', 3200, '整租', 0, '1室1厅', 1.0, 1.0, nan, 41, '朝南', 0, '闵行-古美-新时代花园', '闵行', '古美', '新时代花园', '距12号线虹梅路站约781米', 781.0]
# 第279行：['阳光美景城 近南方商城 锦江乐园 万源城 电梯三房', 9500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 134, '朝南', 0, '闵行-古美-阳光美景城一期', '闵行', '古美', '阳光美景城一期', '距12号线虹梅路站约301米', 301.0]
# ...
# 第4074行：['汤臣二期 原始南北通透主卧精装修一室户 近金科路地铁', 2500, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4075行：['可短租!毕业季特价 包水网费 非合租 独立厨卫近地铁', 1800, '合租主卧', 1, '2户合租', nan, nan, 2.0, 9, '朝南', 0, '浦东-张江-玉兰香苑二期', '浦东', '张江', '玉兰香苑二期', '距13号线张江路站约771米', 771.0]
# 第4076行：['可月付可短租,近2号线广兰路站,亚芯科技园,微电子港', 1450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 12, '朝南', 0, '浦东-张江-张江汤臣豪园一期', '浦东', '张江', '张江汤臣豪园一期', '距2号线张江高科站约219米', 219.0]
# 第4077行：['可月付可短租,近2号线张江高科站,张江微电子港,浦软', 1450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 12, '朝南', 0, '浦东-张江-张江汤臣豪园一期', '浦东', '张江', '张江汤臣豪园一期', '距2号线张江高科站约219米', 219.0]
# 第4078行：['汤臣豪园 步行金科路地铁只需5临近浦东软件园长泰广', 2500, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4079行：['特价优选,近2号线地铁,近软件园,集电港,国创中心,', 1000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 10, '朝南北', 1, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4080行：['古桐三村近二号站 张江园区 精装修一居室 看房随时有', 1990, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南北', 1, '浦东-张江-古桐三村', '浦东', '张江', '古桐三村', nan, nan]
# 第4081行：['张江纳仕国际社区碧云 1室2厅1卫 精装修 5581', 5581, '整租', 0, '1室2厅', 1.0, 2.0, nan, 98, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4082行：['国企张江集团 三房两卫 民水民电 方便停车 无看房费', 7200, '整租', 0, '3室1厅', 3.0, 1.0, nan, 105, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4083行：['近2号线金科路,张江高科,浦软大厦精装主卧一居室独厨', 1500, '合租单间', 2, '3户合租', nan, nan, 3.0, 45, '朝南', 0, '浦东-张江-申源苑', '浦东', '张江', '申源苑', '距2号线广兰路站约936米', 936.0]
# 第4084行：['近金科路和广兰路地铁 软件园 汇智 长泰 朝南一室户', 1000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-贝越佳园北区', '浦东', '张江', '贝越佳园北区', '距2号线广兰路站约1015米', 1015.0]
# 第4085行：['近金科路 张江新苑朝南一居室 配置齐全 干净清爽 随', 2200, '整租', 0, '1室0厅', 1.0, 0.0, nan, 40, '朝南', 0, '浦东-张江-张江新苑', '浦东', '张江', '张江新苑', nan, nan]
# 第4086行：['近2号线广兰路 全独立一室户 近展想 光大 国创 集', 1800, '合租主卧', 1, '2户合租', nan, nan, 2.0, 50, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4087行：['张江纳什大两房 民水电 通燃气!拎包入住', 6500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 100, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4088行：['无任何费用!!!靠近张江科技园区,长泰广场 采光好拎', 2000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4089行：['张江纳仕国际社区碧云 1室2厅1卫 精装修 5581', 5581, '整租', 0, '1室2厅', 1.0, 2.0, nan, 98, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4090行：['玉兰香苑二期独立一室户,近张衡路张江药谷软件押一付一', 1400, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-玉兰香苑', '浦东', '张江', '玉兰香苑', nan, nan]
# 第4091行：['二号线广兰路有轨沿线,阳光花城,精装一房,精装全配,', 2600, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4092行：['近集电港,展想广场,亚芯科技园,星创科技广场等精装一', 1700, '合租主卧', 1, '2户合租', nan, nan, 2.0, 20, '朝南', 0, '浦东-张江-兰沁苑', '浦东', '张江', '兰沁苑', '距2号线广兰路站约673米', 673.0]
# 第4093行：['2号线金科路站汤臣三期近长泰广场浦东软件园药谷,可短', 1400, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-张江汤臣豪园三期', '浦东', '张江', '张江汤臣豪园三期', '距2号线金科路站约736米', 736.0]
# 第4094行：['2号线金科路站古桐六村,近长泰广场浦东软件园,押一付', 1000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 8, '朝南', 0, '浦东-张江-蕉丽新村', '浦东', '张江', '蕉丽新村', '距2号线金科路站约1066米', 1066.0]
# 第4095行：['2号线广兰路0距离 展讯中心 集电港软件园 精装全配', 2300, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4096行：['张江纳什大两房 民水电 通燃气!拎包入住', 6500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 100, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4097行：['近2号线!可押一付一!可养宠物!软件园 药谷 精装独', 1490, '合租主卧', 1, '2户合租', nan, nan, 2.0, 9, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4098行：['无任何费用!!!靠近张江科技园区,长泰广场 采光好拎', 2700, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4099行：['2号线张江高科 汤臣豪园 近长泰广场 浦东软件园 创', 3000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 40, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4100行：['广兰路地铁口 阳光花城一室一厅,装修好,配置齐全!', 3600, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4101行：['官方核验!可长租!可短租!无任何费用! 7日免租 精', 1490, '合租主卧', 1, '2户合租', nan, nan, 2.0, 14, '朝南', 0, '浦东-张江-古桐五村', '浦东', '张江', '古桐五村', nan, nan]
# 第4102行：['2号线金科路地铁口,近长泰广场浦东软件园押一付一,可', 1500, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-古桐公寓', '浦东', '张江', '古桐公寓', nan, nan]
# 第4103行：['近2号线!可押一付一!可养宠物!软件园 药谷 精装独', 2000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-蕉丽新村', '浦东', '张江', '蕉丽新村', '距2号线金科路站约1066米', 1066.0]
# 第4104行：['张江汤臣豪园三期,南北通透带阳台一室户 配置齐全 拎', 3000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南北', 1, '浦东-张江-张江汤臣豪园三期', '浦东', '张江', '张江汤臣豪园三期', '距2号线金科路站约736米', 736.0]
# 第4105行：['近广兰路地铁 精装朝南带阳台一居室 设施齐全 采光极', 2500, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4106行：['近张江高科地铁站 软件园 高档成熟小区 精装全配一室', 2450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 25, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4107行：['(整租)金科路 奶油风公寓式独立厨卫一房一厅 拎包入', 2150, '合租主卧', 1, '2户合租', nan, nan, 2.0, 43, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4108行：['张江集团高性价比三房 !民用水电 燃气做饭 固定车位', 6800, '整租', 0, '3室1厅', 3.0, 1.0, nan, 105, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4109行：['无任何费用!!!靠近张江科技园区,长泰广场 采光好拎', 2790, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '浦东-张江-青云社居里寓', '浦东', '张江', '青云社居里寓', nan, nan]
# 第4110行：['可短租可月付,近13号线张江路站,张江药谷,集电港,', 1450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-玉兰香苑', '浦东', '张江', '玉兰香苑', nan, nan]
# 第4111行：['大房东急租 朝南带阳台独卫 近2号广兰路 展讯中心', 990, '合租主卧', 1, '2户合租', nan, nan, 2.0, 36, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4112行：['广兰地铁500米采光好,拎包入住', 1400, '合租主卧', 1, '2户合租', nan, nan, 2.0, 15, '朝南', 0, '浦东-张江-兰沁苑', '浦东', '张江', '兰沁苑', '距2号线广兰路站约673米', 673.0]
# 第4113行：['出门金科路地铁口 朝南带阳台独立一房一厅 拎包可住', 4000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 55, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4114行：['张江高科近距离广兰路租房樟盛苑电梯房朝南内厨外卫油烟', 1800, '合租主卧', 1, '2户合租', nan, nan, 2.0, 20, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4115行：['近广兰路地铁 亚芯科技园 多套一室户 南北通透 豪华', 1480, '合租主卧', 1, '2户合租', nan, nan, 2.0, 15, '朝南', 0, '浦东-张江-玉兰香苑三期', '浦东', '张江', '玉兰香苑三期', '距13号线张江路站约1020米', 1020.0]
# 第4116行：['张江集团高性价比三房 !民用水电 燃气做饭 固定车位', 6800, '整租', 0, '3室1厅', 3.0, 1.0, nan, 105, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4117行：['阳光花城 性价比房子 采光好 拎包入住 小区环境好', 8400, '整租', 0, '2室2厅', 2.0, 2.0, nan, 115, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4118行：['精装修三房,出门即地铁口,近展想,日月光,集电港,药', 12000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 138, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4119行：['近浦软,药谷,汇智长泰广场,出行通勤方便,周边配套成', 8900, '整租', 0, '2室2厅', 2.0, 2.0, nan, 94, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4120行：['张江科學城 万科翡翠公园 拎包入住 南北通透 豪华装', 9300, '整租', 0, '2室2厅', 2.0, 2.0, nan, 86, '朝南', 0, '浦东-张江-万科翡翠公园', '浦东', '张江', '万科翡翠公园', '距13号线学林路站约361米', 361.0]
# 第4121行：['扩建到800平 带地暖8套房 包物业 家具全配 可看', 34000, '整租', 0, '6室3厅', 6.0, 3.0, nan, 471, '朝东', 3, '浦东-张江-汤臣高尔夫别墅', '浦东', '张江', '汤臣高尔夫别墅', nan, nan]
# 第4122行：['胡姬花园 阳光充足 电梯房 拎包入住 精装大三房适合', 11000, '整租', 0, '3室2厅', 3.0, 2.0, nan, 121, '朝南北', 1, '浦东-张江-胡姬花园', '浦东', '张江', '胡姬花园', '距2号线张江高科站约672米', 672.0]
# 第4123行：['近2号线广兰路,非合租,独立一居室燃气厨卫押一付一拎', 2600, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4124行：['地铁二号线,金科站,古桐五村朝南一室户,精装修全配', 2300, '整租', 0, '1室0厅', 1.0, 0.0, nan, 38, '朝南北', 1, '浦东-张江-古桐五村', '浦东', '张江', '古桐五村', nan, nan]
# 第4125行：['地铁二号线,广兰站,申源苑独立一室户,全装修,全配', 2800, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南北', 1, '浦东-张江-申源苑', '浦东', '张江', '申源苑', '距2号线广兰路站约936米', 936.0]
# 第4126行：['阳光花城主卧,带独立卫生间,2号线广兰路o距离', 2000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 20, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4127行：['近金科路地铁站,独立一室户,近长泰广场软件园药谷,拎', 2250, '合租主卧', 1, '2户合租', nan, nan, 2.0, 25, '朝南', 0, '浦东-张江-古桐四村', '浦东', '张江', '古桐四村', nan, nan]
# 第4128行：['2号线金科路站,近药谷软件园长泰广场对面,押一付一房', 2000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 10, '朝南', 0, '浦东-张江-张江汤臣豪园四期', '浦东', '张江', '张江汤臣豪园四期', '距2号线张江高科站约666米', 666.0]
# 第4129行：['地铁二号线,广兰站,兰沁苑朝南阳台一室户,天然气做饭', 2600, '整租', 0, '1室0厅', 1.0, 0.0, nan, 38, '朝南北', 1, '浦东-张江-兰沁苑', '浦东', '张江', '兰沁苑', '距2号线广兰路站约673米', 673.0]
# 第4130行：['近张江高科地铁站 软件园 高档成熟小区 精装全配一室', 2000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 25, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4131行：['近地铁 广兰路 温馨住宅一居室 随时看房', 3050, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4132行：['阳光花城,近2号线广兰路地铁口300米,豪华装修,拎', 2600, '整租', 0, '1室1厅', 1.0, 1.0, nan, 38, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4133行：['汤臣二期 原始南北通透主卧精装修一室户 近金科路地铁', 2500, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4134行：['张江纳仕国际社区碧云 1室2厅1卫 精装修 5581', 5581, '整租', 0, '1室2厅', 1.0, 2.0, nan, 98, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4135行：['张江纳什大两房 民水电 通燃气!拎包入住', 6500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 100, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4136行：['近张江高科地铁站 软件园 高档成熟小区 精装全配一室', 2450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 25, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4137行：['近集电港,展想广场,亚芯科技园,星创科技广场等精装一', 1700, '合租主卧', 1, '2户合租', nan, nan, 2.0, 20, '朝南', 0, '浦东-张江-兰沁苑', '浦东', '张江', '兰沁苑', '距2号线广兰路站约673米', 673.0]
# 第4138行：['可短租!毕业季特价 包水网费 非合租 独立厨卫近地铁', 1800, '合租主卧', 1, '2户合租', nan, nan, 2.0, 9, '朝南', 0, '浦东-张江-玉兰香苑二期', '浦东', '张江', '玉兰香苑二期', '距13号线张江路站约771米', 771.0]
# 第4139行：['近金科路 张江新苑朝南一居室 配置齐全 干净清爽 随', 2200, '整租', 0, '1室0厅', 1.0, 0.0, nan, 40, '朝南', 0, '浦东-张江-张江新苑', '浦东', '张江', '张江新苑', nan, nan]
# 第4140行：['2号线广兰路0距离 展讯中心 集电港软件园 精装全配', 2300, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4141行：['广兰路地铁口 阳光花城一室一厅,装修好,配置齐全!', 3600, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4142行：['官方核验!可长租!可短租!无任何费用! 7日免租 精', 1490, '合租主卧', 1, '2户合租', nan, nan, 2.0, 14, '朝南', 0, '浦东-张江-古桐五村', '浦东', '张江', '古桐五村', nan, nan]
# 第4143行：['2号线张江高科 汤臣豪园 近长泰广场 浦东软件园 创', 3000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 40, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4144行：['无任何费用!!!靠近张江科技园区,长泰广场 采光好拎', 2000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4145行：['(整租)金科路 奶油风公寓式独立厨卫一房一厅 拎包入', 2150, '合租主卧', 1, '2户合租', nan, nan, 2.0, 43, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4146行：['近金科路和广兰路地铁 软件园 汇智 长泰 朝南一室户', 1000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-贝越佳园北区', '浦东', '张江', '贝越佳园北区', '距2号线广兰路站约1015米', 1015.0]
# 第4147行：['可月付可短租,近2号线广兰路站,亚芯科技园,微电子港', 1450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 12, '朝南', 0, '浦东-张江-张江汤臣豪园一期', '浦东', '张江', '张江汤臣豪园一期', '距2号线张江高科站约219米', 219.0]
# 第4148行：['近2号线!可押一付一!可养宠物!软件园 药谷 精装独', 2000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-蕉丽新村', '浦东', '张江', '蕉丽新村', '距2号线金科路站约1066米', 1066.0]
# 第4149行：['二号线广兰路有轨沿线,阳光花城,精装一房,精装全配,', 2600, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4150行：['国企张江集团 三房两卫 民水民电 方便停车 无看房费', 7200, '整租', 0, '3室1厅', 3.0, 1.0, nan, 105, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4151行：['2号线金科路站古桐六村,近长泰广场浦东软件园,押一付', 1000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 8, '朝南', 0, '浦东-张江-蕉丽新村', '浦东', '张江', '蕉丽新村', '距2号线金科路站约1066米', 1066.0]
# 第4152行：['2号线金科路地铁口,近长泰广场浦东软件园押一付一,可', 1500, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-古桐公寓', '浦东', '张江', '古桐公寓', nan, nan]
# 第4153行：['古桐三村近二号站 张江园区 精装修一居室 看房随时有', 1990, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南北', 1, '浦东-张江-古桐三村', '浦东', '张江', '古桐三村', nan, nan]
# 第4154行：['玉兰香苑二期独立一室户,近张衡路张江药谷软件押一付一', 1400, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-玉兰香苑', '浦东', '张江', '玉兰香苑', nan, nan]
# 第4155行：['出门金科路地铁口 朝南带阳台独立一房一厅 拎包可住', 4000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 55, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4156行：['大房东急租 朝南带阳台独卫 近2号广兰路 展讯中心', 990, '合租主卧', 1, '2户合租', nan, nan, 2.0, 36, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4157行：['特价优选,近2号线地铁,近软件园,集电港,国创中心,', 1000, '合租主卧', 1, '2户合租', nan, nan, 2.0, 10, '朝南北', 1, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4158行：['张江高科近距离广兰路租房樟盛苑电梯房朝南内厨外卫油烟', 1800, '合租主卧', 1, '2户合租', nan, nan, 2.0, 20, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4159行：['无任何费用!!!靠近张江科技园区,长泰广场 采光好拎', 2700, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4160行：['近2号线!可押一付一!可养宠物!软件园 药谷 精装独', 1490, '合租主卧', 1, '2户合租', nan, nan, 2.0, 9, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4161行：['近广兰路地铁 精装朝南带阳台一居室 设施齐全 采光极', 2500, '合租主卧', 1, '2户合租', nan, nan, 2.0, 30, '朝南', 0, '浦东-张江-阳光花城', '浦东', '张江', '阳光花城', '距2号线广兰路站约307米', 307.0]
# 第4162行：['可短租可月付,近13号线张江路站,张江药谷,集电港,', 1450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-玉兰香苑', '浦东', '张江', '玉兰香苑', nan, nan]
# 第4163行：['近2号线广兰路 全独立一室户 近展想 光大 国创 集', 1800, '合租主卧', 1, '2户合租', nan, nan, 2.0, 50, '朝南', 0, '浦东-张江-樟盛苑', '浦东', '张江', '樟盛苑', nan, nan]
# 第4164行：['广兰地铁500米采光好,拎包入住', 1400, '合租主卧', 1, '2户合租', nan, nan, 2.0, 15, '朝南', 0, '浦东-张江-兰沁苑', '浦东', '张江', '兰沁苑', '距2号线广兰路站约673米', 673.0]
# 第4165行：['可月付可短租,近2号线张江高科站,张江微电子港,浦软', 1450, '合租主卧', 1, '2户合租', nan, nan, 2.0, 12, '朝南', 0, '浦东-张江-张江汤臣豪园一期', '浦东', '张江', '张江汤臣豪园一期', '距2号线张江高科站约219米', 219.0]
# 第4166行：['张江集团高性价比三房 !民用水电 燃气做饭 固定车位', 6800, '整租', 0, '3室1厅', 3.0, 1.0, nan, 105, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4167行：['无任何费用!!!靠近张江科技园区,长泰广场 采光好拎', 2790, '整租', 0, '1室1厅', 1.0, 1.0, nan, 45, '朝南', 0, '浦东-张江-青云社居里寓', '浦东', '张江', '青云社居里寓', nan, nan]
# 第4168行：['2号线金科路站汤臣三期近长泰广场浦东软件园药谷,可短', 1400, '合租主卧', 1, '2户合租', nan, nan, 2.0, 18, '朝南', 0, '浦东-张江-张江汤臣豪园三期', '浦东', '张江', '张江汤臣豪园三期', '距2号线金科路站约736米', 736.0]
# 第4169行：['近广兰路地铁 亚芯科技园 多套一室户 南北通透 豪华', 1480, '合租主卧', 1, '2户合租', nan, nan, 2.0, 15, '朝南', 0, '浦东-张江-玉兰香苑三期', '浦东', '张江', '玉兰香苑三期', '距13号线张江路站约1020米', 1020.0]
# 第4170行：['张江纳仕国际柚米公寓 | 88一室两厅民水民电 班车', 5581, '整租', 0, '1室2厅', 1.0, 2.0, nan, 88, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4171行：['张江纳仕国际社区碧云 1室2厅1卫 精装修 5581', 5581, '整租', 0, '1室2厅', 1.0, 2.0, nan, 98, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4172行：['张江汤臣豪园三期,南北通透带阳台一室户 配置齐全 拎', 3000, '整租', 0, '1室1厅', 1.0, 1.0, nan, 48, '朝南北', 1, '浦东-张江-张江汤臣豪园三期', '浦东', '张江', '张江汤臣豪园三期', '距2号线金科路站约736米', 736.0]
# 第4173行：['张江纳什大两房 民水电 通燃气!拎包入住', 6500, '整租', 0, '2室2厅', 2.0, 2.0, nan, 100, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4174行：['近2号线金科路,张江高科,浦软大厦精装主卧一居室独厨', 1500, '合租单间', 2, '3户合租', nan, nan, 3.0, 45, '朝南', 0, '浦东-张江-申源苑', '浦东', '张江', '申源苑', '距2号线广兰路站约936米', 936.0]
# 第4175行：['汤臣豪园 步行金科路地铁只需5临近浦东软件园长泰广', 2500, '整租', 0, '1室1厅', 1.0, 1.0, nan, 40, '朝南', 0, '浦东-张江-张江汤臣豪园二期', '浦东', '张江', '张江汤臣豪园二期', '距2号线金科路站约551米', 551.0]
# 第4176行：['张江集团高性价比三房 !民用水电 燃气做饭 固定车位', 6800, '整租', 0, '3室1厅', 3.0, 1.0, nan, 105, '朝南', 0, '浦东-张江-张江纳仕国际社区', '浦东', '张江', '张江纳仕国际社区', nan, nan]
# 第4177行：['汤臣四期2房,精装修,中间楼层,华二,适合浦外陪读,', 8450, '整租', 0, '2室2厅', 2.0, 2.0, nan, 91, '朝南', 0, '浦东-张江-张江汤臣豪园四期', '浦东', '张江', '张江汤臣豪园四期', '距2号线张江高科站约666米', 666.0]
# 第4178行：['扩建到800平 带地暖8套房 包物业 家具全配 可看', 34000, '整租', 0, '6室3厅', 6.0, 3.0, nan, 471, '朝东', 3, '浦东-张江-汤臣高尔夫别墅', '浦东', '张江', '汤臣高尔夫别墅', nan, nan]
# 第4179行：['朗阅府 豪华装修 自住配置 中央空调地暖 拎包入住', 7800, '整租', 0, '2室2厅', 2.0, 2.0, nan, 91, '朝南北', 1, '浦东-张江-中建朗阅府', '浦东', '张江', '中建朗阅府', nan, nan]
# 第4180行：['住进高迪 | 电梯精装现房,南向三面采光,错过再无,', 8000, '整租', 0, '2室2厅', 2.0, 2.0, nan, 114, '朝南', 0, '浦东-张江-城市经典高迪', '浦东', '张江', '城市经典高迪', '距2号线广兰路站约387米', 387.0]
# 第4181行：['贝越流明新苑 3室2厅2卫 精装修129平米 诚意出', 8500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 129, '朝南北', 1, '浦东-张江-贝越流明新苑', '浦东', '张江', '贝越流明新苑', '距2号线广兰路站约894米', 894.0]
# 第4182行：['2.21广兰站 中环内中芯国际學校旁带泳池网球场南北', 12500, '整租', 0, '3室2厅', 3.0, 2.0, nan, 143, '朝南北', 1, '浦东-张江-日月光水岸花园', '浦东', '张江', '日月光水岸花园', '距2号线广兰路站约569米', 569.0]

# %%
#数据描述与异常值检查

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 设置中文显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]
plt.rcParams["axes.unicode_minus"] = False  # 解决负号显示问题

class DataAnalyzer:
    def __init__(self, file_path):
        """初始化数据分析师，读取数据文件"""
        self.file_path = file_path
        self.data = None
        self.numeric_columns = []
        
    def load_data(self, sheet_name=0):
        """读取Excel数据"""
        try:
            self.data = pd.read_excel(self.file_path, sheet_name=sheet_name)
            print(f"数据读取成功，共 {self.data.shape[0]} 行，{self.data.shape[1]} 列")
            # 获取数值型列
            self.numeric_columns = self.data.select_dtypes(include=[np.number]).columns.tolist()
            print(f"检测到数值型列: {self.numeric_columns}")
            return True
        except Exception as e:
            print(f"数据读取失败: {str(e)}")
            return False
    
    def basic_statistics(self, columns=None):
        """计算基本统计量"""
        if self.data is None:
            print("请先加载数据")
            return
        
        # 如果未指定列，默认分析所有数值型列
        if columns is None:
            columns = self.numeric_columns
        
        # 检查指定的列是否存在且为数值型
        valid_columns = [col for col in columns if col in self.numeric_columns]
        if not valid_columns:
            print("没有有效的数值型列可分析")
            return
        
        print("\n===== 基本统计信息 =====")
        stats_df = self.data[valid_columns].describe()
        # 添加中位数和变异系数
        stats_df.loc['median'] = self.data[valid_columns].median()
        stats_df.loc['cv'] = self.data[valid_columns].std() / self.data[valid_columns].mean()  # 变异系数
        print(stats_df.round(4))
        return stats_df
    
    def detect_outliers(self, column, method='iqr', threshold=3):
        """检测异常值"""
        if self.data is None:
            print("请先加载数据")
            return None, None
        
        if column not in self.numeric_columns:
            print(f"{column} 不是有效的数值型列")
            return None, None
        
        data = self.data[column].dropna()
        
        if method == 'iqr':
            # IQR方法
            q1 = data.quantile(0.25)
            q3 = data.quantile(0.75)
            iqr = q3 - q1
            lower = q1 - 1.5 * iqr
            upper = q3 + 1.5 * iqr
            outliers = data[(data < lower) | (data > upper)]
            
        elif method == 'zscore':
            # Z-score方法
            z_scores = np.abs(stats.zscore(data))
            outliers = data[z_scores > threshold]
            lower = data.mean() - threshold * data.std()
            upper = data.mean() + threshold * data.std()
            
        else:
            print("不支持的异常值检测方法，可选：'iqr' 或 'zscore'")
            return None, None
        
        print(f"\n{column}列使用{method}方法检测到 {len(outliers)} 个异常值")
        print(f"异常值边界: [{lower:.4f}, {upper:.4f}]")
        return outliers, (lower, upper)
    
    def visualize_data(self, columns=None):
        """数据可视化"""
        if self.data is None:
            print("请先加载数据")
            return
        
        # 如果未指定列，默认分析所有数值型列（最多4列）
        if columns is None:
            columns = self.numeric_columns[:4]
        else:
            columns = [col for col in columns if col in self.numeric_columns]
        
        if not columns:
            print("没有有效的数值型列可可视化")
            return
        
        # 创建可视化图表
        n_cols = 2
        n_rows = (len(columns) + 1) // n_cols
        fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 5 * n_rows))
        axes = axes.flatten() if n_rows * n_cols > 1 else [axes]
        
        for i, col in enumerate(columns):
            # 直方图
            sns.histplot(self.data[col].dropna(), kde=True, ax=axes[i])
            axes[i].set_title(f'{col} 数据分布')
            
            # 标记异常值边界（IQR方法）
            _, (lower, upper) = self.detect_outliers(col, method='iqr')
            if lower is not None and upper is not None:
                axes[i].axvline(lower, color='r', linestyle='--', label=f'下界: {lower:.2f}')
                axes[i].axvline(upper, color='r', linestyle='--', label=f'上界: {upper:.2f}')
                axes[i].legend()
        
        # 隐藏未使用的子图
        for i in range(len(columns), len(axes)):
            axes[i].axis('off')
        
        plt.tight_layout()
        plt.show()
        
        # 箱线图
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=self.data[columns])
        plt.title('各列数据箱线图（异常值检测）')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
    
    def analyze_correlation(self):
        """分析数值型列之间的相关性"""
        if self.data is None:
            print("请先加载数据")
            return
        
        if len(self.numeric_columns) < 2:
            print("数值型列不足，无法分析相关性")
            return
        
        # 计算相关系数
        corr_matrix = self.data[self.numeric_columns].corr()
        print("\n===== 列间相关系数矩阵 =====")
        print(corr_matrix.round(4))
        
        # 热力图可视化
        plt.figure(figsize=(10, 8))
        sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f')
        plt.title('列间相关性热力图')
        plt.tight_layout()
        plt.show()

import matplotlib.pyplot as plt

# 指定使用 SimHei 字体
plt.rcParams["font.family"] = ["SimHei"]
# 解决负号显示问题
plt.rcParams["axes.unicode_minus"] = False

# 使用示例
if __name__ == "__main__":
    # 替换为你的数据文件路径
    file_path = "HW3_Rent.xlsx"
    
    # 创建分析器实例
    analyzer = DataAnalyzer(file_path)
    
    # 加载数据
    if analyzer.load_data():
        # 基本统计分析
        analyzer.basic_statistics()
        
        # 异常值检测（以第一列为例）
        if analyzer.numeric_columns:
            first_col = analyzer.numeric_columns[0]
            analyzer.detect_outliers(first_col, method='iqr')
            analyzer.detect_outliers(first_col, method='zscore')
        
        # 数据可视化
        analyzer.visualize_data()
# Out:
# 数据读取成功，共 4182 行，18 列
# 检测到数值型列: ['价格（元/月）', '出租方式（整租-0，合租主卧-1，合租单间-2）', '整租室数', '整租厅数', '合租人数', '面积（单位：㎡）', '朝向（朝南-0，朝南北-1，朝东南-2，朝东-3，朝西南-4，西南北向-5，朝北-6，朝西-7，朝东北-8，朝西北-9，朝东南北-10，朝东西-11，朝东西南-12）', '据地铁站距离', '每平米租房价格']
#
# ===== 基本统计信息 =====
#            价格（元/月）  出租方式（整租-0，合租主卧-1，合租单间-2）       整租室数       整租厅数      合租人数  \
# count    4182.0000                 4182.0000  3553.0000  3553.0000  629.0000
# mean     6937.1365                    0.1552     1.7512     1.2730    2.0318
# std      6375.0199                    0.3751     0.8926     0.5757    0.1756
# min       990.0000                    0.0000     1.0000     0.0000    2.0000
# 25%      3000.0000                    0.0000     1.0000     1.0000    2.0000
# 50%      4800.0000                    0.0000     2.0000     1.0000    2.0000
# 75%      8500.0000                    0.0000     2.0000     2.0000    2.0000
# max     78000.0000                    2.0000     7.0000     3.0000    3.0000
# median   4800.0000                    0.0000     2.0000     1.0000    2.0000
# cv          0.9190                    2.4171     0.5097     0.4522    0.0864
#
#          面积（单位：㎡）  \
# count   4182.0000
# mean      71.8278
# std      181.3570
# min        8.0000
# 25%       38.0000
# 50%       48.0000
# 75%       93.0000
# max     8000.0000
# median    48.0000
# cv         2.5249
#
#         朝向（朝南-0，朝南北-1，朝东南-2，朝东-3，朝西南-4，西南北向-5，朝北-6，朝西-7，朝东北-8，朝西北-9，朝东南北-10，朝东西-11，朝东西南-12）  \
# count                                           4182.0000
# mean                                               0.3678
# std                                                1.0760
# min                                                0.0000
# 25%                                                0.0000
# 50%                                                0.0000
# 75%                                                0.0000
# max                                               12.0000
# median                                             0.0000
# cv                                                 2.9257
#
#            据地铁站距离    每平米租房价格
# count   3725.0000  4182.0000
# mean     552.9906   100.3243
# std      223.1458    33.9244
# min       47.0000     1.0000
# 25%      361.0000    75.6098
# 50%      551.0000    96.8486
# 75%      704.0000   120.5751
# max     1099.0000   270.0000
# median   551.0000    96.8486
# cv         0.4035     0.3381
#
# 价格（元/月）列使用iqr方法检测到 293 个异常值
# 异常值边界: [-5250.0000, 16750.0000]
#
# 价格（元/月）列使用zscore方法检测到 84 个异常值
# 异常值边界: [-12187.9233, 26062.1963]
#
# 价格（元/月）列使用iqr方法检测到 293 个异常值
# 异常值边界: [-5250.0000, 16750.0000]
#
# 出租方式（整租-0，合租主卧-1，合租单间-2）列使用iqr方法检测到 629 个异常值
# 异常值边界: [0.0000, 0.0000]
#
# 整租室数列使用iqr方法检测到 118 个异常值
# 异常值边界: [-0.5000, 3.5000]
#
# 整租厅数列使用iqr方法检测到 0 个异常值
# 异常值边界: [-0.5000, 3.5000]

# %%
import pandas as pd

# 读取Excel数据
df = pd.read_excel("HW3_RENT.xlsx", sheet_name=0)

# 初始化各区域的列表（存储第2列和第9列数据）
gumei_Rent_price = []    # 古美区域的第2列数据
shibo_Rent_price = []    # 世博区域的第2列数据
xuhui_Rent_price = []    # 徐汇区域的第2列数据
zhangjiang_Rent_price = []  # 张江区域的第2列数据

gumei_Area = []          # 古美区域的第9列数据
shibo_Area = []          # 世博区域的第9列数据
xuhui_Area = []          # 徐汇区域的第9列数据
zhangjiang_Area = []     # 张江区域的第9列数据

# 遍历DataFrame的每一行
for index, row in df.iterrows():
    # 获取第14列的区域信息（注意：Python列索引从0开始，第14列对应索引13）
    region = row.iloc[13]
    
    # 获取第2列数据（索引1）和第9列数据（索引8）
    col2_data = row.iloc[1]  # 第2列数据
    col9_data = row.iloc[8]  # 第9列数据
    
    # 根据区域将数据添加到对应列表
    if region == "古美":
        gumei_Rent_price.append(col2_data)
        gumei_Area.append(col9_data)
    elif region == "世博":
        shibo_Rent_price.append(col2_data)
        shibo_Area.append(col9_data)
    elif region == "徐汇":
        xuhui_Rent_price.append(col2_data)
        xuhui_Area.append(col9_data)
    elif region == "张江":
        zhangjiang_Rent_price.append(col2_data)
        zhangjiang_Area.append(col9_data)
    # 如需处理其他区域，可添加更多elif条件

# 打印结果示例（验证数据拆分是否正确）
print("古美区域第2列数据数量：", len(gumei_Rent_price))
print("世博区域第9列数据数量：", len(shibo_Area))
print("徐汇区域第2列前5条数据：", xuhui_Rent_price[:5])
print("张江区域第9列前5条数据：", zhangjiang_Area[:5])
# Out:
# 古美区域第2列数据数量： 582
# 世博区域第9列数据数量： 1200
# 徐汇区域第2列前5条数据： [13500, 14000, 14500, 20000, 3800]
# 张江区域第9列前5条数据： [30, 38, 40, 20, 25]

# %%
def divide_lists(list1, list2):
    """
    计算两个列表对应位置元素的除法
    
    参数:
        list1: 被除数列表
        list2: 除数列表
        
    返回:
        结果列表，每个元素为对应位置的商；
        若除数为0，对应位置返回None；
        若列表长度不匹配，返回None
    """
    # 检查两个列表长度是否一致
    if len(list1) != len(list2):
        print("错误：两个列表长度不匹配")
        return None
    
    result = []
    for a, b in zip(list1, list2):
        try:
            # 尝试进行除法运算
            result.append(a / b)
        except ZeroDivisionError:
            # 处理除数为0的情况
            result.append(None)
        except TypeError:
            # 处理非数字元素的情况
            result.append(None)
    
    return result

   
gumei_rent=divide_lists(gumei_Rent_price, gumei_Area)   
shibo_rent=divide_lists(shibo_Rent_price,shibo_Area)
xuhui_rent=divide_lists(xuhui_Rent_price, xuhui_Area)
zhangjiang_rent=divide_lists(zhangjiang_Rent_price, zhangjiang_Area)

print(gumei_rent)
print(shibo_rent)
print(xuhui_rent)
print(zhangjiang_rent)
# Out:
# [146.66666666666666, 67.3913043478261, 55.172413793103445, 75.60975609756098, 74.4186046511628, 73.14634146341463, 56.14035087719298, 60.0, 57.142857142857146, 79.48717948717949, 72.72727272727273, 62.5, 69.56521739130434, 78.04878048780488, 65.3061224489796, 65.11627906976744, 74.35897435897436, 79.48717948717949, 63.63636363636363, 68.08510638297872, 68.29268292682927, 70.4390243902439, 74.35897435897436, 59.57446808510638, 75.67567567567568, 67.3913043478261, 68.88888888888889, 66.66666666666667, 75.60975609756098, 65.95744680851064, 78.04878048780488, 70.45454545454545, 62.22222222222222, 71.7948717948718, 68.29268292682927, 77.5, 64.0, 78.04878048780488, 70.8955223880597, 100.87719298245614, 88.43537414965986, 71.73913043478261, 166.66666666666666, 82.79569892473118, 105.5045871559633, 115.67164179104478, 113.04347826086956, 158.27338129496403, 153.25670498084293, 81.89655172413794, 110.0, 147.72727272727272, 96.42857142857143, 85.71428571428571, 96.15384615384616, 111.11111111111111, 90.9090909090909, 150.37593984962405, 127.81954887218045, 116.27906976744185, 146.66666666666666, 66.66666666666667, 75.60975609756098, 63.63636363636363, 65.3061224489796, 73.14634146341463, 74.4186046511628, 60.0, 59.57446808510638, 78.04878048780488, 75.60975609756098, 62.22222222222222, 74.35897435897436, 57.142857142857146, 67.3913043478261, 68.88888888888889, 79.48717948717949, 65.11627906976744, 77.5, 55.172413793103445, 79.48717948717949, 72.72727272727273, 62.5, 78.04878048780488, 64.0, 65.95744680851064, 67.3913043478261, 68.08510638297872, 56.14035087719298, 68.29268292682927, 74.35897435897436, 69.56521739130434, 75.67567567567568, 70.45454545454545, 71.7948717948718, 68.29268292682927, 70.4390243902439, 78.04878048780488, 70.8955223880597, 88.43537414965986, 100.87719298245614, 71.73913043478261, 96.15384615384616, 105.5045871559633, 147.72727272727272, 90.45226130653266, 94.82758620689656, 112.35955056179775, 113.04347826086956, 85.9375, 153.50877192982455, 107.78443113772455, 89.84375, 92.82700421940929, 112.78195488721805, 85.71428571428571, 115.27777777777777, 105.55555555555556, 127.81954887218045, 111.11111111111111, 146.66666666666666, 67.3913043478261, 78.04878048780488, 68.88888888888889, 63.63636363636363, 75.60975609756098, 75.60975609756098, 62.22222222222222, 68.29268292682927, 70.4390243902439, 55.172413793103445, 78.04878048780488, 56.14035087719298, 65.3061224489796, 73.14634146341463, 71.7948717948718, 79.48717948717949, 65.11627906976744, 57.142857142857146, 64.0, 74.35897435897436, 65.95744680851064, 68.29268292682927, 60.0, 74.35897435897436, 62.5, 67.3913043478261, 68.08510638297872, 75.67567567567568, 69.56521739130434, 59.57446808510638, 66.66666666666667, 79.48717948717949, 72.72727272727273, 74.4186046511628, 70.45454545454545, 77.5, 70.8955223880597, 78.04878048780488, 100.87719298245614, 88.43537414965986, 71.73913043478261, 105.5045871559633, 112.78195488721805, 142.85714285714286, 90.57971014492753, 108.84353741496598, 105.55555555555556, 113.11475409836065, 75.0, 89.84375, 158.27338129496403, 82.79569892473118, 93.75, 85.71428571428571, 147.72727272727272, 150.37593984962405, 81.89655172413794, 115.67164179104478, 90.45226130653266, 146.66666666666666, 66.66666666666667, 75.60975609756098, 63.63636363636363, 65.3061224489796, 73.14634146341463, 74.4186046511628, 60.0, 59.57446808510638, 78.04878048780488, 75.60975609756098, 62.22222222222222, 74.35897435897436, 57.142857142857146, 67.3913043478261, 68.88888888888889, 79.48717948717949, 65.11627906976744, 77.5, 55.172413793103445, 79.48717948717949, 72.72727272727273, 62.5, 78.04878048780488, 64.0, 65.95744680851064, 67.3913043478261, 68.08510638297872, 56.14035087719298, 68.29268292682927, 74.35897435897436, 69.56521739130434, 75.67567567567568, 70.45454545454545, 71.7948717948718, 68.29268292682927, 70.4390243902439, 78.04878048780488, 70.8955223880597, 88.43537414965986, 100.87719298245614, 71.73913043478261, 96.15384615384616, 105.5045871559633,  ...
# [102.56410256410257, 90.47619047619048, 107.6923076923077, 102.94117647058823, 111.25, 105.12820512820512, 113.15789473684211, 117.94871794871794, 102.56410256410257, 111.11111111111111, 115.38461538461539, 119.35483870967742, 117.14285714285714, 105.26315789473684, 105.26315789473684, 95.0, 113.51351351351352, 118.18181818181819, 118.75, 100.0, 90.0, 115.15151515151516, 102.56410256410257, 113.51351351351352, 127.58620689655173, 123.52941176470588, 105.88235294117646, 123.07692307692308, 105.4054054054054, 101.85185185185185, 132.25806451612902, 102.4390243902439, 93.87755102040816, 56.666666666666664, 100.0, 94.87179487179488, 117.6470588235294, 87.8048780487805, 52.5, 49.411764705882355, 105.71428571428571, 123.52941176470588, 124.13793103448276, 102.56410256410257, 79.54545454545455, 128.57142857142858, 32.58426966292135, 105.49450549450549, 77.77777777777777, 86.80555555555556, 92.6829268292683, 97.82608695652173, 108.82352941176471, 115.38461538461539, 151.72413793103448, 102.04081632653062, 117.6470588235294, 93.87755102040816, 90.0, 102.4390243902439, 92.5, 94.28571428571429, 97.5609756097561, 95.0, 112.24489795918367, 124.13793103448276, 109.0909090909091, 81.13207547169812, 92.85714285714286, 97.05882352941177, 101.96078431372548, 100.0, 144.82758620689654, 93.87755102040816, 117.74193548387096, 121.94444444444444, 89.1304347826087, 137.93103448275863, 92.10526315789474, 137.93103448275863, 110.25641025641026, 108.48484848484848, 94.11764705882354, 80.35714285714286, 91.42857142857143, 137.93103448275863, 84.90566037735849, 102.56410256410257, 75.0, 141.3793103448276, 84.90566037735849, 106.38297872340425, 84.44444444444444, 100.0, 122.58064516129032, 100.0, 111.11111111111111, 88.37209302325581, 85.45454545454545, 95.74468085106383, 71.9298245614035, 86.84210526315789, 92.10526315789474, 61.72839506172839, 82.92957746478874, 55.294117647058826, 88.46153846153847, 61.875, 82.3529411764706, 102.56410256410257, 124.13793103448276, 90.74074074074075, 60.645161290322584, 108.10810810810811, 79.2, 88.88888888888889, 120.0, 73.52941176470588, 101.85185185185185, 134.48275862068965, 92.10526315789474, 111.11111111111111, 97.5609756097561, 78.94736842105263, 95.83333333333333, 64.1025641025641, 118.0, 73.52941176470588, 86.0377358490566, 53.513513513513516, 65.78947368421052, 92.10526315789474, 129.41176470588235, 95.0, 88.88888888888889, 102.22222222222223, 116.66666666666667, 113.51351351351352, 102.04081632653062, 89.28571428571429, 82.3529411764706, 113.15789473684211, 102.70270270270271, 95.74468085106383, 82.6086956521739, 79.36507936507937, 95.23809523809524, 108.88888888888889, 69.87951807228916, 90.47619047619048, 52.94117647058823, 49.375, 100.0, 92.3076923076923, 80.35714285714286, 115.15151515151516, 124.13793103448276, 137.93103448275863, 90.47619047619048, 102.28571428571429, 102.12765957446808, 92.10526315789474, 95.0, 92.5925925925926, 100.0, 25.88235294117647, 129.03225806451613, 97.5609756097561, 112.24489795918367, 96.15384615384616, 90.47619047619048, 61.875, 92.10526315789474, 108.10810810810811, 98.0, 88.37209302325581, 69.27058823529411, 60.645161290322584, 112.24489795918367, 108.48484848484848, 100.0, 104.65116279069767, 104.65116279069767, 55.625, 108.10810810810811, 82.92957746478874, 111.76470588235294, 90.69767441860465, 131.25, 88.88888888888889, 94.11764705882354, 36.875, 84.48275862068965, 101.96078431372548, 95.0, 92.5, 90.47619047619048, 75.0, 102.12765957446808, 102.56410256410257, 92.85714285714286, 75.38461538461539, 53.714285714285715, 137.93103448275863, 49.411764705882355, 85.45454545454545, 85.71428571428571, 108.57142857142857, 57.47126436781609, 91.11111111111111, 89.1304347826087, 109.52380952380952, 96.29629629629629, 104.25531914893617, 93.75, 55.625, 144.82758620689654, 139.28571428571428, 85.36585365853658, 118.42105263157895, 93.75, 108.57142857142857, 85.71428571428571, 50.0, 95.83333333333333, 90.9090909090909, 85.71428571428571, 100.0, 120.6896551724138, 86.20689655172414,  ...
# [107.14285714285714, 98.59154929577464, 90.625, 150.37593984962405, 102.70270270270271, 144.52554744525548, 110.55276381909547, 137.93103448275863, 115.78947368421052, 127.38853503184713, 118.14345991561181, 106.38297872340425, 85.9375, 183.104, 114.94252873563218, 109.46745562130178, 99.33774834437087, 147.05882352941177, 127.14285714285714, 126.3157894736842, 118.562874251497, 137.984496124031, 112.0, 126.92307692307692, 107.78443113772455, 110.46511627906976, 111.25827814569537, 105.88235294117646, 126.92307692307692, 125.0, 108.82352941176471, 100.0, 159.5744680851064, 111.25827814569537, 106.16438356164383, 148.14814814814815, 145.45454545454547, 125.87412587412588, 111.875, 136.36363636363637, 119.23076923076923, 154.54545454545453, 115.38461538461539, 118.75, 96.7741935483871, 172.09302325581396, 141.73228346456693, 156.86274509803923, 152.0, 85.1063829787234, 125.21008403361344, 86.33093525179856, 97.52066115702479, 109.64912280701755, 122.34042553191489, 46.875, 117.6470588235294, 115.55555555555556, 122.12389380530973, 97.70114942528735, 114.6788990825688, 109.64912280701755, 99.32885906040268, 111.67883211678833, 155.40540540540542, 83.33333333333333, 97.52066115702479, 125.21008403361344, 112.5, 81.9672131147541, 111.11111111111111, 101.06382978723404, 115.55555555555556, 121.62162162162163, 97.70114942528735, 104.31654676258992, 125.0, 111.47540983606558, 135.89743589743588, 115.38461538461539, 154.76190476190476, 142.2680412371134, 122.22222222222223, 127.27272727272727, 114.58333333333333, 114.58333333333333, 46.875, 142.85714285714286, 117.6470588235294, 128.57142857142858, 124.32432432432432, 122.34042553191489, 105.6910569105691, 140.0, 108.66141732283465, 147.05882352941177, 115.38461538461539, 137.5, 126.98412698412699, 162.5, 137.93103448275863, 170.54263565891472, 108.64197530864197, 106.91823899371069, 125.0, 81.08108108108108, 98.63945578231292, 157.89473684210526, 103.52941176470588, 140.8450704225352, 108.02919708029196, 150.0, 73.33333333333333, 89.65517241379311, 170.54263565891472, 106.91823899371069, 150.0, 120.53571428571429, 114.1304347826087, 149.15254237288136, 110.09174311926606, 115.04424778761062, 155.96330275229357, 190.14084507042253, 145.6140350877193, 212.23021582733813, 111.36363636363636, 90.3225806451613, 104.76190476190476, 120.53571428571429, 130.76923076923077, 117.02127659574468, 140.8450704225352, 173.61111111111111, 170.54263565891472, 110.71428571428571, 137.93103448275863, 148.93617021276594, 154.54545454545453, 170.54263565891472, 149.12280701754386, 116.07142857142857, 170.45454545454547, 98.46153846153847, 120.25316455696202, 129.62962962962962, 150.0, 110.09174311926606, 202.27272727272728, 101.79640718562874, 112.67605633802818, 136.36363636363637, 170.54263565891472, 191.0569105691057, 80.5774278215223, 125.0, 137.93103448275863, 115.38461538461539, 160.37735849056602, 150.0, 106.91823899371069, 100.0, 129.82456140350877, 115.38461538461539, 108.64197530864197, 100.0, 159.72222222222223, 73.33333333333333, 157.89473684210526, 98.63945578231292, 102.27272727272727, 136.66666666666666, 121.84873949579831, 116.43835616438356, 114.1304347826087, 122.64150943396227, 100.0, 103.36134453781513, 116.07142857142857, 147.69230769230768, 170.54263565891472, 100.0, 121.84873949579831, 96.93877551020408, 170.45454545454547, 155.96330275229357, 120.25316455696202, 212.23021582733813, 101.79640718562874, 154.54545454545453, 173.61111111111111, 100.0, 110.71428571428571, 127.27272727272727, 124.20382165605096, 106.50887573964496, 237.5, 125.45454545454545, 119.04761904761905, 87.43169398907104, 99.26470588235294, 117.6470588235294, 1.0, 118.64406779661017, 117.02127659574468, 94.28571428571429, 116.41791044776119, 102.56410256410257, 190.9090909090909, 93.33333333333333, 85.29411764705883, 94.4055944055944, 111.42857142857143, 100.0, 107.8125, 106.38297872340425, 109.0909090909091, 95.39473684210526, 133.06451612903226, 92.5925925925926, 151.72413793103448, 91.95402298850574, 144.23076 ...
# [86.66666666666667, 60.526315789473685, 70.0, 100.0, 90.0, 200.0, 68.42105263157895, 80.0, 76.25, 68.42105263157895, 62.5, 56.94897959183673, 65.0, 98.0, 85.0, 200.0, 55.0, 57.5, 80.0, 106.42857142857143, 75.0, 66.66666666666667, 50.0, 33.333333333333336, 120.83333333333333, 66.66666666666667, 65.0, 68.57142857142857, 125.0, 83.33333333333333, 49.75, 77.77777777777777, 72.72727272727273, 27.5, 100.0, 90.0, 90.0, 165.55555555555554, 83.33333333333333, 80.55555555555556, 36.0, 93.33333333333333, 120.83333333333333, 64.76190476190476, 62.0, 77.77777777777777, 98.66666666666667, 63.42045454545455, 56.94897959183673, 62.5, 65.0, 33.333333333333336, 62.5, 64.76190476190476, 92.85714285714286, 72.1868365180467, 85.71428571428571, 70.17543859649123, 65.89147286821705, 87.41258741258741, 80.0, 86.66666666666667, 60.526315789473685, 100.0, 68.42105263157895, 70.0, 90.0, 76.25, 68.42105263157895, 200.0, 65.0, 65.0, 62.0, 68.57142857142857, 77.77777777777777, 57.5, 100.0, 200.0, 98.66666666666667, 80.55555555555556, 72.72727272727273, 62.5, 165.55555555555554, 75.0, 90.0, 62.5, 55.0, 50.0, 93.33333333333333, 33.333333333333336, 120.83333333333333, 56.94897959183673, 36.0, 77.77777777777777, 65.0, 85.0, 66.66666666666667, 66.66666666666667, 120.83333333333333, 64.76190476190476, 33.333333333333336, 56.94897959183673, 106.42857142857143, 62.5, 83.33333333333333, 63.42045454545455, 90.0, 83.33333333333333, 98.0, 27.5, 80.0, 49.75, 125.0, 64.76190476190476, 70.17543859649123, 94.68085106382979, 85.71428571428571, 65.89147286821705, 119.0, 87.41258741258741, 68.42105263157895, 60.526315789473685, 70.0, 200.0, 90.0, 76.25, 68.42105263157895, 80.0, 100.0, 86.66666666666667, 63.42045454545455, 62.5, 200.0, 120.83333333333333, 120.83333333333333, 62.5, 100.0, 49.75, 56.94897959183673, 68.57142857142857, 33.333333333333336, 33.333333333333336, 55.0, 36.0, 65.0, 66.66666666666667, 56.94897959183673, 77.77777777777777, 65.0, 85.0, 77.77777777777777, 125.0, 57.5, 65.0, 165.55555555555554, 90.0, 75.0, 80.0, 106.42857142857143, 83.33333333333333, 66.66666666666667, 62.5, 83.33333333333333, 98.0, 50.0, 64.76190476190476, 62.0, 80.55555555555556, 27.5, 93.33333333333333, 72.72727272727273, 90.0, 98.66666666666667, 64.76190476190476, 73.04347826086956, 86.95652173913044, 94.68085106382979, 108.13953488372093, 72.1868365180467, 90.9090909090909, 80.0, 86.66666666666667, 60.526315789473685, 100.0, 68.42105263157895, 70.0, 90.0, 76.25, 68.42105263157895, 200.0, 65.0, 65.0, 62.0, 68.57142857142857, 77.77777777777777, 57.5, 100.0, 200.0, 98.66666666666667, 80.55555555555556, 72.72727272727273, 62.5, 165.55555555555554, 75.0, 90.0, 62.5, 55.0, 50.0, 93.33333333333333, 33.333333333333336, 120.83333333333333, 56.94897959183673, 36.0, 77.77777777777777, 65.0, 85.0, 66.66666666666667, 66.66666666666667, 120.83333333333333, 64.76190476190476, 33.333333333333336, 56.94897959183673, 106.42857142857143, 62.5, 83.33333333333333, 63.42045454545455, 90.0, 83.33333333333333, 98.0, 27.5, 80.0, 49.75, 125.0, 64.76190476190476, 70.17543859649123, 94.68085106382979, 85.71428571428571, 65.89147286821705, 119.0, 87.41258741258741, 80.0, 86.66666666666667, 60.526315789473685, 100.0, 68.42105263157895, 70.0, 90.0, 76.25, 68.42105263157895, 200.0, 65.0, 65.0, 62.0, 68.57142857142857, 77.77777777777777, 57.5, 100.0, 200.0, 98.66666666666667, 80.55555555555556, 72.72727272727273, 62.5, 165.55555555555554, 75.0, 90.0, 62.5, 55.0, 50.0, 93.33333333333333, 33.333333333333336, 120.83333333333333, 56.94897959183673, 36.0, 77.77777777777777, 65.0, 85.0, 66.66666666666667, 66.66666666666667, 120.83333333333333, 64.76190476190476, 33.333333333333336, 56.94897959183673, 106.42857142857143, 62.5, 83.33333333333333, 63.42045454545455, 90.0, 83.33333333333333, 98.0, 27.5, 80.0, 49.75, 125.0, 64.76190476190476, 70.17543859649123, 94.68085106382979, 85.71428571428571, 65.89147286821705, 119.0, 87.41258741258741, 86.66666666666667, 60.526315789473685, 70.0, 100.0, 90.0, 200.0, 68.42105263157895, 80. ...

# %%
import numpy as np

def remove_outliers_from_list(data_list, method='iqr'):
    """
    从列表中去除异常值
    
    参数:
        data_list: 包含数值的列表（可能含None）
        method: 异常值检测方法，'iqr'或'std'
    
    返回:
        去除异常值后的新列表
    """
    # 过滤掉None值（空白），同时保留原始数值用于计算边界
    valid_data = [x for x in data_list if x is not None]
    
    if not valid_data:
        print("警告：列表中没有有效数据")
        return []
    
    # 转换为numpy数组便于计算
    valid_np = np.array(valid_data)
    
    # 计算上下限
    if method == 'iqr':
        # IQR方法
        q1 = np.percentile(valid_np, 25)
        q3 = np.percentile(valid_np, 75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        print(f"IQR方法：下限={lower_bound:.2f}, 上限={upper_bound:.2f}")
    elif method == 'std':
        # 标准差方法（3倍标准差）
        mean = np.mean(valid_np)
        std = np.std(valid_np)
        lower_bound = mean - 3 * std
        upper_bound = mean + 3 * std
        print(f"标准差方法：均值={mean:.2f}, 标准差={std:.2f}, 下限={lower_bound:.2f}, 上限={upper_bound:.2f}")
    else:
        print("错误：方法必须是'iqr'或'std'")
        return []
    
    # 过滤异常值（保留在范围内的数据，同时保留原始列表中的None位置）
    cleaned_list = []
    for value in data_list:
        if value is None:
            # 保留空白值
            cleaned_list.append(None)
        else:
            # 判断是否在正常范围内
            if lower_bound <= value <= upper_bound:
                cleaned_list.append(value)
    
    return cleaned_list

# IQR方法
clean_gumei_rent = remove_outliers_from_list(gumei_rent, method='iqr')
clean_shibo_rent = remove_outliers_from_list(shibo_rent, method='iqr')
clean_xuhui_rent = remove_outliers_from_list(xuhui_rent, method='iqr')
clean_zhangjiang_rent = remove_outliers_from_list(zhangjiang_rent, method='iqr')

print("\nIQR方法处理后：")
print(clean_gumei_rent)
print(clean_shibo_rent)
print(clean_xuhui_rent)
print(clean_zhangjiang_rent)
# Out:
# IQR方法：下限=32.80, 上限=125.04
# IQR方法：下限=50.81, 上限=155.32
# IQR方法：下限=51.09, 上限=194.07
# IQR方法：下限=22.98, 上限=130.21
#
# IQR方法处理后：
# [67.3913043478261, 55.172413793103445, 75.60975609756098, 74.4186046511628, 73.14634146341463, 56.14035087719298, 60.0, 57.142857142857146, 79.48717948717949, 72.72727272727273, 62.5, 69.56521739130434, 78.04878048780488, 65.3061224489796, 65.11627906976744, 74.35897435897436, 79.48717948717949, 63.63636363636363, 68.08510638297872, 68.29268292682927, 70.4390243902439, 74.35897435897436, 59.57446808510638, 75.67567567567568, 67.3913043478261, 68.88888888888889, 66.66666666666667, 75.60975609756098, 65.95744680851064, 78.04878048780488, 70.45454545454545, 62.22222222222222, 71.7948717948718, 68.29268292682927, 77.5, 64.0, 78.04878048780488, 70.8955223880597, 100.87719298245614, 88.43537414965986, 71.73913043478261, 82.79569892473118, 105.5045871559633, 115.67164179104478, 113.04347826086956, 81.89655172413794, 110.0, 96.42857142857143, 85.71428571428571, 96.15384615384616, 111.11111111111111, 90.9090909090909, 116.27906976744185, 66.66666666666667, 75.60975609756098, 63.63636363636363, 65.3061224489796, 73.14634146341463, 74.4186046511628, 60.0, 59.57446808510638, 78.04878048780488, 75.60975609756098, 62.22222222222222, 74.35897435897436, 57.142857142857146, 67.3913043478261, 68.88888888888889, 79.48717948717949, 65.11627906976744, 77.5, 55.172413793103445, 79.48717948717949, 72.72727272727273, 62.5, 78.04878048780488, 64.0, 65.95744680851064, 67.3913043478261, 68.08510638297872, 56.14035087719298, 68.29268292682927, 74.35897435897436, 69.56521739130434, 75.67567567567568, 70.45454545454545, 71.7948717948718, 68.29268292682927, 70.4390243902439, 78.04878048780488, 70.8955223880597, 88.43537414965986, 100.87719298245614, 71.73913043478261, 96.15384615384616, 105.5045871559633, 90.45226130653266, 94.82758620689656, 112.35955056179775, 113.04347826086956, 85.9375, 107.78443113772455, 89.84375, 92.82700421940929, 112.78195488721805, 85.71428571428571, 115.27777777777777, 105.55555555555556, 111.11111111111111, 67.3913043478261, 78.04878048780488, 68.88888888888889, 63.63636363636363, 75.60975609756098, 75.60975609756098, 62.22222222222222, 68.29268292682927, 70.4390243902439, 55.172413793103445, 78.04878048780488, 56.14035087719298, 65.3061224489796, 73.14634146341463, 71.7948717948718, 79.48717948717949, 65.11627906976744, 57.142857142857146, 64.0, 74.35897435897436, 65.95744680851064, 68.29268292682927, 60.0, 74.35897435897436, 62.5, 67.3913043478261, 68.08510638297872, 75.67567567567568, 69.56521739130434, 59.57446808510638, 66.66666666666667, 79.48717948717949, 72.72727272727273, 74.4186046511628, 70.45454545454545, 77.5, 70.8955223880597, 78.04878048780488, 100.87719298245614, 88.43537414965986, 71.73913043478261, 105.5045871559633, 112.78195488721805, 90.57971014492753, 108.84353741496598, 105.55555555555556, 113.11475409836065, 75.0, 89.84375, 82.79569892473118, 93.75, 85.71428571428571, 81.89655172413794, 115.67164179104478, 90.45226130653266, 66.66666666666667, 75.60975609756098, 63.63636363636363, 65.3061224489796, 73.14634146341463, 74.4186046511628, 60.0, 59.57446808510638, 78.04878048780488, 75.60975609756098, 62.22222222222222, 74.35897435897436, 57.142857142857146, 67.3913043478261, 68.88888888888889, 79.48717948717949, 65.11627906976744, 77.5, 55.172413793103445, 79.48717948717949, 72.72727272727273, 62.5, 78.04878048780488, 64.0, 65.95744680851064, 67.3913043478261, 68.08510638297872, 56.14035087719298, 68.29268292682927, 74.35897435897436, 69.56521739130434, 75.67567567567568, 70.45454545454545, 71.7948717948718, 68.29268292682927, 70.4390243902439, 78.04878048780488, 70.8955223880597, 88.43537414965986, 100.87719298245614, 71.73913043478261, 96.15384615384616, 105.5045871559633, 90.45226130653266, 94.82758620689656, 112.35955056179775, 113.04347826086956, 85.9375, 107.78443113772455, 89.84375, 92.82700421940929, 112.78195488721805, 85.71428571428571, 115.27777777777777, 105.55555555555556, 111.11111111111111, 66.66666666666667, 75.60975609756098, 63.63636363636363, 65.3061224489796, 73.14634146341463, 74.41860465 ...
# [102.56410256410257, 90.47619047619048, 107.6923076923077, 102.94117647058823, 111.25, 105.12820512820512, 113.15789473684211, 117.94871794871794, 102.56410256410257, 111.11111111111111, 115.38461538461539, 119.35483870967742, 117.14285714285714, 105.26315789473684, 105.26315789473684, 95.0, 113.51351351351352, 118.18181818181819, 118.75, 100.0, 90.0, 115.15151515151516, 102.56410256410257, 113.51351351351352, 127.58620689655173, 123.52941176470588, 105.88235294117646, 123.07692307692308, 105.4054054054054, 101.85185185185185, 132.25806451612902, 102.4390243902439, 93.87755102040816, 56.666666666666664, 100.0, 94.87179487179488, 117.6470588235294, 87.8048780487805, 52.5, 105.71428571428571, 123.52941176470588, 124.13793103448276, 102.56410256410257, 79.54545454545455, 128.57142857142858, 105.49450549450549, 77.77777777777777, 86.80555555555556, 92.6829268292683, 97.82608695652173, 108.82352941176471, 115.38461538461539, 151.72413793103448, 102.04081632653062, 117.6470588235294, 93.87755102040816, 90.0, 102.4390243902439, 92.5, 94.28571428571429, 97.5609756097561, 95.0, 112.24489795918367, 124.13793103448276, 109.0909090909091, 81.13207547169812, 92.85714285714286, 97.05882352941177, 101.96078431372548, 100.0, 144.82758620689654, 93.87755102040816, 117.74193548387096, 121.94444444444444, 89.1304347826087, 137.93103448275863, 92.10526315789474, 137.93103448275863, 110.25641025641026, 108.48484848484848, 94.11764705882354, 80.35714285714286, 91.42857142857143, 137.93103448275863, 84.90566037735849, 102.56410256410257, 75.0, 141.3793103448276, 84.90566037735849, 106.38297872340425, 84.44444444444444, 100.0, 122.58064516129032, 100.0, 111.11111111111111, 88.37209302325581, 85.45454545454545, 95.74468085106383, 71.9298245614035, 86.84210526315789, 92.10526315789474, 61.72839506172839, 82.92957746478874, 55.294117647058826, 88.46153846153847, 61.875, 82.3529411764706, 102.56410256410257, 124.13793103448276, 90.74074074074075, 60.645161290322584, 108.10810810810811, 79.2, 88.88888888888889, 120.0, 73.52941176470588, 101.85185185185185, 134.48275862068965, 92.10526315789474, 111.11111111111111, 97.5609756097561, 78.94736842105263, 95.83333333333333, 64.1025641025641, 118.0, 73.52941176470588, 86.0377358490566, 53.513513513513516, 65.78947368421052, 92.10526315789474, 129.41176470588235, 95.0, 88.88888888888889, 102.22222222222223, 116.66666666666667, 113.51351351351352, 102.04081632653062, 89.28571428571429, 82.3529411764706, 113.15789473684211, 102.70270270270271, 95.74468085106383, 82.6086956521739, 79.36507936507937, 95.23809523809524, 108.88888888888889, 69.87951807228916, 90.47619047619048, 52.94117647058823, 100.0, 92.3076923076923, 80.35714285714286, 115.15151515151516, 124.13793103448276, 137.93103448275863, 90.47619047619048, 102.28571428571429, 102.12765957446808, 92.10526315789474, 95.0, 92.5925925925926, 100.0, 129.03225806451613, 97.5609756097561, 112.24489795918367, 96.15384615384616, 90.47619047619048, 61.875, 92.10526315789474, 108.10810810810811, 98.0, 88.37209302325581, 69.27058823529411, 60.645161290322584, 112.24489795918367, 108.48484848484848, 100.0, 104.65116279069767, 104.65116279069767, 55.625, 108.10810810810811, 82.92957746478874, 111.76470588235294, 90.69767441860465, 131.25, 88.88888888888889, 94.11764705882354, 84.48275862068965, 101.96078431372548, 95.0, 92.5, 90.47619047619048, 75.0, 102.12765957446808, 102.56410256410257, 92.85714285714286, 75.38461538461539, 53.714285714285715, 137.93103448275863, 85.45454545454545, 85.71428571428571, 108.57142857142857, 57.47126436781609, 91.11111111111111, 89.1304347826087, 109.52380952380952, 96.29629629629629, 104.25531914893617, 93.75, 55.625, 144.82758620689654, 139.28571428571428, 85.36585365853658, 118.42105263157895, 93.75, 108.57142857142857, 85.71428571428571, 95.83333333333333, 90.9090909090909, 85.71428571428571, 100.0, 120.6896551724138, 86.20689655172414, 144.82758620689654, 56.25, 92.5, 113.51351351351352, 100.0, 89.74358974358974, 56.93069306930693, 55 ...
# [107.14285714285714, 98.59154929577464, 90.625, 150.37593984962405, 102.70270270270271, 144.52554744525548, 110.55276381909547, 137.93103448275863, 115.78947368421052, 127.38853503184713, 118.14345991561181, 106.38297872340425, 85.9375, 183.104, 114.94252873563218, 109.46745562130178, 99.33774834437087, 147.05882352941177, 127.14285714285714, 126.3157894736842, 118.562874251497, 137.984496124031, 112.0, 126.92307692307692, 107.78443113772455, 110.46511627906976, 111.25827814569537, 105.88235294117646, 126.92307692307692, 125.0, 108.82352941176471, 100.0, 159.5744680851064, 111.25827814569537, 106.16438356164383, 148.14814814814815, 145.45454545454547, 125.87412587412588, 111.875, 136.36363636363637, 119.23076923076923, 154.54545454545453, 115.38461538461539, 118.75, 96.7741935483871, 172.09302325581396, 141.73228346456693, 156.86274509803923, 152.0, 85.1063829787234, 125.21008403361344, 86.33093525179856, 97.52066115702479, 109.64912280701755, 122.34042553191489, 117.6470588235294, 115.55555555555556, 122.12389380530973, 97.70114942528735, 114.6788990825688, 109.64912280701755, 99.32885906040268, 111.67883211678833, 155.40540540540542, 83.33333333333333, 97.52066115702479, 125.21008403361344, 112.5, 81.9672131147541, 111.11111111111111, 101.06382978723404, 115.55555555555556, 121.62162162162163, 97.70114942528735, 104.31654676258992, 125.0, 111.47540983606558, 135.89743589743588, 115.38461538461539, 154.76190476190476, 142.2680412371134, 122.22222222222223, 127.27272727272727, 114.58333333333333, 114.58333333333333, 142.85714285714286, 117.6470588235294, 128.57142857142858, 124.32432432432432, 122.34042553191489, 105.6910569105691, 140.0, 108.66141732283465, 147.05882352941177, 115.38461538461539, 137.5, 126.98412698412699, 162.5, 137.93103448275863, 170.54263565891472, 108.64197530864197, 106.91823899371069, 125.0, 81.08108108108108, 98.63945578231292, 157.89473684210526, 103.52941176470588, 140.8450704225352, 108.02919708029196, 150.0, 73.33333333333333, 89.65517241379311, 170.54263565891472, 106.91823899371069, 150.0, 120.53571428571429, 114.1304347826087, 149.15254237288136, 110.09174311926606, 115.04424778761062, 155.96330275229357, 190.14084507042253, 145.6140350877193, 111.36363636363636, 90.3225806451613, 104.76190476190476, 120.53571428571429, 130.76923076923077, 117.02127659574468, 140.8450704225352, 173.61111111111111, 170.54263565891472, 110.71428571428571, 137.93103448275863, 148.93617021276594, 154.54545454545453, 170.54263565891472, 149.12280701754386, 116.07142857142857, 170.45454545454547, 98.46153846153847, 120.25316455696202, 129.62962962962962, 150.0, 110.09174311926606, 101.79640718562874, 112.67605633802818, 136.36363636363637, 170.54263565891472, 191.0569105691057, 80.5774278215223, 125.0, 137.93103448275863, 115.38461538461539, 160.37735849056602, 150.0, 106.91823899371069, 100.0, 129.82456140350877, 115.38461538461539, 108.64197530864197, 100.0, 159.72222222222223, 73.33333333333333, 157.89473684210526, 98.63945578231292, 102.27272727272727, 136.66666666666666, 121.84873949579831, 116.43835616438356, 114.1304347826087, 122.64150943396227, 100.0, 103.36134453781513, 116.07142857142857, 147.69230769230768, 170.54263565891472, 100.0, 121.84873949579831, 96.93877551020408, 170.45454545454547, 155.96330275229357, 120.25316455696202, 101.79640718562874, 154.54545454545453, 173.61111111111111, 100.0, 110.71428571428571, 127.27272727272727, 124.20382165605096, 106.50887573964496, 125.45454545454545, 119.04761904761905, 87.43169398907104, 99.26470588235294, 117.6470588235294, 118.64406779661017, 117.02127659574468, 94.28571428571429, 116.41791044776119, 102.56410256410257, 190.9090909090909, 93.33333333333333, 85.29411764705883, 94.4055944055944, 111.42857142857143, 100.0, 107.8125, 106.38297872340425, 109.0909090909091, 95.39473684210526, 133.06451612903226, 92.5925925925926, 151.72413793103448, 91.95402298850574, 144.23076923076923, 105.63380281690141, 176.92307692307693, 120.0, 140.8450704225352, 153.8461538 ...
# [86.66666666666667, 60.526315789473685, 70.0, 100.0, 90.0, 68.42105263157895, 80.0, 76.25, 68.42105263157895, 62.5, 56.94897959183673, 65.0, 98.0, 85.0, 55.0, 57.5, 80.0, 106.42857142857143, 75.0, 66.66666666666667, 50.0, 33.333333333333336, 120.83333333333333, 66.66666666666667, 65.0, 68.57142857142857, 125.0, 83.33333333333333, 49.75, 77.77777777777777, 72.72727272727273, 27.5, 100.0, 90.0, 90.0, 83.33333333333333, 80.55555555555556, 36.0, 93.33333333333333, 120.83333333333333, 64.76190476190476, 62.0, 77.77777777777777, 98.66666666666667, 63.42045454545455, 56.94897959183673, 62.5, 65.0, 33.333333333333336, 62.5, 64.76190476190476, 92.85714285714286, 72.1868365180467, 85.71428571428571, 70.17543859649123, 65.89147286821705, 87.41258741258741, 80.0, 86.66666666666667, 60.526315789473685, 100.0, 68.42105263157895, 70.0, 90.0, 76.25, 68.42105263157895, 65.0, 65.0, 62.0, 68.57142857142857, 77.77777777777777, 57.5, 100.0, 98.66666666666667, 80.55555555555556, 72.72727272727273, 62.5, 75.0, 90.0, 62.5, 55.0, 50.0, 93.33333333333333, 33.333333333333336, 120.83333333333333, 56.94897959183673, 36.0, 77.77777777777777, 65.0, 85.0, 66.66666666666667, 66.66666666666667, 120.83333333333333, 64.76190476190476, 33.333333333333336, 56.94897959183673, 106.42857142857143, 62.5, 83.33333333333333, 63.42045454545455, 90.0, 83.33333333333333, 98.0, 27.5, 80.0, 49.75, 125.0, 64.76190476190476, 70.17543859649123, 94.68085106382979, 85.71428571428571, 65.89147286821705, 119.0, 87.41258741258741, 68.42105263157895, 60.526315789473685, 70.0, 90.0, 76.25, 68.42105263157895, 80.0, 100.0, 86.66666666666667, 63.42045454545455, 62.5, 120.83333333333333, 120.83333333333333, 62.5, 100.0, 49.75, 56.94897959183673, 68.57142857142857, 33.333333333333336, 33.333333333333336, 55.0, 36.0, 65.0, 66.66666666666667, 56.94897959183673, 77.77777777777777, 65.0, 85.0, 77.77777777777777, 125.0, 57.5, 65.0, 90.0, 75.0, 80.0, 106.42857142857143, 83.33333333333333, 66.66666666666667, 62.5, 83.33333333333333, 98.0, 50.0, 64.76190476190476, 62.0, 80.55555555555556, 27.5, 93.33333333333333, 72.72727272727273, 90.0, 98.66666666666667, 64.76190476190476, 73.04347826086956, 86.95652173913044, 94.68085106382979, 108.13953488372093, 72.1868365180467, 90.9090909090909, 80.0, 86.66666666666667, 60.526315789473685, 100.0, 68.42105263157895, 70.0, 90.0, 76.25, 68.42105263157895, 65.0, 65.0, 62.0, 68.57142857142857, 77.77777777777777, 57.5, 100.0, 98.66666666666667, 80.55555555555556, 72.72727272727273, 62.5, 75.0, 90.0, 62.5, 55.0, 50.0, 93.33333333333333, 33.333333333333336, 120.83333333333333, 56.94897959183673, 36.0, 77.77777777777777, 65.0, 85.0, 66.66666666666667, 66.66666666666667, 120.83333333333333, 64.76190476190476, 33.333333333333336, 56.94897959183673, 106.42857142857143, 62.5, 83.33333333333333, 63.42045454545455, 90.0, 83.33333333333333, 98.0, 27.5, 80.0, 49.75, 125.0, 64.76190476190476, 70.17543859649123, 94.68085106382979, 85.71428571428571, 65.89147286821705, 119.0, 87.41258741258741, 80.0, 86.66666666666667, 60.526315789473685, 100.0, 68.42105263157895, 70.0, 90.0, 76.25, 68.42105263157895, 65.0, 65.0, 62.0, 68.57142857142857, 77.77777777777777, 57.5, 100.0, 98.66666666666667, 80.55555555555556, 72.72727272727273, 62.5, 75.0, 90.0, 62.5, 55.0, 50.0, 93.33333333333333, 33.333333333333336, 120.83333333333333, 56.94897959183673, 36.0, 77.77777777777777, 65.0, 85.0, 66.66666666666667, 66.66666666666667, 120.83333333333333, 64.76190476190476, 33.333333333333336, 56.94897959183673, 106.42857142857143, 62.5, 83.33333333333333, 63.42045454545455, 90.0, 83.33333333333333, 98.0, 27.5, 80.0, 49.75, 125.0, 64.76190476190476, 70.17543859649123, 94.68085106382979, 85.71428571428571, 65.89147286821705, 119.0, 87.41258741258741, 86.66666666666667, 60.526315789473685, 70.0, 100.0, 90.0, 68.42105263157895, 80.0, 76.25, 68.42105263157895, 62.5, 56.94897959183673, 65.0, 98.0, 85.0, 55.0, 57.5, 80.0, 106.42857142857143, 75.0, 66.66666666666667, 50.0, 33.333333333333336, 120.833333333333 ...

# %%
#求各个区域的中位数
import statistics

# 计算古美每平方米租金价格的中位数
gumei_median = statistics.median(clean_gumei_rent)
print("古美每平方米租金价格的中位数为：", gumei_median)

# 计算世博每平方米租金价格的中位数
shibo_median = statistics.median(clean_shibo_rent)
print("世博每平方米租金价格的中位数为：", shibo_median)

# 计算徐汇每平方米租金价格的中位数
xuhui_median = statistics.median(clean_xuhui_rent)
print("徐汇每平方米租金价格的中位数为：", xuhui_median)

# 计算张江每平方米租金价格的中位数
zhangjiang_median = statistics.median(clean_zhangjiang_rent)
print("张江每平方米租金价格的中位数为：", zhangjiang_median)
# Out:
# 古美每平方米租金价格的中位数为： 73.14634146341463
# 世博每平方米租金价格的中位数为： 101.4
# 徐汇每平方米租金价格的中位数为： 120.37037037037037
# 张江每平方米租金价格的中位数为： 72.1868365180467

# %%
#第二部分：求各区域二手房中位数

# %%
import pandas as pd

# 读取Excel数据
df1 = pd.read_excel("HW3_SEC.xlsx", sheet_name=0)

# 初始化各区域的列表（存储第三列数据）
gumei_SEC_price = []    # 古美区域的第三列数据
shibo_SEC_price = []    # 世博区域的第三列数据
xuhui_SEC_price = []    # 徐汇区域的第三列数据
zhangjiang_SEC_price = []  # 张江区域的第三列数据

# 遍历DataFrame的每一行
for index, row in df1.iterrows():
    # 获取第18列的区域信息（Python列索引从0开始，第18列对应索引17）
    region = row.iloc[17]
    
    # 获取第三列数据（索引为2）
    col3_data = row.iloc[2]
    
    # 根据区域将数据添加到对应列表
    if region == "古美":
        gumei_SEC_price.append(col3_data)
    elif region == "世博":
        shibo_SEC_price.append(col3_data)
    elif region == "徐汇":
        xuhui_SEC_price.append(col3_data)
    elif region == "张江":
        zhangjiang_SEC_price.append(col3_data)
    # 如需处理其他可能的区域，可添加更多条件

# 验证各列表的数据量
print(f"古美区域数据量：{len(gumei_SEC_price)}")
print(f"世博区域数据量：{len(shibo_SEC_price)}")
print(f"徐汇区域数据量：{len(xuhui_SEC_price)}")
print(f"张江区域数据量：{len(zhangjiang_SEC_price)}")

# 打印各列表前5条数据示例
print("\n古美前5条数据：", gumei_SEC_price[:5])
print("世博前5条数据：", shibo_SEC_price[:5])
print("徐汇前5条数据：", xuhui_SEC_price[:5])
print("张江前5条数据：", zhangjiang_SEC_price[:5])
# Out:
# 古美区域数据量：504
# 世博区域数据量：1200
# 徐汇区域数据量：1200
# 张江区域数据量：1127
#
# 古美前5条数据： [66339, 72547, 60534, 48459, 62955]
# 世博前5条数据： [68095, 68106, 70143, 42222, 61284]
# 徐汇前5条数据： [88449, 94656, 115101, 100922, 101486]
# 张江前5条数据： [100452, 41538, 46971, 106325, 37209]

# %%
#数据描述与异常值

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# 设置中文显示
plt.rcParams["font.family"] = ["SimHei", "WenQuanYi Micro Hei", "Heiti TC"]
plt.rcParams["axes.unicode_minus"] = False  # 解决负号显示问题

class DataAnalyzer:
    def __init__(self, file_path):
        """初始化数据分析师，读取数据文件"""
        self.file_path = file_path
        self.data = None
        self.numeric_columns = []
        
    def load_data(self, sheet_name=0):
        """读取Excel数据"""
        try:
            self.data = pd.read_excel(self.file_path, sheet_name=sheet_name)
            print(f"数据读取成功，共 {self.data.shape[0]} 行，{self.data.shape[1]} 列")
            # 获取数值型列
            self.numeric_columns = self.data.select_dtypes(include=[np.number]).columns.tolist()
            print(f"检测到数值型列: {self.numeric_columns}")
            return True
        except Exception as e:
            print(f"数据读取失败: {str(e)}")
            return False
    
    def basic_statistics(self, columns=None):
        """计算基本统计量"""
        if self.data is None:
            print("请先加载数据")
            return
        
        # 如果未指定列，默认分析所有数值型列
        if columns is None:
            columns = self.numeric_columns
        
        # 检查指定的列是否存在且为数值型
        valid_columns = [col for col in columns if col in self.numeric_columns]
        if not valid_columns:
            print("没有有效的数值型列可分析")
            return
        
        print("\n===== 基本统计信息 =====")
        stats_df = self.data[valid_columns].describe()
        # 添加中位数和变异系数
        stats_df.loc['median'] = self.data[valid_columns].median()
        stats_df.loc['cv'] = self.data[valid_columns].std() / self.data[valid_columns].mean()  # 变异系数
        print(stats_df.round(4))
        return stats_df
    
    def detect_outliers(self, column, method='iqr', threshold=3):
        """检测异常值"""
        if self.data is None:
            print("请先加载数据")
            return None, None
        
        if column not in self.numeric_columns:
            print(f"{column} 不是有效的数值型列")
            return None, None
        
        data = self.data[column].dropna()
        
        if method == 'iqr':
            # IQR方法
            q1 = data.quantile(0.25)
            q3 = data.quantile(0.75)
            iqr = q3 - q1
            lower = q1 - 1.5 * iqr
            upper = q3 + 1.5 * iqr
            outliers = data[(data < lower) | (data > upper)]
            
        elif method == 'zscore':
            # Z-score方法
            z_scores = np.abs(stats.zscore(data))
            outliers = data[z_scores > threshold]
            lower = data.mean() - threshold * data.std()
            upper = data.mean() + threshold * data.std()
            
        else:
            print("不支持的异常值检测方法，可选：'iqr' 或 'zscore'")
            return None, None
        
        print(f"\n{column}列使用{method}方法检测到 {len(outliers)} 个异常值")
        print(f"异常值边界: [{lower:.4f}, {upper:.4f}]")
        return outliers, (lower, upper)
    
    def visualize_data(self, columns=None):
        """数据可视化"""
        if self.data is None:
            print("请先加载数据")
            return
        
        # 如果未指定列，默认分析所有数值型列（最多4列）
        if columns is None:
            columns = self.numeric_columns[:4]
        else:
            columns = [col for col in columns if col in self.numeric_columns]
        
        if not columns:
            print("没有有效的数值型列可可视化")
            return
        
        # 创建可视化图表
        n_cols = 2
        n_rows = (len(columns) + 1) // n_cols
        fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 5 * n_rows))
        axes = axes.flatten() if n_rows * n_cols > 1 else [axes]
        
        for i, col in enumerate(columns):
            # 直方图
            sns.histplot(self.data[col].dropna(), kde=True, ax=axes[i])
            axes[i].set_title(f'{col} 数据分布')
            
            # 标记异常值边界（IQR方法）
            _, (lower, upper) = self.detect_outliers(col, method='iqr')
            if lower is not None and upper is not None:
                axes[i].axvline(lower, color='r', linestyle='--', label=f'下界: {lower:.2f}')
                axes[i].axvline(upper, color='r', linestyle='--', label=f'上界: {upper:.2f}')
                axes[i].legend()
        
        # 隐藏未使用的子图
        for i in range(len(columns), len(axes)):
            axes[i].axis('off')
        
        plt.tight_layout()
        plt.show()
        
        # 箱线图
        plt.figure(figsize=(10, 6))
        sns.boxplot(data=self.data[columns])
        plt.title('各列数据箱线图（异常值检测）')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
    
    def analyze_correlation(self):
        """分析数值型列之间的相关性"""
        if self.data is None:
            print("请先加载数据")
            return
        
        if len(self.numeric_columns) < 2:
            print("数值型列不足，无法分析相关性")
            return
        
        # 计算相关系数
        corr_matrix = self.data[self.numeric_columns].corr()
        print("\n===== 列间相关系数矩阵 =====")
        print(corr_matrix.round(4))
        
        # 热力图可视化
        plt.figure(figsize=(10, 8))
        sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt='.2f')
        plt.title('列间相关性热力图')
        plt.tight_layout()
        plt.show()

import matplotlib.pyplot as plt

# 指定使用 SimHei 字体
plt.rcParams["font.family"] = ["SimHei"]
# 解决负号显示问题
plt.rcParams["axes.unicode_minus"] = False

# 使用示例
if __name__ == "__main__":
    # 替换为你的数据文件路径
    file_path = "HW3_SEC.xlsx"
    
    # 创建分析器实例
    analyzer = DataAnalyzer(file_path)
    
    # 加载数据
    if analyzer.load_data():
        # 基本统计分析
        analyzer.basic_statistics()
        
        # 异常值检测（以第一列为例）
        if analyzer.numeric_columns:
            first_col = analyzer.numeric_columns[0]
            analyzer.detect_outliers(first_col, method='iqr')
            analyzer.detect_outliers(first_col, method='zscore')
        
        # 数据可视化
        analyzer.visualize_data()
# Out:
# 数据读取成功，共 4031 行，18 列
# 检测到数值型列: ['价格（单位：万）', '每平方米价格（单位：元/㎡）', '室数', '厅数', '面积（单位：㎡）', '层数', '层级（底层-0，低层-1，中层-2，高层-3，顶层-4）', '朝向（南向-0，南北向-1，东南向-2，东向-3，西南向-4，西南北向-5）', '距离地铁站距离（单位：米）']
#
# ===== 基本统计信息 =====
#          价格（单位：万）  每平方米价格（单位：元/㎡）         室数         厅数   面积（单位：㎡）         层数  \
# count   4031.0000       4031.0000  4031.0000  4031.0000  4031.0000  3850.0000
# mean     743.9419      70488.8948     2.3706     1.6095    99.8518    13.1273
# std      563.4657      24856.0656     0.8510     0.5691    70.9087     8.4579
# min      118.0000      14057.0000     1.0000     0.0000    26.2800     1.0000
# 25%      350.0000      49481.0000     2.0000     1.0000    64.1700     6.0000
# 50%      620.0000      67369.0000     2.0000     2.0000    92.2300    11.0000
# 75%      990.0000      87393.0000     3.0000     2.0000   124.0000    18.0000
# max     9800.0000     178663.0000    11.0000     8.0000  2705.0000    37.0000
# median   620.0000      67369.0000     2.0000     2.0000    92.2300    11.0000
# cv         0.7574          0.3526     0.3590     0.3536     0.7101     0.6443
#
#         层级（底层-0，低层-1，中层-2，高层-3，顶层-4）  朝向（南向-0，南北向-1，东南向-2，东向-3，西南向-4，西南北向-5）  \
# count                      3850.0000                               3985.0000
# mean                          2.1621                                  0.4700
# std                           0.9837                                  0.6055
# min                           0.0000                                  0.0000
# 25%                           2.0000                                  0.0000
# 50%                           2.0000                                  0.0000
# 75%                           3.0000                                  1.0000
# max                           4.0000                                  5.0000
# median                        2.0000                                  0.0000
# cv                            0.4550                                  1.2883
#
#         距离地铁站距离（单位：米）
# count       3652.0000
# mean         588.8582
# std          236.6137
# min           47.0000
# 25%          408.0000
# 50%          580.5000
# 75%          736.0000
# max         1180.0000
# median       580.5000
# cv             0.4018
#
# 价格（单位：万）列使用iqr方法检测到 96 个异常值
# 异常值边界: [-610.0000, 1950.0000]
#
# 价格（单位：万）列使用zscore方法检测到 43 个异常值
# 异常值边界: [-946.4552, 2434.3391]
#
# 价格（单位：万）列使用iqr方法检测到 96 个异常值
# 异常值边界: [-610.0000, 1950.0000]
#
# 每平方米价格（单位：元/㎡）列使用iqr方法检测到 16 个异常值
# 异常值边界: [-7387.0000, 144261.0000]
#
# 室数列使用iqr方法检测到 54 个异常值
# 异常值边界: [0.5000, 4.5000]
#
# 厅数列使用iqr方法检测到 9 个异常值
# 异常值边界: [-0.5000, 3.5000]

# %%
#剔除异常值
clean_gumei_SEC=remove_outliers_from_list(gumei_SEC_price, method='iqr')
clean_shibo_SEC=remove_outliers_from_list(shibo_SEC_price, method='iqr')
clean_xuhui_SEC=remove_outliers_from_list(xuhui_SEC_price, method='iqr')
clean_zhangjiang_SEC=remove_outliers_from_list(zhangjiang_SEC_price, method='iqr')
#求中位数
gumei_median_SEC = statistics.median(clean_gumei_SEC)
shibo_median_SEC = statistics.median(clean_shibo_SEC)
xuhui_median_SEC = statistics.median(clean_xuhui_SEC)
zhangjiang_median_SEC = statistics.median(clean_zhangjiang_SEC)

print("古美每平方米二手房价格的中位数为：", gumei_median_SEC)
print("世博每平方米二手房价格的中位数为：", shibo_median_SEC)
print("徐汇每平方米二手房价格的中位数为：", xuhui_median_SEC)
print("张江每平方米二手房价格的中位数为：", zhangjiang_median_SEC)
# Out:
# IQR方法：下限=10690.38, 上限=127403.38
# IQR方法：下限=13261.62, 上限=102754.62
# IQR方法：下限=41358.38, 上限=136197.38
# IQR方法：下限=-7163.50, 上限=123216.50
# 古美每平方米二手房价格的中位数为： 67387
# 世博每平方米二手房价格的中位数为： 53668
# 徐汇每平方米二手房价格的中位数为： 87830.5
# 张江每平方米二手房价格的中位数为： 50403

# %%
#计算比率
gumei_ratio=gumei_median_SEC/gumei_median
shibo_ratio=shibo_median_SEC/shibo_median
xuhui_ratio=xuhui_median_SEC/xuhui_median
zhangjiang_ratio=zhangjiang_median_SEC/zhangjiang_median

# %%
import matplotlib.pyplot as plt

# 区域名称
regions = ['古美', '世博', '徐汇', '张江']
ratios = [gumei_ratio, shibo_ratio, xuhui_ratio, zhangjiang_ratio]

# 指定支持中文的字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 这里设置为黑体，也可换成其他支持中文的字体，如 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 创建柱状图
plt.bar(regions, ratios)

# 添加标题和坐标轴标签
plt.title('各区域 Ratio 柱状图')
plt.xlabel('区域')
plt.ylabel('Ratio 值')

# 显示图形
plt.show()

# %%
#作业二

# %%
#模型一的方程为price/m2i = β0m2i + β2locationi + ϵi
import pandas as pd
import statsmodels.api as sm

# 读取Excel数据
df1 = pd.read_excel("HW3_SEC.xlsx", sheet_name=0)

# 1. 处理区域虚拟变量（R列对应索引17）
# 定义区域到虚拟变量的映射：古美=0，世博=1，徐汇=2，张江=3
region_mapping = {"古美": 0, "世博": 1, "徐汇": 2, "张江": 3}

# 将R列区域数据转换为虚拟变量，存储在新列
df1['location_dummy'] = df1.iloc[:, 17].map(region_mapping)

# 2. 提取m2数据（G列对应索引6）
df1['m2'] = df1.iloc[:, 6]

# 3. 提取rent/m2数据（C列对应索引2）
df1['rent_per_m2'] = df1.iloc[:, 2]

# 4. 处理缺失值（删除包含缺失值的行）
df1_clean = df1.dropna(subset=['location_dummy', 'm2', 'rent_per_m2'])

# 5. 构建回归模型：rent_per_m2 = β0 + β1*m2 + β2*location_dummy + ε
# 添加常数项
X = sm.add_constant(df1_clean[['m2', 'location_dummy']])
# 因变量
y = df1_clean['rent_per_m2']

# 拟合OLS回归模型
model = sm.OLS(y, X)
results = model.fit()

# 6. 输出回归结果
print("回归系数：")
print(results.params)
print("\n完整回归统计结果：")
print(results.summary())
# Out:
# 回归系数：
# const             62395.161567
# m2                   79.717170
# location_dummy       77.278566
# dtype: float64
#
# 完整回归统计结果：
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            rent_per_m2   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     110.2
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           2.66e-47
# Time:                        09:10:10   Log-Likelihood:                -46409.
# No. Observations:                4031   AIC:                         9.282e+04
# Df Residuals:                    4028   BIC:                         9.284e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            6.24e+04    899.259     69.385      0.000    6.06e+04    6.42e+04
# m2                79.7172      5.400     14.761      0.000      69.129      90.305
# location_dummy    77.2786    381.842      0.202      0.840    -671.343     825.900
# ==============================================================================
# Omnibus:                      362.284   Durbin-Watson:                   1.447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2286.388
# Skew:                           0.144   Prob(JB):                         0.00
# Kurtosis:                       6.678   Cond. No.                         302.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 设置中文显示
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 1. 读取数据
df1 = pd.read_excel("HW3_SEC.xlsx", sheet_name=0)

# 2. 数据预处理
## 2.1 提取所需列（根据实际列位置调整索引）
# R列：区域信息（索引17）
# G列：m2数据（索引6）
# C列：租金/平米数据（索引2）
df1 = df1.iloc[:, [17, 6, 2]].copy()  # 只保留需要的列
df1.columns = ['location', 'm2', 'rent_per_m2']  # 重命名列便于处理

## 2.2 转换区域为虚拟变量（古美=0，世博=1，徐汇=2，张江=3）
region_mapping = {"古美": 0, "世博": 1, "徐汇": 2, "张江": 3}
df1['location_dummy'] = df1['location'].map(region_mapping)

## 2.3 处理异常值和缺失值
# 去除缺失值
df1 = df1.dropna(subset=['location_dummy', 'm2', 'rent_per_m2'])

# 处理租金异常值（使用IQR方法）
def remove_outliers(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    return df[(df[column] >= lower) & (df[column] <= upper)]

df_clean = remove_outliers(df1, 'rent_per_m2')
print(f"数据清洗后保留 {len(df_clean)} 条记录（原始 {len(df1)} 条）")

# 3. 构建回归模型
## 模型：rent_per_m2 = β0 + β1*m2 + β2*location_dummy + ε
X = sm.add_constant(df_clean[['m2', 'location_dummy']])  # 加入常数项
y = df_clean['rent_per_m2']

# 拟合模型
model = sm.OLS(y, X)
results = model.fit()

# 4. 输出回归结果
print("\n===== 租房价格回归结果 =====")
print(results.summary())


# 6. 提取并打印关键系数
print("\n===== 回归系数 =====")
print(f"常数项 (β0): {results.params['const']:.2f}")
print(f"面积系数 (β1): {results.params['m2']:.2f}")
print(f"区域系数 (β2): {results.params['location_dummy']:.2f}")
# Out:
# 数据清洗后保留 4015 条记录（原始 4031 条）
#
# ===== 租房价格回归结果 =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            rent_per_m2   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     101.8
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           7.51e-44
# Time:                        10:03:10   Log-Likelihood:                -46143.
# No. Observations:                4015   AIC:                         9.229e+04
# Df Residuals:                    4012   BIC:                         9.231e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           6.294e+04    882.959     71.278      0.000    6.12e+04    6.47e+04
# m2                75.8361      5.322     14.249      0.000      65.401      86.271
# location_dummy  -195.1164    374.959     -0.520      0.603    -930.244     540.011
# ==============================================================================
# Omnibus:                      300.512   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1569.258
# Skew:                           0.107   Prob(JB):                         0.00
# Kurtosis:                       6.055   Cond. No.                         301.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ===== 回归系数 =====
# 常数项 (β0): 62935.98
# 面积系数 (β1): 75.84
# 区域系数 (β2): -195.12

# %%
import numpy as np
import matplotlib.pyplot as plt
# 确保中文正常显示
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 二手房回归系数
sec_const = 62395.161567
sec_m2 = 79.717170
sec_location = 77.278566

# 租房回归系数
rent_const = 62935.98
rent_m2 = 75.84
rent_location = -195.12

# 生成模拟数据的数量
n_samples = 50000
# 区域列表
regions = ['古美', '世博', '徐汇', '张江']
# 区域虚拟变量值
region_dummies = [0, 1, 2, 3]

# 存储每个区域的比率结果
region_ratios = {region: [] for region in regions}

# 生成模拟数据并计算比率
for i, region in enumerate(regions):
    loc_dummy = region_dummies[i]
    # 生成m2数据（假设在合理范围内，如50到200）
    m2 = np.random.uniform(50, 200, n_samples)
    # 生成二手房价格
    sec_price = sec_const + sec_m2 * m2 + sec_location * loc_dummy
    # 生成租房价格
    rent_price = rent_const + rent_m2 * m2 + rent_location * loc_dummy
    # 计算比率（二手房价格 / 租房价格 * 100），并处理可能的除零情况
    ratio = np.where(rent_price != 0, (sec_price / rent_price) * 100, np.nan)
    ratio = ratio[~np.isnan(ratio)]  # 去除NaN值
    region_ratios[region] = ratio

# 计算每个区域比率的中位数
medians = {region: np.median(ratios) for region, ratios in region_ratios.items()}

# 绘制柱状图展示各区域比率中位数
plt.figure(figsize=(10, 6))
x = np.arange(len(regions))
plt.bar(x, medians.values(), width=0.6, align='center')
plt.xticks(x, regions)
plt.title('各区域二手房与租房价格比率中位数')
plt.xlabel('区域')
plt.ylabel('比率（二手房价格/租房价格×100）')
# 在柱子上标注中位数数值
for i, v in enumerate(medians.values()):
    plt.text(i, v + 1, f'{v:.2f}', ha='center')
plt.show()

# %%
#作业三

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# 设置中文显示
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 1. 读取数据
df1 = pd.read_excel("HW3_SEC.xlsx", sheet_name=0)

# 2. 数据预处理
## 2.1 提取所需列并命名
# R列: location数据（索引17）
# G列: m2数据（索引6）
# C列: price/m2数据（索引2）
df1 = df1.iloc[:, [17, 6, 2]].copy()
df1.columns = ['location', 'm2', 'price_per_m2']

## 2.2 转换区域为虚拟变量（古美=0，世博=1，徐汇=2，张江=3）
region_mapping = {"古美": 0, "世博": 1, "徐汇": 2, "张江": 3}
df1['location_dummy'] = df1['location'].map(region_mapping)

## 2.3 创建二次项和交互项
df1['m2_squared'] = df1['m2'] ** 2  # m2的平方项
df1['m2_location'] = df1['m2'] * df1['location_dummy']  # m2与区域的交互项

## 2.4 处理缺失值
df_clean = df1.dropna(subset=['location_dummy', 'm2', 'price_per_m2', 'm2_squared', 'm2_location'])
print(f"数据清洗后保留 {len(df_clean)} 条记录（原始 {len(df1)} 条）")

# 3. 构建回归模型
## 模型: price/m2 = alpha1 + alpha2*m2 + alpha3*(m2)^2 + alpha4*location + alpha5*m2*location + epsilon
X = df_clean[['m2', 'm2_squared', 'location_dummy', 'm2_location']]
X = sm.add_constant(X)  # 添加常数项（alpha1）
y = df_clean['price_per_m2']

# 拟合模型
model = sm.OLS(y, X)
results = model.fit()

# 4. 输出回归结果
print("\n===== 回归模型结果 =====")
print(results.summary())

# 5. 提取回归系数
print("\n===== 回归系数 =====")
print(f"alpha1 (常数项): {results.params['const']:.4f}")
print(f"alpha2 (m2系数): {results.params['m2']:.4f}")
print(f"alpha3 (m2平方项系数): {results.params['m2_squared']:.4f}")
print(f"alpha4 (区域系数): {results.params['location_dummy']:.4f}")
print(f"alpha5 (m2与区域交互项系数): {results.params['m2_location']:.4f}")
# Out:
# 数据清洗后保留 4031 条记录（原始 4031 条）
#
# ===== 回归模型结果 =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           price_per_m2   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     198.7
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          1.03e-155
# Time:                        10:15:30   Log-Likelihood:                -46153.
# No. Observations:                4031   AIC:                         9.232e+04
# Df Residuals:                    4026   BIC:                         9.235e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            4.18e+04   1694.205     24.675      0.000    3.85e+04    4.51e+04
# m2               308.7780     15.694     19.675      0.000     278.009     339.547
# m2_squared        -0.0784      0.006    -13.068      0.000      -0.090      -0.067
# location_dummy  3362.8130    893.662      3.763      0.000    1610.740    5114.886
# m2_location      -37.8851      8.025     -4.721      0.000     -53.619     -22.152
# ==============================================================================
# Omnibus:                      204.760   Durbin-Watson:                   1.489
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              236.182
# Skew:                           0.573   Prob(JB):                     5.17e-52
# Kurtosis:                       3.307   Cond. No.                     7.70e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.7e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== 回归系数 =====
# alpha1 (常数项): 41804.2115
# alpha2 (m2系数): 308.7780
# alpha3 (m2平方项系数): -0.0784
# alpha4 (区域系数): 3362.8130
# alpha5 (m2与区域交互项系数): -37.8851

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt


# 1. 读取数据
df = pd.read_excel("HW3_RENT.xlsx", sheet_name=0)

# 2. 数据预处理
## 2.1 提取所需列并命名
# N列: location数据（索引13）
# I列: m2数据（索引8）
# R列: rent/m2数据（索引17）
df = df.iloc[:, [13, 8, 17]].copy()
df.columns = ['location', 'm2', 'rent_per_m2']

## 2.2 转换区域为虚拟变量（古美=0，世博=1，徐汇=2，张江=3）
region_mapping = {"古美": 0, "世博": 1, "徐汇": 2, "张江": 3}
df['location_dummy'] = df['location'].map(region_mapping)

## 2.3 创建二次项和交互项
df['m2_squared'] = df['m2'] **2  # m2的平方项
df['m2_location'] = df['m2'] * df['location_dummy']  # m2与区域的交互项

## 2.4 处理缺失值
df_clean = df.dropna(subset=['location_dummy', 'm2', 'rent_per_m2', 'm2_squared', 'm2_location'])
print(f"数据清洗后保留 {len(df_clean)} 条记录（原始 {len(df)} 条）")

# 3. 构建回归模型
## 模型: rent/m2 = alpha1 + alpha2*m2 + alpha3*(m2)^2 + alpha4*location + alpha5*m2*location + epsilon
# 注意：修正了原公式中alpha3重复的问题，将location项系数改为alpha4
X = df_clean[['m2', 'm2_squared', 'location_dummy', 'm2_location']]
X = sm.add_constant(X)  # 添加常数项（alpha1）
y = df_clean['rent_per_m2']

# 拟合模型
model = sm.OLS(y, X)
results = model.fit()

# 4. 输出回归结果
print("\n===== 回归模型结果 =====")
print(results.summary())

# 5. 提取回归系数
print("\n===== 回归系数 =====")
print(f"alpha1 (常数项): {results.params['const']:.4f}")
print(f"alpha2 (m2系数): {results.params['m2']:.4f}")
print(f"alpha3 (m2平方项系数): {results.params['m2_squared']:.4f}")
print(f"alpha4 (区域系数): {results.params['location_dummy']:.4f}")
print(f"alpha5 (m2与区域交互项系数): {results.params['m2_location']:.4f}")
# Out:
# 数据清洗后保留 4182 条记录（原始 4182 条）
#
# ===== 回归模型结果 =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            rent_per_m2   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     25.26
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.05e-20
# Time:                        10:19:01   Log-Likelihood:                -20621.
# No. Observations:                4182   AIC:                         4.125e+04
# Df Residuals:                    4177   BIC:                         4.128e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             91.5015      1.721     53.174      0.000      88.128      94.875
# m2                 0.1747      0.021      8.506      0.000       0.134       0.215
# m2_squared     -5.636e-06   1.32e-06     -4.268      0.000   -8.23e-06   -3.05e-06
# location_dummy     2.9530      0.779      3.791      0.000       1.426       4.480
# m2_location       -0.0708      0.009     -7.641      0.000      -0.089      -0.053
# ==============================================================================
# Omnibus:                      523.681   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              838.762
# Skew:                           0.873   Prob(JB):                    7.33e-183
# Kurtosis:                       4.329   Cond. No.                     5.00e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  5e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== 回归系数 =====
# alpha1 (常数项): 91.5015
# alpha2 (m2系数): 0.1747
# alpha3 (m2平方项系数): -0.0000
# alpha4 (区域系数): 2.9530
# alpha5 (m2与区域交互项系数): -0.0708

# %%
import numpy as np
import matplotlib.pyplot as plt
# 确保中文正常显示
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 租房回归系数
rent_alpha1 = 91.5015
rent_alpha2 = 0.1747
rent_alpha3 = -0.0000
rent_alpha4 = 2.9530
rent_alpha5 = -0.0708

# 二手房回归系数
sec_alpha1 = 41804.2115
sec_alpha2 = 308.7780
sec_alpha3 = -0.0784
sec_alpha4 = 3362.8130
sec_alpha5 = -37.8851

# 生成模拟数据的数量
n_samples = 50000
# 区域列表
regions = ['古美', '世博', '徐汇', '张江']
# 区域虚拟变量值
region_dummies = [0, 1, 2, 3]

# 存储每个区域的比率结果
region_ratios = {region: [] for region in regions}

# 生成模拟数据并计算比率
for i, region in enumerate(regions):
    loc_dummy = region_dummies[i]
    # 生成m2数据（假设在合理范围内，如50到200）
    m2 = np.random.uniform(50, 200, n_samples)
    # 生成租房价格
    rent_price = rent_alpha1 + rent_alpha2 * m2 + rent_alpha3 * m2**2 + rent_alpha4 * loc_dummy + rent_alpha5 * m2 * loc_dummy
    # 生成二手房价格
    sec_price = sec_alpha1 + sec_alpha2 * m2 + sec_alpha3 * m2**2 + sec_alpha4 * loc_dummy + sec_alpha5 * m2 * loc_dummy
    # 计算比率（二手房价格 / 租房价格），并处理可能的除零情况
    ratio = np.where(rent_price != 0, sec_price / rent_price, np.nan)
    ratio = ratio[~np.isnan(ratio)]  # 去除NaN值
    region_ratios[region] = ratio

# 计算每个区域比率的中位数
medians = {region: np.median(ratios) for region, ratios in region_ratios.items()}

# 绘制柱状图展示各区域比率中位数
plt.figure(figsize=(10, 6))
x = np.arange(len(regions))
plt.bar(x, medians.values(), width=0.6, align='center')
plt.xticks(x, regions)
plt.title('各区域二手房与租房价格比率中位数')
plt.xlabel('区域')
plt.ylabel('比率（二手房价格/租房价格）')
# 在柱子上标注中位数数值
for i, v in enumerate(medians.values()):
    plt.text(i, v + 1, f'{v:.2f}', ha='center')
plt.show()

# %%
#对比三张柱状图，最后一种模型效果最好，使用样本量最大。第一种模型使用数据较少，计算具有偶然性。第二种模型R方小，预测能力差，与实际情况差异较大。

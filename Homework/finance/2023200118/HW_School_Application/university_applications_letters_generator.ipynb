# %%
# docxtpl & docx2pdf
# !pip install docxtpl
# !pip install docx2pdf
# Out:
# Requirement already satisfied: docxtpl in d:\anaconda\lib\site-packages (0.20.1)
# Requirement already satisfied: python-docx>=1.1.1 in d:\anaconda\lib\site-packages (from docxtpl) (1.2.0)
# Requirement already satisfied: docxcompose in d:\anaconda\lib\site-packages (from docxtpl) (1.4.0)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from docxtpl) (3.1.4)
# Requirement already satisfied: lxml in d:\anaconda\lib\site-packages (from docxtpl) (5.2.1)
# Requirement already satisfied: typing_extensions>=4.9.0 in d:\anaconda\lib\site-packages (from python-docx>=1.1.1->docxtpl) (4.15.0)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from docxcompose->docxtpl) (75.1.0)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from docxcompose->docxtpl) (1.16.0)
# Requirement already satisfied: babel in d:\anaconda\lib\site-packages (from docxcompose->docxtpl) (2.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->docxtpl) (2.1.3)
# Requirement already satisfied: pytz>=2015.7 in d:\anaconda\lib\site-packages (from babel->docxcompose->docxtpl) (2024.1)
# Requirement already satisfied: docx2pdf in d:\anaconda\lib\site-packages (0.1.8)
# Requirement already satisfied: pywin32>=227 in d:\anaconda\lib\site-packages (from docx2pdf) (305.1)
# Requirement already satisfied: tqdm>=4.41.0 in d:\anaconda\lib\site-packages (from docx2pdf) (4.66.5)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.41.0->docx2pdf) (0.4.6)

# %%
import os
from pathlib import Path
import pandas as pd
from docxtpl import DocxTemplate
import platform
from docx2pdf import convert as docx2pdf_convert

# 路径设置
OUT_DIR = Path(r"D:\Quant\Homework\Homework_2\School_Application")
OUT_DIR.mkdir(parents=True, exist_ok=True)

UNIVERSITY_FILE = Path("university.xlsx")
RESEARCH_AREA_FILE = Path("research_area.xlsx")
TEMPLATE_FILE = Path("template.docx")

# 姓名设置
NAME = "Puwen Sun"

# Step 1: 读取Excel
df_university = pd.read_excel(UNIVERSITY_FILE)
df_research_area = pd.read_excel(RESEARCH_AREA_FILE)

# Step 2: 生成所有组合
generated_files = []

for _, row_u in df_university.iterrows():
    university = str(row_u["university"]).strip()
    
    for _, row_r in df_research_area.iterrows():
        Research_Area = str(row_r["Research_Area"]).strip()
        research_area = str(row_r["research_area"]).strip()
        journal_1 = str(row_r["journal_1"]).strip()
        journal_2 = str(row_r["journal_2"]).strip()
        journal_3 = str(row_r["journal_3"]).strip()
        career = str(row_r["career"]).strip()
        skills = str(row_r["skills"]).strip()

        # 每次都重新加载模板，防止上一次渲染残留
        tpl = DocxTemplate(str(TEMPLATE_FILE))

        # 构造模板上下文
        context = {
            "name": NAME,
            "university": university,
            "Research_Area": Research_Area,
            "research_area": research_area,
            "journal_1": journal_1,
            "journal_2": journal_2,
            "journal_3": journal_3,
            "career": career,
            "skills": skills,
        }

        # 渲染模板
        tpl.render(context)

        # 安全文件名处理
        safe_uni = "".join(c for c in university if c.isalnum() or c in (" ", "_", "-")).strip()
        safe_area = "".join(c for c in research_area if c.isalnum() or c in (" ", "_", "-")).strip()
        filename = f"SOP_{safe_uni}_{safe_area}.docx"
        output_path = OUT_DIR / filename

        # 保存 Word 文件
        tpl.save(output_path)
        generated_files.append(output_path)
        print(f"[INFO] 生成 Word: {output_path}")

# Step 3: 批量转换 PDF
if platform.system() == "Windows":
    print("\n[INFO] 开始批量转换 PDF ...")
    try:
        docx2pdf_convert(str(OUT_DIR))  # 一次性转换整个文件夹
        print("[INFO] ✅ 所有 PDF 转换完成！")
    except Exception as e:
        print(f"[WARN] PDF 批量转换失败: {e}")
else:
    print("[INFO] 非 Windows 系统，跳过 PDF 转换。")

print(f"\n✅ 已生成 {len(generated_files)} 份 Word 文件，保存在 {OUT_DIR}")
# Out:
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Harvard University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Harvard University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Harvard University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Massachusetts Institute of Technology_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Massachusetts Institute of Technology_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Massachusetts Institute of Technology_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Berkeley_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Berkeley_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Berkeley_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Chicago_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Chicago_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Chicago_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Princeton University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Princeton University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Princeton University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Stanford University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Stanford University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Stanford University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Yale University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Yale University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Yale University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Columbia University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Columbia University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Columbia University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_New York University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_New York University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_New York University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Brown University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Brown University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Brown University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Boston College_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Boston College_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Boston College_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Cornell University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Cornell University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Cornell University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Davis_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Davis_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Davis_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Johns Hopkins University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Johns Hopkins University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Johns Hopkins University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Irvine_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Irvine_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Irvine_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Maryland_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Maryland_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Maryland_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Notre Dame_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Notre Dame_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Notre Dame_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Vanderbilt University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Vanderbilt University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Vanderbilt University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Texas-Austin_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Texas-Austin_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Texas-Austin_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Cambridge_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Cambridge_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Cambridge_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Virginia_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Virginia_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Virginia_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Georgetown University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Georgetown University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Georgetown University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Minnesota_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Minnesota_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Minnesota_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Santa Barbara_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Santa Barbara_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Santa Barbara_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Washington University in St Louis_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Washington University in St Louis_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Washington University in St Louis_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Pennsylvania State University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Pennsylvania State University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Pennsylvania State University_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Colorado_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Colorado_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of Colorado_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Santa Cruz_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Santa Cruz_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_University of California-Santa Cruz_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Rutgers University-New Brunswick_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Rutgers University-New Brunswick_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Rutgers University-New Brunswick_finance.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Ohio State University_accounting.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Ohio State University_economics.docx
# [INFO] 生成 Word: D:\Quant\Homework\Homework_2\School_Application\SOP_Ohio State University_finance.docx
#
# [INFO] 开始批量转换 PDF ...
#   0%|          | 0/90 [00:00<?, ?it/s]
# [INFO] ✅ 所有 PDF 转换完成！
#
# ✅ 已生成 90 份 Word 文件，保存在 D:\Quant\Homework\Homework_2\School_Application

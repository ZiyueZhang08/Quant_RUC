# %%
pip install docxtpl doc2pdf requests beautifulsoup4 pandas openpyxl
# Out:
# Requirement already satisfied: docxtpl in d:\anaconda2025.4.20\lib\site-packages (0.20.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: doc2pdf in d:\anaconda2025.4.20\lib\site-packages (0.2.0)
# Requirement already satisfied: requests in d:\anaconda2025.4.20\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda2025.4.20\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in d:\anaconda2025.4.20\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in d:\anaconda2025.4.20\lib\site-packages (3.1.5)
# Requirement already satisfied: python-docx>=1.1.1 in d:\anaconda2025.4.20\lib\site-packages (from docxtpl) (1.2.0)
# Requirement already satisfied: docxcompose in d:\anaconda2025.4.20\lib\site-packages (from docxtpl) (1.4.0)
# Requirement already satisfied: jinja2 in d:\anaconda2025.4.20\lib\site-packages (from docxtpl) (3.1.4)
# Requirement already satisfied: lxml in d:\anaconda2025.4.20\lib\site-packages (from docxtpl) (5.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda2025.4.20\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda2025.4.20\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda2025.4.20\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda2025.4.20\lib\site-packages (from requests) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda2025.4.20\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda2025.4.20\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda2025.4.20\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda2025.4.20\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda2025.4.20\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in d:\anaconda2025.4.20\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda2025.4.20\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in d:\anaconda2025.4.20\lib\site-packages (from python-docx>=1.1.1->docxtpl) (4.15.0)
# Requirement already satisfied: setuptools in d:\anaconda2025.4.20\lib\site-packages (from docxcompose->docxtpl) (75.1.0)
# Requirement already satisfied: babel in d:\anaconda2025.4.20\lib\site-packages (from docxcompose->docxtpl) (2.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda2025.4.20\lib\site-packages (from jinja2->docxtpl) (2.1.3)

# %%
from docxtpl import DocxTemplate
import os

# %%
doc=DocxTemplate(r"D:\HuaweiMoveData\Users\24522\Desktop\application letter.docx")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import random
import itertools
import time

# %%
df1 = pd.read_excel(r"C:\Users\24522\python25\university rank.xlsx")
print(df1[:90])
# Out:
#     Rank                                        Institution
# 0      1        Department of Economics, Harvard University
# 1      2  Economics Department, Massachusetts Institute ...
# 2      3  Department of Economics, University of Califor...
# 3      4     Department of Economics, University of Chicago
# 4      5                          Paris School of Economics
# ..   ...                                                ...
# 85    86  Department of Economics, George Washington Uni...
# 86    87  Department of Economics, Mitch Daniels School ...
# 87    88  School of Economics, Faculty of Arts and Socia...
# 88    89         Department of Economics, McGill University
# 89    90  Department of Economics, University of Washington
#
# [90 rows x 2 columns]

# %%
population1=list(range(1,31))
population2=list(range(31,61))
population3=list(range(61,91))
nums1=random.sample(population1,10)
nums2=random.sample(population2,10)
nums3=random.sample(population3,10)
nums=nums1+nums2+nums3
df2=df1[df1["Rank"].isin(nums)]
df3=pd.DataFrame(df2)
df3.to_excel("chosen_universities.xlsx",index=False,engine="openpyxl")

# %%
class TemplateProcessor:
    # 1. 构建全局变量
    def __init__(self, template_file, universities_file, area_file):
        self.template_file = template_file
        self.universities_file = universities_file
        self.area_file = area_file
        self.universities_df = None
        self.area_df = None
        self.template = None
    
    # 2. 读取文件数据
    def load_data(self):
        """加载模板和数据文件"""
        try:
            self.universities_df = pd.read_excel(self.universities_file)
            self.area_df = pd.read_excel(self.area_file)
            self.template=DocxTemplate(self.template_file)
            print("数据加载成功")
            return True
        except FileNotFoundError as e:
            print(f"文件未找到: {e}")
            return False
        except Exception as e:
            print(f"数据加载失败: {e}")
            return False
    
    # 3. 对文件数据进行替换和保存
    def replace_and_save_document(self, university, area_data, output_dir="output"):
        """替换模板并保存文档"""
        try:
            if not os.path.exists(output_dir):
                os.makedirs(output_dir)
            
            # 验证数据完整性
            if not all(key in area_data for key in ['Area', 'Journal', 'Skill']):
                print(f"数据不完整: {area_data}")
                return None
            
            context = {
                "school": university,
                "major": area_data['Area'],
                "journal": area_data['Journal'],
                "skill": area_data['Skill']
            }
            
            # 4. 生成文件 - 处理文件名过长问题
            base_name = f"Application_{university}_{area_data['Area']}"
            # 清理文件名中的非法字符并限制长度
            file_name = "".join(c for c in base_name if c not in r'<>:"/\\|?*')
            # 限制文件名长度（Windows最大路径限制）
            if len(file_name) > 200:
                file_name = file_name[:200]
            file_name += ".docx"
            file_path = os.path.join(output_dir, file_name)
            
            
            template = DocxTemplate(self.template_file)
            template.render(context)
            template.save(file_path)
            
            print(f"文件已生成：{file_name}")
            return file_path
            
        except Exception as e:
            print(f"生成文档失败 {university}-{area_data.get('Area', 'Unknown')}: {e}")
            return None
    
    def onebyone(self, output_dir="applications_output"):
        """批量生成所有文档"""
        # 加载数据
        if not self.load_data():
            print("数据加载失败，无法继续")
            return
        
        # 验证数据列是否存在
        required_uni_columns = ['Institution']
        required_area_columns = ['Area', 'Journal', 'Skill']
        
        if not all(col in self.universities_df.columns for col in required_uni_columns):
            print("大学数据文件缺少必要列")
            return
            
        if not all(col in self.area_df.columns for col in required_area_columns):
            print("领域数据文件缺少必要列")
            return
        
        # 检查数据是否为空
        if self.universities_df.empty:
            print("大学数据文件为空")
            return
            
        if self.area_df.empty:
            print("领域数据文件为空")
            return
        
        file_count = 0
        success_count = 0
        
        # 遍历所有组合
        for _, uni_row in self.universities_df.iterrows():
            university = uni_row['Institution']
            # 检查大学名称是否为空
            if pd.isna(university) or str(university).strip() == "":
                print("跳过空大学名称")
                continue
                
            for _, area_row in self.area_df.iterrows():
                # 检查区域数据是否完整
                if any(pd.isna(area_row[col]) for col in ['Area', 'Journal', 'Skill']):
                    print(f"跳过不完整的数据行: {area_row}")
                    continue
                    
                file_count += 1
                area_data = {
                    'Area': area_row['Area'],
                    'Journal': area_row['Journal'],
                    'Skill': area_row['Skill']
                }
                
                result = self.replace_and_save_document(university, area_data, output_dir)
                if result:
                    success_count += 1
        
        print(f"处理完成: 成功生成 {success_count}/{file_count} 个申请文件")
        print(f"保存于 {output_dir} 目录中")

# %%
if __name__=="__main__":
    processor = TemplateProcessor(
        template_file=r"D:\HuaweiMoveData\Users\24522\Desktop\application letter.docx",
        universities_file=r"C:\Users\24522\python25\university rank.xlsx", 
        area_file=r"D:\HuaweiMoveData\Users\24522\Desktop\area.xlsx"
    )
    processor.onebyone("applications_output")
# Out:
# 文件已生成：Application_Department of Economics, Harvard University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Harvard University_ECON.docx
# 文件已生成：Application_Department of Economics, Harvard University_SOC SCI.docx
# 文件已生成：Application_Economics Department, Massachusetts Institute of Technology (MIT)_FINANCE.docx
# 文件已生成：Application_Economics Department, Massachusetts Institute of Technology (MIT)_ECON.docx
# 文件已生成：Application_Economics Department, Massachusetts Institute of Technology (MIT)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of California-Berkeley_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of California-Berkeley_ECON.docx
# 文件已生成：Application_Department of Economics, University of California-Berkeley_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Chicago_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Chicago_ECON.docx
# 文件已生成：Application_Department of Economics, University of Chicago_SOC SCI.docx
# 文件已生成：Application_Paris School of Economics_FINANCE.docx
# 文件已生成：Application_Paris School of Economics_ECON.docx
# 文件已生成：Application_Paris School of Economics_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Princeton University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Princeton University_ECON.docx
# 文件已生成：Application_Department of Economics, Princeton University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Stanford University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Stanford University_ECON.docx
# 文件已生成：Application_Department of Economics, Stanford University_SOC SCI.docx
# 文件已生成：Application_Economics Department, Yale University_FINANCE.docx
# 文件已生成：Application_Economics Department, Yale University_ECON.docx
# 文件已生成：Application_Economics Department, Yale University_SOC SCI.docx
# 文件已生成：Application_Toulouse School of Economics (TSE)_FINANCE.docx
# 文件已生成：Application_Toulouse School of Economics (TSE)_ECON.docx
# 文件已生成：Application_Toulouse School of Economics (TSE)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Oxford University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Oxford University_ECON.docx
# 文件已生成：Application_Department of Economics, Oxford University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, School of Arts and Sciences, Columbia University_FINANCE.docx
# 文件已生成：Application_Department of Economics, School of Arts and Sciences, Columbia University_ECON.docx
# 文件已生成：Application_Department of Economics, School of Arts and Sciences, Columbia University_SOC SCI.docx
# 文件已生成：Application_Barcelona School of Economics (BSE)_FINANCE.docx
# 文件已生成：Application_Barcelona School of Economics (BSE)_ECON.docx
# 文件已生成：Application_Barcelona School of Economics (BSE)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, New York University (NYU)_FINANCE.docx
# 文件已生成：Application_Department of Economics, New York University (NYU)_ECON.docx
# 文件已生成：Application_Department of Economics, New York University (NYU)_SOC SCI.docx
# 文件已生成：Application_Economics Department, Brown University_FINANCE.docx
# 文件已生成：Application_Economics Department, Brown University_ECON.docx
# 文件已生成：Application_Economics Department, Brown University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Pennsylvania_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Pennsylvania_ECON.docx
# 文件已生成：Application_Department of Economics, University of Pennsylvania_SOC SCI.docx
# 文件已生成：Application_Economics Department, London School of Economics (LSE)_FINANCE.docx
# 文件已生成：Application_Economics Department, London School of Economics (LSE)_ECON.docx
# 文件已生成：Application_Economics Department, London School of Economics (LSE)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Boston University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Boston University_ECON.docx
# 文件已生成：Application_Department of Economics, Boston University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University College London (UCL)_FINANCE.docx
# 文件已生成：Application_Department of Economics, University College London (UCL)_ECON.docx
# 文件已生成：Application_Department of Economics, University College London (UCL)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of California-San Diego (UCSD)_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of California-San Diego (UCSD)_ECON.docx
# 文件已生成：Application_Department of Economics, University of California-San Diego (UCSD)_SOC SCI.docx
# 文件已生成：Application_Economics Department, University of Michigan_FINANCE.docx
# 文件已生成：Application_Economics Department, University of Michigan_ECON.docx
# 文件已生成：Application_Economics Department, University of Michigan_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Northwestern University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Northwestern University_ECON.docx
# 文件已生成：Application_Department of Economics, Northwestern University_SOC SCI.docx
# 文件已生成：Application_Economics Department, Dartmouth College_FINANCE.docx
# 文件已生成：Application_Economics Department, Dartmouth College_ECON.docx
# 文件已生成：Application_Economics Department, Dartmouth College_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Southern California_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Southern California_ECON.docx
# 文件已生成：Application_Department of Economics, University of Southern California_SOC SCI.docx
# 文件已生成：Application_School of Economics and Management, Universiteit van Tilburg_FINANCE.docx
# 文件已生成：Application_School of Economics and Management, Universiteit van Tilburg_ECON.docx
# 文件已生成：Application_School of Economics and Management, Universiteit van Tilburg_SOC SCI.docx
# 文件已生成：Application_Vancouver School of Economics, University of British Columbia_FINANCE.docx
# 文件已生成：Application_Vancouver School of Economics, University of British Columbia_ECON.docx
# 文件已生成：Application_Vancouver School of Economics, University of British Columbia_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of California-Los Angeles (UCLA)_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of California-Los Angeles (UCLA)_ECON.docx
# 文件已生成：Application_Department of Economics, University of California-Los Angeles (UCLA)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Duke University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Duke University_ECON.docx
# 文件已生成：Application_Department of Economics, Duke University_SOC SCI.docx
# 文件已生成：Application_Economics Department, University of Wisconsin-Madison_FINANCE.docx
# 文件已生成：Application_Economics Department, University of Wisconsin-Madison_ECON.docx
# 文件已生成：Application_Economics Department, University of Wisconsin-Madison_SOC SCI.docx
# 文件已生成：Application_Institut für Volkswirtschaftslehre, Wirtschaftswissenschaftliche Fakutält, Universität Zürich_FINANCE.docx
# 文件已生成：Application_Institut für Volkswirtschaftslehre, Wirtschaftswissenschaftliche Fakutält, Universität Zürich_ECON.docx
# 文件已生成：Application_Institut für Volkswirtschaftslehre, Wirtschaftswissenschaftliche Fakutält, Universität Zürich_SOC SCI.docx
# 文件已生成：Application_Economics Department, Michigan State University_FINANCE.docx
# 文件已生成：Application_Economics Department, Michigan State University_ECON.docx
# 文件已生成：Application_Economics Department, Michigan State University_SOC SCI.docx
# 文件已生成：Application_Finance and Economics Department, Graduate School of Business, Columbia University_FINANCE.docx
# 文件已生成：Application_Finance and Economics Department, Graduate School of Business, Columbia University_ECON.docx
# 文件已生成：Application_Finance and Economics Department, Graduate School of Business, Columbia University_SOC SCI.docx
# 文件已生成：Application_Faculty of Economics, University of Cambridge_FINANCE.docx
# 文件已生成：Application_Faculty of Economics, University of Cambridge_ECON.docx
# 文件已生成：Application_Faculty of Economics, University of Cambridge_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Boston College_FINANCE.docx
# 文件已生成：Application_Department of Economics, Boston College_ECON.docx
# 文件已生成：Application_Department of Economics, Boston College_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Toronto_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Toronto_ECON.docx
# 文件已生成：Application_Department of Economics, University of Toronto_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Warwick_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Warwick_ECON.docx
# 文件已生成：Application_Department of Economics, University of Warwick_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Cornell University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Cornell University_ECON.docx
# 文件已生成：Application_Department of Economics, Cornell University_SOC SCI.docx
# 文件已生成：Application_Economics Department, University of California-Davis_FINANCE.docx
# 文件已生成：Application_Economics Department, University of California-Davis_ECON.docx
# 文件已生成：Application_Economics Department, University of California-Davis_SOC SCI.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfskunde, Rijksuniversiteit Groningen_FINANCE.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfskunde, Rijksuniversiteit Groningen_ECON.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfskunde, Rijksuniversiteit Groningen_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Johns Hopkins University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Johns Hopkins University_ECON.docx
# 文件已生成：Application_Department of Economics, Johns Hopkins University_SOC SCI.docx
# 文件已生成：Application_Dipartimento di Scienze Economiche, Alma Mater Studiorum - Università di Bologna_FINANCE.docx
# 文件已生成：Application_Dipartimento di Scienze Economiche, Alma Mater Studiorum - Università di Bologna_ECON.docx
# 文件已生成：Application_Dipartimento di Scienze Economiche, Alma Mater Studiorum - Università di Bologna_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Sciences économiques, Sciences Po_FINANCE.docx
# 文件已生成：Application_Department of Economics, Sciences économiques, Sciences Po_ECON.docx
# 文件已生成：Application_Department of Economics, Sciences économiques, Sciences Po_SOC SCI.docx
# 文件已生成：Application_School of Economics, University of Nottingham_FINANCE.docx
# 文件已生成：Application_School of Economics, University of Nottingham_ECON.docx
# 文件已生成：Application_School of Economics, University of Nottingham_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of California-Irvine_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of California-Irvine_ECON.docx
# 文件已生成：Application_Department of Economics, University of California-Irvine_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Monash Business School, Monash University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Monash Business School, Monash University_ECON.docx
# 文件已生成：Application_Department of Economics, Monash Business School, Monash University_SOC SCI.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfswetenschappen, KU Leuven_FINANCE.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfswetenschappen, KU Leuven_ECON.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfswetenschappen, KU Leuven_SOC SCI.docx
# 文件已生成：Application_Institut for Økonomi, Aarhus Universitet_FINANCE.docx
# 文件已生成：Application_Institut for Økonomi, Aarhus Universitet_ECON.docx
# 文件已生成：Application_Institut for Økonomi, Aarhus Universitet_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Maryland_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Maryland_ECON.docx
# 文件已生成：Application_Department of Economics, University of Maryland_SOC SCI.docx
# 文件已生成：Application_École d'Économie d'Aix-Marseille, Aix-Marseille Université_FINANCE.docx
# 文件已生成：Application_École d'Économie d'Aix-Marseille, Aix-Marseille Université_ECON.docx
# 文件已生成：Application_École d'Économie d'Aix-Marseille, Aix-Marseille Université_SOC SCI.docx
# 文件已生成：Application_School of Business and Economics, Vrije Universiteit Amsterdam_FINANCE.docx
# 文件已生成：Application_School of Business and Economics, Vrije Universiteit Amsterdam_ECON.docx
# 文件已生成：Application_School of Business and Economics, Vrije Universiteit Amsterdam_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Notre Dame_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Notre Dame_ECON.docx
# 文件已生成：Application_Department of Economics, University of Notre Dame_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Vanderbilt University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Vanderbilt University_ECON.docx
# 文件已生成：Application_Department of Economics, Vanderbilt University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Texas-Austin_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Texas-Austin_ECON.docx
# 文件已生成：Application_Department of Economics, University of Texas-Austin_SOC SCI.docx
# 文件已生成：Application_Centro de Estudios Monetarios y Financieros (CEMFI)_FINANCE.docx
# 文件已生成：Application_Centro de Estudios Monetarios y Financieros (CEMFI)_ECON.docx
# 文件已生成：Application_Centro de Estudios Monetarios y Financieros (CEMFI)_SOC SCI.docx
# 文件已生成：Application_Department of Economics and Related Studies, University of York_FINANCE.docx
# 文件已生成：Application_Department of Economics and Related Studies, University of York_ECON.docx
# 文件已生成：Application_Department of Economics and Related Studies, University of York_SOC SCI.docx
# 文件已生成：Application_Økonomisk Institut, Københavns Universitet_FINANCE.docx
# 文件已生成：Application_Økonomisk Institut, Københavns Universitet_ECON.docx
# 文件已生成：Application_Økonomisk Institut, Københavns Universitet_SOC SCI.docx
# 文件已生成：Application_Faculteit der Economische Wetenschappen, Erasmus Universiteit Rotterdam_FINANCE.docx
# 文件已生成：Application_Faculteit der Economische Wetenschappen, Erasmus Universiteit Rotterdam_ECON.docx
# 文件已生成：Application_Faculteit der Economische Wetenschappen, Erasmus Universiteit Rotterdam_SOC SCI.docx
# 文件已生成：Application_College of Business and Economics, Australian National University_FINANCE.docx
# 文件已生成：Application_College of Business and Economics, Australian National University_ECON.docx
# 文件已生成：Application_College of Business and Economics, Australian National University_SOC SCI.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfskunde, Universiteit van Amsterdam_FINANCE.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfskunde, Universiteit van Amsterdam_ECON.docx
# 文件已生成：Application_Faculteit Economie en Bedrijfskunde, Universiteit van Amsterdam_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Western Ontario_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Western Ontario_ECON.docx
# 文件已生成：Application_Department of Economics, University of Western Ontario_SOC SCI.docx
# 文件已生成：Application_Economics Department, Queen's University_FINANCE.docx
# 文件已生成：Application_Economics Department, Queen's University_ECON.docx
# 文件已生成：Application_Economics Department, Queen's University_SOC SCI.docx
# 文件已生成：Application_School of Economics, University of Queensland_FINANCE.docx
# 文件已生成：Application_School of Economics, University of Queensland_ECON.docx
# 文件已生成：Application_School of Economics, University of Queensland_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Virginia_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Virginia_ECON.docx
# 文件已生成：Application_Department of Economics, University of Virginia_SOC SCI.docx
# 文件已生成：Application_Economics Department, Georgetown University_FINANCE.docx
# 文件已生成：Application_Economics Department, Georgetown University_ECON.docx
# 文件已生成：Application_Economics Department, Georgetown University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Minnesota_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Minnesota_ECON.docx
# 文件已生成：Application_Department of Economics, University of Minnesota_SOC SCI.docx
# 文件已生成：Application_Economics Department, Stern School of Business, New York University (NYU)_FINANCE.docx
# 文件已生成：Application_Economics Department, Stern School of Business, New York University (NYU)_ECON.docx
# 文件已生成：Application_Economics Department, Stern School of Business, New York University (NYU)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of California-Santa Barbara (UCSB)_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of California-Santa Barbara (UCSB)_ECON.docx
# 文件已生成：Application_Department of Economics, University of California-Santa Barbara (UCSB)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Washington University in St. Louis_FINANCE.docx
# 文件已生成：Application_Department of Economics, Washington University in St. Louis_ECON.docx
# 文件已生成：Application_Department of Economics, Washington University in St. Louis_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Pennsylvania State University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Pennsylvania State University_ECON.docx
# 文件已生成：Application_Department of Economics, Pennsylvania State University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, University of Colorado_FINANCE.docx
# 文件已生成：Application_Department of Economics, University of Colorado_ECON.docx
# 文件已生成：Application_Department of Economics, University of Colorado_SOC SCI.docx
# 文件已生成：Application_Economics Department, University of California-Santa Cruz (UCSC)_FINANCE.docx
# 文件已生成：Application_Economics Department, University of California-Santa Cruz (UCSC)_ECON.docx
# 文件已生成：Application_Economics Department, University of California-Santa Cruz (UCSC)_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Rutgers University-New Brunswick_FINANCE.docx
# 文件已生成：Application_Department of Economics, Rutgers University-New Brunswick_ECON.docx
# 文件已生成：Application_Department of Economics, Rutgers University-New Brunswick_SOC SCI.docx
# 文件已生成：Application_Volkswirtschaftliche Fakultät, Ludwig-Maximilians-Universität München_FINANCE.docx
# 文件已生成：Application_Volkswirtschaftliche Fakultät, Ludwig-Maximilians-Universität München_ECON.docx
# 文件已生成：Application_Volkswirtschaftliche Fakultät, Ludwig-Maximilians-Universität München_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Ohio State University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Ohio State University_ECON.docx
# 文件已生成：Application_Department of Economics, Ohio State University_SOC SCI.docx
# 文件已生成：Application_School of Economics, Universitat de Barcelona_FINANCE.docx
# 文件已生成：Application_School of Economics, Universitat de Barcelona_ECON.docx
# 文件已生成：Application_School of Economics, Universitat de Barcelona_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Andrew Young School of Policy Studies, Georgia State University_FINANCE.docx
# 文件已生成：Application_Department of Economics, Andrew Young School of Policy Studies, Georgia State University_ECON.docx
# 文件已生成：Application_Department of Economics, Andrew Young School of Policy Studies, Georgia State University_SOC SCI.docx
# 文件已生成：Application_Dipartimenti e Istituti di Scienze Economiche, Università Cattolica del Sacro Cuore_FINANCE.docx
# 文件已生成：Application_Dipartimenti e Istituti di Scienze Economiche, Università Cattolica del Sacro Cuore_ECON.docx
# 文件已生成：Application_Dipartimenti e Istituti di Scienze Economiche, Università Cattolica del Sacro Cuore_SOC SCI.docx
# 文件已生成：Application_Fachbereich Wirtschaftswissenschaft, Goethe Universität Frankfurt am Main_FINANCE.docx
# 文件已生成：Application_Fachbereich Wirtschaftswissenschaft, Goethe Universität Frankfurt am Main_ECON.docx
# 文件已生成：Application_Fachbereich Wirtschaftswissenschaft, Goethe Universität Frankfurt am Main_SOC SCI.docx
# 文件已生成：Application_Eitan Berglas School of Economics, Tel Aviv University_FINANCE.docx
# 文件已生成：Application_Eitan Berglas School of Economics, Tel Aviv University_ECON.docx
# 文件已生成：Application_Eitan Berglas School of Economics, Tel Aviv University_SOC SCI.docx
# 文件已生成：Application_Departamento de Economía, Universidad Carlos III de Madrid_FINANCE.docx
# 文件已生成：Application_Departamento de Economía, Universidad Carlos III de Madrid_ECON.docx
# 文件已生成：Application_Departamento de Economía, Universidad Carlos III de Madrid_SOC SCI.docx
# 文件已生成：Application_Økonomisk institutt, Universitetet i Oslo_FINANCE.docx
# 文件已生成：Application_Økonomisk institutt, Universitetet i Oslo_ECON.docx
# 文件已生成：Application_Økonomisk institutt, Universitetet i Oslo_SOC SCI.docx
# 文件已生成：Application_School of Economics, UNSW Business School, UNSW Sydney_FINANCE.docx
# 文件已生成：Application_School of Economics, UNSW Business School, UNSW Sydney_ECON.docx
# 文件已生成：Application_School of Economics, UNSW Business School, UNSW Sydney_SOC SCI.docx
# 文件已生成：Application_Wirtschaftswissenschaftlicher Fachbereich, Rheinische Friedrich-Wilhelms-Universität Bonn_FINANCE.docx
# 文件已生成：Application_Wirtschaftswissenschaftlicher Fachbereich, Rheinische Friedrich-Wilhelms-Universität Bonn_ECON.docx
# 文件已生成：Application_Wirtschaftswissenschaftlicher Fachbereich, Rheinische Friedrich-Wilhelms-Universität Bonn_SOC SCI.docx
# 文件已生成：Application_Department of Economics, W.P. Carey School of Business, Arizona State University_FINANCE.docx
# 文件已生成：Application_Department of Economics, W.P. Carey School of Business, Arizona State University_ECON.docx
# 文件已生成：Application_Department of Economics, W.P. Carey School of Business, Arizona State University_SOC SCI.docx
# 文件已生成：Application_Department of Economics, Hebrew University of Jerusalem_FINANCE.docx
# 文件已生成：Application_Department of Economics, Hebrew University of Jerusalem_ECON.docx
# 文件已生成：Application_Department of Economics, Hebrew University of Jerusalem_SOC SCI.docx
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[74], line 7
#       1 if __name__=="__main__":
#       2     processor = TemplateProcessor(
#       3         template_file=r"D:\HuaweiMoveData\Users\24522\Desktop\application letter.docx",
#       4         universities_file=r"C:\Users\24522\python25\university rank.xlsx",
#       5         area_file=r"D:\HuaweiMoveData\Users\24522\Desktop\area.xlsx"
#       6     )
# ----> 7     processor.onebyone("applications_output")
#
# Cell In[72], line 48, in TemplateProcessor.onebyone(self, output_dir)
#      42 for _,area_row in self.area_df.iterrows():
#      43     area_data={
#      44         'Area':area_row['Area'],
#      45         'Journal':area_row['Journal'],
#      46         'Skill':area_row['Skill']
#      47     }
# ---> 48     result=self.replace_and_save_document(university,area_data,output_dir)
#      49     if result:
#      50         file+=1
#
# Cell In[72], line 31, in TemplateProcessor.replace_and_save_document(self, university, area_data, output_dir)
#      29 self.template.render(context)
#      30 #6.保存文档
# ---> 31 self.template.save(file_path)
#      32 print(f"文件已生成：{file_name}")
#      33 return file_path
#
# File D:\Anaconda2025.4.20\Lib\site-packages\docxtpl\template.py:885, in DocxTemplate.save(self, filename, *args, **kwargs)
#     883     self.docx = Document(self.template_file)
#     884 self.pre_processing()
# --> 885 self.docx.save(filename, *args, **kwargs)
#     886 self.post_processing(filename)
#     887 self.is_saved = True
#
# File D:\Anaconda2025.4.20\Lib\site-packages\docx\document.py:204, in Document.save(self, path_or_stream)
#     198 def save(self, path_or_stream: str | IO[bytes]):
#     199     """Save this document to `path_or_stream`.
#     200
#     201     `path_or_stream` can be either a path to a filesystem location (a string) or a
#     202     file-like object.
#     203     """
# --> 204     self._part.save(path_or_stream)
#
# File D:\Anaconda2025.4.20\Lib\site-packages\docx\parts\document.py:114, in DocumentPart.save(self, path_or_stream)
#     111 def save(self, path_or_stream: str | IO[bytes]):
#     112     """Save this document to `path_or_stream`, which can be either a path to a
#     113     filesystem location (a string) or a file-like object."""
# --> 114     self.package.save(path_or_stream)
#
# File D:\Anaconda2025.4.20\Lib\site-packages\docx\opc\package.py:166, in OpcPackage.save(self, pkg_file)
#     164 for part in self.parts:
#     165     part.before_marshal()
# --> 166 PackageWriter.write(pkg_file, self.rels, self.parts)
#
# File D:\Anaconda2025.4.20\Lib\site-packages\docx\opc\pkgwriter.py:34, in PackageWriter.write(pkg_file, pkg_rels, parts)
#      30 @staticmethod
#      31 def write(pkg_file, pkg_rels, parts):
#      32     """Write a physical package (.pptx file) to `pkg_file` containing `pkg_rels` and
#      33     `parts` and a content types stream based on the content types of the parts."""
# ---> 34     phys_writer = PhysPkgWriter(pkg_file)
#      35     PackageWriter._write_content_types_stream(phys_writer, parts)
#      36     PackageWriter._write_pkg_rels(phys_writer, pkg_rels)
#
# File D:\Anaconda2025.4.20\Lib\site-packages\docx\opc\phys_pkg.py:109, in _ZipPkgWriter.__init__(self, pkg_file)
#     107 def __init__(self, pkg_file):
#     108     super(_ZipPkgWriter, self).__init__()
# --> 109     self._zipf = ZipFile(pkg_file, "w", compression=ZIP_DEFLATED)
#
# File D:\Anaconda2025.4.20\Lib\zipfile\__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# OSError: [Errno 22] Invalid argument: 'applications_output\\Application_Facoltà di Economia, Università degli Studi di Roma "Tor Vergata"_FINANCE.docx'

# %%
# !pip install docx2pdf
from docx2pdf import convert
def to_pdf(docx_path,pdf_path=None):
    if pdf_path is None:
        pdf_path=docx_path.replace('docx','pdf')
    convert(docx_path,pdf_path)
    print(f"转换PDF成功")
    return True

if __name__ =="__main__":
    to_pdf(r"C:\Users\24522\python25\applications_output\Application_Barcelona School of Economics (BSE)_ECON.docx")
# Out:
# Requirement already satisfied: docx2pdf in d:\anaconda2025.4.20\lib\site-packages (0.1.8)
# Requirement already satisfied: pywin32>=227 in d:\anaconda2025.4.20\lib\site-packages (from docx2pdf) (305.1)
# Requirement already satisfied: tqdm>=4.41.0 in d:\anaconda2025.4.20\lib\site-packages (from docx2pdf) (4.66.5)
# Requirement already satisfied: colorama in d:\anaconda2025.4.20\lib\site-packages (from tqdm>=4.41.0->docx2pdf) (0.4.6)
#   0%|          | 0/1 [00:00<?, ?it/s]
# 转换PDF成功

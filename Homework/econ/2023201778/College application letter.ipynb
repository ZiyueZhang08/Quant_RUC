# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
# !pip install pandas docxtpl docx2pdf
# Out:
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (2.2.2)
# Requirement already satisfied: docxtpl in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (0.20.1)
# Requirement already satisfied: docx2pdf in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (0.1.8)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-docx>=1.1.1 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docxtpl) (1.2.0)
# Requirement already satisfied: docxcompose in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docxtpl) (1.4.0)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docxtpl) (3.1.4)
# Requirement already satisfied: lxml in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docxtpl) (6.0.2)
# Requirement already satisfied: pywin32>=227 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docx2pdf) (306)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docx2pdf) (4.66.5)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-docx>=1.1.1->docxtpl) (4.12.2)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from tqdm>=4.41.0->docx2pdf) (0.4.6)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docxcompose->docxtpl) (72.2.0)
# Requirement already satisfied: babel in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from docxcompose->docxtpl) (2.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jinja2->docxtpl) (2.1.5)

# %%
import pandas as pd
from docxtpl import DocxTemplate
import os
from datetime import datetime

# %%
def generate_application_letters():
    # 创建输出目录
    output_dir = "HW_School_Application"
    os.makedirs(output_dir, exist_ok=True)
    
    # 读取Excel数据
    try:
        # 读取目标学校
        df_schools = pd.read_excel(r"C:\Users\lenovo\Desktop\Python homework.xlsx", sheet_name="target college")
        schools = df_schools.iloc[:, 1].dropna().tolist()  # 获取B列的所有学校
        
        # 读取领域和期刊
        df_journals = pd.read_excel(r"C:\Users\lenovo\Desktop\Python homework.xlsx", sheet_name="Field and Journal")
    except Exception as e:
        print(f"读取Excel文件错误: {e}")
        return
    
    # 处理期刊数据
    fields_journals = {}
    current_field = None
    
    for index, row in df_journals.iterrows():
        field = row['Field']
        journal = row['Journal']
        
        if pd.notna(field):
            current_field = field
            fields_journals[current_field] = []
        
        if pd.notna(journal) and current_field:
            fields_journals[current_field].append(journal)
    
    # 技能列表（从step6获取）
    skills = [
        "Python, R, Stata, SQL, MATLAB, Econometrics, Statistical Analysis, Machine Learning",
        "Python, SQL, Tableau, Power BI, Financial Modeling, Risk Management, Data Visualization", 
        "Stata, R, Python, Econometric Analysis, Time Series Analysis, Statistical Modeling, Data Mining",
        "MATLAB, Python, SQL, Quantitative Analysis, Mathematical Modeling, Optimization Techniques",
        "R, Python, SQL, Statistical Inference, Experimental Design, Causal Inference Methods"
    ]
    
    # 个人基本信息
    personal_info = {
        'name': 'Zimin Gu ',
        'program': 'Doctor of Economics'
    }
    
    # 加载Word模板
    try:
        doc = DocxTemplate(r"C:\Users\lenovo\Desktop\MS Word template(Admission Letter).docx")
    except Exception as e:
        print(f"加载Word模板错误: {e}")
        return
    
    # 生成申请信
    generated_count = 0
    
    for i, school in enumerate(schools):
        for field, journals in fields_journals.items():
            # 选择技能（循环使用）
            skill = skills[i % len(skills)]
            
            # 准备上下文数据
            context = {
                'name': personal_info['name'],
                'program': personal_info['program'],
                'university': school,
                'journals': ', '.join(journals[:3]),  # 取前3个期刊
                'skills': skill,
                'field': field.lower(),
                'current_date': datetime.now().strftime("%B %d, %Y")
            }
            
            # 渲染文档
            doc.render(context)
               
            # 生成文件名
            filename = f"{school.replace(' ', '_').replace('(', '').replace(')', '')}_{field}_application.docx"
            filepath = os.path.join(output_dir, filename)
            
            # 保存文档
            doc.save(filepath)
            generated_count += 1
            
            print(f"生成: {filename}")
    
    print(f"\n成功生成 {generated_count} 封申请信!")
    
    # 生成一个示例PDF（如果环境支持）
    try:
        # 生成一个示例文件用于提交
        example_context = {
            'name': personal_info['name'],
            'program': personal_info['program'],
            'university': schools[0],
            'journals': ', '.join(list(fields_journals.values())[0][:3]),
            'skills': skills[0],
            'field': list(fields_journals.keys())[0].lower(),
            'current_date': datetime.now().strftime("%B %d, %Y")
        }
        
        example_doc = DocxTemplate(r"C:\Users\lenovo\Desktop\MS Word template(Admission Letter).docx")
        example_doc.render(example_context)
        example_path = os.path.join(output_dir, "Example_Application.docx")
        example_doc.save(example_path)
        
        # 尝试转换为PDF（仅Windows）
        try:
            from docx2pdf import convert
            convert(example_path, example_path.replace('.docx', '.pdf'))
            print(f"已生成示例PDF文件: {example_path.replace('.docx', '.pdf')}")
        except:
            print("PDF转换不可用，仅生成Word文档")
            
    except Exception as e:
        print(f"生成示例文件时出错: {e}")

if __name__ == "__main__":
    generate_application_letters()
# Out:
# 生成: Economics_Department,_London_School_of_Economics_LSE_ECON_application.docx
# 生成: Economics_Department,_London_School_of_Economics_LSE_FINANCE_application.docx
# 生成: Economics_Department,_London_School_of_Economics_LSE_MKT_application.docx
# 生成: Department_of_Economics,_University_College_London_UCL_ECON_application.docx
# 生成: Department_of_Economics,_University_College_London_UCL_FINANCE_application.docx
# 生成: Department_of_Economics,_University_College_London_UCL_MKT_application.docx
# 生成: Department_of_Economics,_University_of_California-Berkeley_ECON_application.docx
# 生成: Department_of_Economics,_University_of_California-Berkeley_FINANCE_application.docx
# 生成: Department_of_Economics,_University_of_California-Berkeley_MKT_application.docx
# 生成: Paris_School_of_Economics_ECON_application.docx
# 生成: Paris_School_of_Economics_FINANCE_application.docx
# 生成: Paris_School_of_Economics_MKT_application.docx
# 生成: Department_of_Economics,_Oxford_University_ECON_application.docx
# 生成: Department_of_Economics,_Oxford_University_FINANCE_application.docx
# 生成: Department_of_Economics,_Oxford_University_MKT_application.docx
# 生成: Barcelona_School_of_Economics_BSE_ECON_application.docx
# 生成: Barcelona_School_of_Economics_BSE_FINANCE_application.docx
# 生成: Barcelona_School_of_Economics_BSE_MKT_application.docx
# 生成: School_of_Economics_and_Management,_Universiteit_van_Tilburg_ECON_application.docx
# 生成: School_of_Economics_and_Management,_Universiteit_van_Tilburg_FINANCE_application.docx
# 生成: School_of_Economics_and_Management,_Universiteit_van_Tilburg_MKT_application.docx
# 生成: Vancouver_School_of_Economics,_University_of_British_Columbia_ECON_application.docx
# 生成: Vancouver_School_of_Economics,_University_of_British_Columbia_FINANCE_application.docx
# 生成: Vancouver_School_of_Economics,_University_of_British_Columbia_MKT_application.docx
# 生成: Institut_für_Volkswirtschaftslehre,_Wirtschaftswissenschaftliche_Fakutält,_Universität_Zürich_ECON_application.docx
# 生成: Institut_für_Volkswirtschaftslehre,_Wirtschaftswissenschaftliche_Fakutält,_Universität_Zürich_FINANCE_application.docx
# 生成: Institut_für_Volkswirtschaftslehre,_Wirtschaftswissenschaftliche_Fakutält,_Universität_Zürich_MKT_application.docx
# 生成: Department_of_Economics,_Harvard_University_ECON_application.docx
# 生成: Department_of_Economics,_Harvard_University_FINANCE_application.docx
# 生成: Department_of_Economics,_Harvard_University_MKT_application.docx
# 生成: Faculty_of_Economics,_University_of_Cambridge_ECON_application.docx
# 生成: Faculty_of_Economics,_University_of_Cambridge_FINANCE_application.docx
# 生成: Faculty_of_Economics,_University_of_Cambridge_MKT_application.docx
# 生成: Department_of_Economics,_University_of_Toronto_ECON_application.docx
# 生成: Department_of_Economics,_University_of_Toronto_FINANCE_application.docx
# 生成: Department_of_Economics,_University_of_Toronto_MKT_application.docx
# 生成: Department_of_Economics,_University_of_Warwick_ECON_application.docx
# 生成: Department_of_Economics,_University_of_Warwick_FINANCE_application.docx
# 生成: Department_of_Economics,_University_of_Warwick_MKT_application.docx
# 生成: Department_of_Economics,_Sciences_économiques,_Sciences_Po_ECON_application.docx
# 生成: Department_of_Economics,_Sciences_économiques,_Sciences_Po_FINANCE_application.docx
# 生成: Department_of_Economics,_Sciences_économiques,_Sciences_Po_MKT_application.docx
# 生成: Faculteit_Economie_en_Bedrijfswetenschappen,_KU_Leuven_ECON_application.docx
# 生成: Faculteit_Economie_en_Bedrijfswetenschappen,_KU_Leuven_FINANCE_application.docx
# 生成: Faculteit_Economie_en_Bedrijfswetenschappen,_KU_Leuven_MKT_application.docx
# 生成: School_of_Business_and_Economics,_Vrije_Universiteit_Amsterdam_ECON_application.docx
# 生成: School_of_Business_and_Economics,_Vrije_Universiteit_Amsterdam_FINANCE_application.docx
# 生成: School_of_Business_and_Economics,_Vrije_Universiteit_Amsterdam_MKT_application.docx
# 生成: Department_of_Economics_and_Related_Studies,_University_of_York_ECON_application.docx
# 生成: Department_of_Economics_and_Related_Studies,_University_of_York_FINANCE_application.docx
# 生成: Department_of_Economics_and_Related_Studies,_University_of_York_MKT_application.docx
# 生成: Faculteit_Economie_en_Bedrijfskunde,_Universiteit_van_Amsterdam_ECON_application.docx
# 生成: Faculteit_Economie_en_Bedrijfskunde,_Universiteit_van_Amsterdam_FINANCE_application.docx
# 生成: Faculteit_Economie_en_Bedrijfskunde,_Universiteit_van_Amsterdam_MKT_application.docx
# 生成: Økonomisk_Institut,_Københavns_Universitet_ECON_application.docx
# 生成: Økonomisk_Institut,_Københavns_Universitet_FINANCE_application.docx
# 生成: Økonomisk_Institut,_Københavns_Universitet_MKT_application.docx
# 生成: Centro_de_Estudios_Monetarios_y_Financieros_CEMFI_ECON_application.docx
# 生成: Centro_de_Estudios_Monetarios_y_Financieros_CEMFI_FINANCE_application.docx
# 生成: Centro_de_Estudios_Monetarios_y_Financieros_CEMFI_MKT_application.docx
# 生成: Dipartimenti_e_Istituti_di_Scienze_Economiche,_Università_Cattolica_del_Sacro_Cuore_ECON_application.docx
# 生成: Dipartimenti_e_Istituti_di_Scienze_Economiche,_Università_Cattolica_del_Sacro_Cuore_FINANCE_application.docx
# 生成: Dipartimenti_e_Istituti_di_Scienze_Economiche,_Università_Cattolica_del_Sacro_Cuore_MKT_application.docx
# 生成: School_of_Economics,_Universitat_de_Barcelona_ECON_application.docx
# 生成: School_of_Economics,_Universitat_de_Barcelona_FINANCE_application.docx
# 生成: School_of_Economics,_Universitat_de_Barcelona_MKT_application.docx
# 生成: Departamento_de_Economía,_Universidad_Carlos_III_de_Madrid_ECON_application.docx
# 生成: Departamento_de_Economía,_Universidad_Carlos_III_de_Madrid_FINANCE_application.docx
# 生成: Departamento_de_Economía,_Universidad_Carlos_III_de_Madrid_MKT_application.docx
# 生成: Økonomisk_institutt,_Universitetet_i_Oslo_ECON_application.docx
# 生成: Økonomisk_institutt,_Universitetet_i_Oslo_FINANCE_application.docx
# 生成: Økonomisk_institutt,_Universitetet_i_Oslo_MKT_application.docx
# 生成: School_of_Economics,_UNSW_Business_School,_UNSW_Sydney_ECON_application.docx
# 生成: School_of_Economics,_UNSW_Business_School,_UNSW_Sydney_FINANCE_application.docx
# 生成: School_of_Economics,_UNSW_Business_School,_UNSW_Sydney_MKT_application.docx
# 生成: Wirtschaftswissenschaftlicher_Fachbereich,_Rheinische_Friedrich-Wilhelms-Universität_Bonn_ECON_application.docx
# 生成: Wirtschaftswissenschaftlicher_Fachbereich,_Rheinische_Friedrich-Wilhelms-Universität_Bonn_FINANCE_application.docx
# 生成: Wirtschaftswissenschaftlicher_Fachbereich,_Rheinische_Friedrich-Wilhelms-Universität_Bonn_MKT_application.docx
# 生成: Department_of_Economics,_McGill_University_ECON_application.docx
# 生成: Department_of_Economics,_McGill_University_FINANCE_application.docx
# 生成: Department_of_Economics,_McGill_University_MKT_application.docx
# 生成: College_of_Business_and_Economics,_Australian_National_University_ECON_application.docx
# 生成: College_of_Business_and_Economics,_Australian_National_University_FINANCE_application.docx
# 生成: College_of_Business_and_Economics,_Australian_National_University_MKT_application.docx
# 生成: Economics_Department,_Stern_School_of_Business,_New_York_University_NYU_ECON_application.docx
# 生成: Economics_Department,_Stern_School_of_Business,_New_York_University_NYU_FINANCE_application.docx
# 生成: Economics_Department,_Stern_School_of_Business,_New_York_University_NYU_MKT_application.docx
# 生成: Volkswirtschaftliche_Fakultät,_Ludwig-Maximilians-Universität_München_ECON_application.docx
# 生成: Volkswirtschaftliche_Fakultät,_Ludwig-Maximilians-Universität_München_FINANCE_application.docx
# 生成: Volkswirtschaftliche_Fakultät,_Ludwig-Maximilians-Universität_München_MKT_application.docx
#
# 成功生成 90 封申请信!
#   0%|          | 0/1 [00:00<?, ?it/s]
# 已生成示例PDF文件: HW_School_Application\Example_Application.pdf

# %%
import os
print("当前工作目录:", os.getcwd())
# Out:
# 当前工作目录: C:\Users\lenovo

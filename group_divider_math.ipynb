# %%
import pandas as pd

filename='mathecon.xlsx'

df=pd.read_excel(filename,header=2)

cond=df['序号'].notnull()
df=df[cond]

df=df.astype({'学号':int})

var_list=['序号', '学号', '姓名', '班级']

df=df[var_list]
# Out:
# c:\Users\Leige\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df['班级'].replace('\d\d\d\d|级|\d|班','',regex=True).value_counts()
# Out:
# 班级
# 经济学-数学双学位实验               13
# “经济学-数学”双学士学位复合型人才培养项目     6
# Name: count, dtype: int64

# %%
df_groups=df.sample(frac = 1,random_state=202509)

df_groups['number'] = range(len(df_groups))

n_members=4

df_groups['group']=df_groups['number']//n_members+1

# %%
df_groups.sort_values(by='group')
# Out:
#       序号          学号   姓名                            班级  number  group
# 1    1.0  2023200593   赵蔚              2023经济学-数学双学位实验班       0      1
# 15  15.0  2023201778  顾梓民  2023“经济学-数学”双学士学位复合型人才培养项目1班       1      1
# 3    3.0  2023200604  路畅宇              2023经济学-数学双学位实验班       2      1
# 14  14.0  2023201777  许家淼  2023“经济学-数学”双学士学位复合型人才培养项目1班       3      1
# 9    9.0  2023200740  陈君昊              2023经济学-数学双学位实验班       4      2
# 10  10.0  2023200753  白瑞睿              2023经济学-数学双学位实验班       5      2
# 12  12.0  2023200769   郑瑜              2023经济学-数学双学位实验班       6      2
# 16  16.0  2023201779  孙一丹  2023“经济学-数学”双学士学位复合型人才培养项目1班       7      2
# 13  13.0  2023200778  贺佳乐              2023经济学-数学双学位实验班       8      3
# 19  19.0  2023201782  柏欣妍  2023“经济学-数学”双学士学位复合型人才培养项目1班       9      3
# 4    4.0  2023200609  王一舟              2023经济学-数学双学位实验班      10      3
# 18  18.0  2023201781  王子涵  2023“经济学-数学”双学士学位复合型人才培养项目1班      11      3
# 5    5.0  2023200697  陶绪志              2023经济学-数学双学位实验班      12      4
# 8    8.0  2023200727  吴宇茜              2023经济学-数学双学位实验班      13      4
# 7    7.0  2023200725  潘晓语              2023经济学-数学双学位实验班      14      4
# 17  17.0  2023201780  袁博辰  2023“经济学-数学”双学士学位复合型人才培养项目1班      15      4
# 2    2.0  2023200595  高福玉              2023经济学-数学双学位实验班      16      5
# 11  11.0  2023200761  黄皆瑞              2023经济学-数学双学位实验班      17      5
# 6    6.0  2023200721  李昕芮              2023经济学-数学双学位实验班      18      5
